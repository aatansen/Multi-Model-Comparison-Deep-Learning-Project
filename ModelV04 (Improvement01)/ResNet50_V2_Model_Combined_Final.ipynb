# %% [markdown]
# # ResNet50V2 Model (Kaggle + Roboflow Dataset)

# %% [markdown]
# ### Import required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import time
import matplotlib.pyplot as plt
from PIL import Image
import cv2
from google.colab.patches import cv2_imshow
import imutils
from sklearn.metrics import classification_report, confusion_matrix, precision_recall_fscore_support, roc_curve, auc
import tensorflow as tf
from tensorflow.keras.utils import plot_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.applications.resnet_v2 import preprocess_input
from tensorflow.keras.applications.resnet_v2 import ResNet50V2

# %% [markdown]
# ### Define constants

# %%
TRAIN_PATH = "/content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Training"
TEST_PATH = "/content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Testing"
labels = ['glioma_tumor', 'meningioma_tumor', 'no_tumor', 'pituitary_tumor']
IMAGE_SIZE = [224, 224]
BATCH_SIZE = 32
NUM_EPOCHS = 50

# %% [markdown]
# ### Count of images Before filtering

# %%
print("Before filtering out images:")
for label in labels:
    train_count = len(os.listdir(os.path.join(TRAIN_PATH, label)))
    test_count = len(os.listdir(os.path.join(TEST_PATH, label)))
    print(f"{label}: Train - {train_count}, Test - {test_count}")
    
total_train_count = sum([len(os.listdir(os.path.join(TRAIN_PATH, label))) for label in labels])
total_test_count = sum([len(os.listdir(os.path.join(TEST_PATH, label))) for label in labels])
print(f"Total: Train - {total_train_count}, Test - {total_test_count}")
# Out:
# Before filtering out images:
# glioma_tumor: Train - 2147, Test - 399
# meningioma_tumor: Train - 2155, Test - 416
# no_tumor: Train - 1801, Test - 486
# pituitary_tumor: Train - 2272, Test - 374
# Total: Train - 8375, Test - 1675

# %% [markdown]
# ### Filtering images

# %%
# Initialize a dictionary to store the count of detected black images for each label
detected_count = {label: 0 for label in labels}

# Loop through each label folder in training and testing paths
for path in [TRAIN_PATH, TEST_PATH]:
    for label in labels:
        dir_path = os.path.join(path, label)

        # Loop through each image in the folder
        for img_name in os.listdir(dir_path):
            img_path = os.path.join(dir_path, img_name)
            img = cv2.imread(img_path)

            # Check if the image is mostly black
            if (img.max() <= 120):
                detected_count[label] += 1
                print(f"Detected {img_path} as mostly black. Maximum pixel value: {img.max()}")

                # Remove the detected black image from the original location
                os.remove(img_path)

# Print the count of detected black images for each label
for label in labels:
    print(f"Detected {detected_count[label]} mostly black images for {label} label.") 

if sum(detected_count.values()) == 0:
    print("No black images detected.")
# Out:
# Detected /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Training/glioma_tumor/Tr-gl_0495_jpg.rf.ace2cba0de49d4aa276f1c0d2c648f6f.jpg as mostly black. Maximum pixel value: 84
# Detected /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Training/glioma_tumor/Tr-gl_1145_jpg.rf.cd8d56ea44a6ec0fae3d86a626987d10.jpg as mostly black. Maximum pixel value: 90
# Detected /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Training/glioma_tumor/Tr-gl_0206_jpg.rf.f749061bc2037da1da840d38020d0515.jpg as mostly black. Maximum pixel value: 83
# Detected /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Training/glioma_tumor/Tr-gl_0158_jpg.rf.2807bb97ceabca643be6e44c720bb97e.jpg as mostly black. Maximum pixel value: 117
# Detected /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Training/glioma_tumor/Tr-gl_0635_jpg.rf.a9023ff2c43c9764b72594b7aaa39ecc.jpg as mostly black. Maximum pixel value: 93
# Detected /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Training/glioma_tumor/Tr-gl_0554_jpg.rf.2948be701b85f0267bb95deb7fb2c65d.jpg as mostly black. Maximum pixel value: 98
# Detected /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Training/glioma_tumor/Tr-gl_0500_jpg.rf.2282d48313e15fe677fcb24cb3c0cfaa.jpg as mostly black. Maximum pixel value: 93
# Detected /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Training/glioma_tumor/Tr-gl_0208_jpg.rf.2d2f6f429eb3cdbd6f0ffec434848130.jpg as mostly black. Maximum pixel value: 87
# Detected /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Training/glioma_tumor/Tr-gl_0809_jpg.rf.f5b3e0c62d727167c44bc4661e08c18f.jpg as mostly black. Maximum pixel value: 107
# Detected /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Training/glioma_tumor/Tr-gl_0130_jpg.rf.a9c1433ac10d3c5c085d8a5ee616cc10.jpg as mostly black. Maximum pixel value: 74
# Detected /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Training/glioma_tumor/Tr-glTr_0001_jpg.rf.abb005e4e3abc069146ee85b292644b3.jpg as mostly black. Maximum pixel value: 93
# Detected /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Training/glioma_tumor/Tr-gl_1228_jpg.rf.f8de6c674314011c60ed000d0c3bfe32.jpg as mostly black. Maximum pixel value: 87
# Detected /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Training/glioma_tumor/Tr-gl_0991_jpg.rf.2f2653ae6f67571e8195461dae772e54.jpg as mostly black. Maximum pixel value: 85
# Detected /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Training/glioma_tumor/Tr-gl_1244_jpg.rf.2be79d7a8625f5dc93e219716d7273d2.jpg as mostly black. Maximum pixel value: 100
# Detected /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Training/glioma_tumor/Tr-gl_1084_jpg.rf.0060179a4b4eb50f5ca84e4ee9b74c50.jpg as mostly black. Maximum pixel value: 81
# Detected /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Training/glioma_tumor/Tr-gl_
jpg as mostly black. Maximum pixel value: 102
# Detected /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Training/pituitary_tumor/Tr-pi_0986_jpg.rf.478a6c68d3e09f248649fa2812fd56e7.jpg as mostly black. Maximum pixel value: 94
# Detected /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Training/pituitary_tumor/Tr-pi_0365_jpg.rf.1a34e6833e6259eb0dacef2b25598d4c.jpg as mostly black. Maximum pixel value: 77
# Detected /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Training/pituitary_tumor/Tr-pi_1308_jpg.rf.a28276947fdc1d804d1438cb918aff63.jpg as mostly black. Maximum pixel value: 120
# Detected /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Training/pituitary_tumor/Tr-pi_1170_jpg.rf.72afc4a9c3118840f6da723543033440.jpg as mostly black. Maximum pixel value: 93
# Detected /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Training/pituitary_tumor/Tr-pi_0881_jpg.rf.530d7838028f594bbde1d609884503d9.jpg as mostly black. Maximum pixel value: 86
# Detected /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Training/pituitary_tumor/Tr-pi_1224_jpg.rf.deb2429ce1363c70a0652f7af2d40960.jpg as mostly black. Maximum pixel value: 106
# Detected /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Training/pituitary_tumor/Tr-pi_1057_jpg.rf.00d61134087ca90db50fb24cb6fb6652.jpg as mostly black. Maximum pixel value: 89
# Detected /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Training/pituitary_tumor/Tr-pi_0792_jpg.rf.d35f226c48ac834e5ec1f1e04347c3da.jpg as mostly black. Maximum pixel value: 78
# Detected /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Training/pituitary_tumor/Tr-pi_0871_jpg.rf.d0b145f9f15bf40754385740b650ecf8.jpg as mostly black. Maximum pixel value: 108
# Detected /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Training/pituitary_tumor/Tr-pi_1412_jpg.rf.7ba0d5f3653d563f0e3cac0de6b038e8.jpg as mostly black. Maximum pixel value: 112
# Detected /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Training/pituitary_tumor/Tr-pi_0147_jpg.rf.f6e6074e6dc6bf20a4ef748a699a8385.jpg as mostly black. Maximum pixel value: 98
# Detected /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Training/pituitary_tumor/Tr-pi_0122_jpg.rf.80874f9f9afacad08eda05a0f81601a5.jpg as mostly black. Maximum pixel value: 98
# Detected /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Training/pituitary_tumor/Tr-pi_0458_jpg.rf.25af55a8fa1a06799625b1c04aa0984c.jpg as mostly black. Maximum pixel value: 98
# Detected /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Training/pituitary_tumor/Tr-pi_0179_jpg.rf.d881870d5f6b1900ed8a5e6186452143.jpg as mostly black. Maximum pixel value: 102
# Detected /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Training/pituitary_tumor/Tr-pi_0353_jpg.rf.d24285111f38ea2926b5e6806bf93813.jpg as mostly black. Maximum pixel value: 118
# Detected /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Training/pituitary_tumor/Tr-pi_1427_jpg.rf.79568d2d3adff4def0ab1834dec584c8.jpg as mostly black. Maximum pixel value: 113
# Detected /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Training/pituitary_tumor/Tr-pi_0121_jpg.rf.24a513cfb2dbf1e4b99a53c943eae9b6.jpg as mostly black. Maximum pixel value: 82
# Detected /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Training/pituitary_tumor/Tr-pi_0021_jpg.rf.fedef4835719093916fc1680bb3bc5e2.jpg as mostly black. Maximum pixel value: 85
# Detected /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Training/pituitary_tumor/Tr-pi_0294_jpg.rf.4f95e30b69c71ff072f011f5b8168c1d.jpg as mostly black. Maximum pixel value: 96
# Detected /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Training/pituitary_tumor/Tr-pi_0837_jpg.rf.b0637c3029e31968f6bcb6cad0958369.jpg as mostly black. Maximum pixel value: 119
# Detected /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Training/pituitary_tumor/Tr-pi_0985_jpg.rf.289d87d3552855ace2f00cc74e6e23d2.jpg as mostly black. Maximum pixel value: 88
# Detected /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Training/pituitary_tumor/Tr-pi_1341_jpg.rf.a63a1d065f101f2f854e46bd5169fd6d.jpg as mostly black. Maximum pixel value: 82
# Detected /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Training/pituitary_tumor/Tr-pi_0836_jpg.rf.cf0f6d7c840ec26e3128aa030cec4ff1.jpg as mostly black. Maximum pixel value: 120
# Detected /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Training/pituitary_tumor/Tr-pi_0962_jpg.rf.21ba8af4ae89a77024d02af3de9fde73.jpg as mostly black. Maximum pixel value: 85
# Detected /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Training/pituitary_tumor/Tr-pi_0666_jpg.rf.a9a43ec5e47f499a6fae49f67f04695c.jpg as mostly black. Maximum pixel value: 109
# Detected /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Training/pituitary_tumor/Tr-pi_0206_jpg.rf.594502a0d064e7e4cd2ae4c93a2e4acb.jpg as mostly black. Maximum pixel value: 78
# Detected /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Training/pituitary_tumor/Tr-pi_0314_jpg.rf.82fc66d579b6e1f28c996736c63050f3.jpg as mostly black. Maximum pixel value: 77
# Detected /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Training/pituitary_tumor/Tr-pi_0070_jpg.rf.fbd0e7b27e04941a4987805f155d572b.jpg as mostly black. Maximum pixel value: 116
# Detected /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Training/pituitary_tumor/Tr-pi_1114_jpg.rf.acbb001998cfef26341b9df4f580a75e.jpg as mostly black. Maximum pixel value: 83
# Detected /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Training/pituitary_tumor/Tr-pi_0943_jpg.rf.5800c8e9edc3e63e9df60090a436ac3d.jpg as mostly black. Maximum pixel value: 83
# Detected /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Training/pituitary_tumor/Tr-pi_0715_jpg.rf.4f9218cbf8c8b15a6a678084bb37b9ae.jpg as mostly black. Maximum pixel value: 90
# Detected /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Training/pituitary_tumor/Tr-pi_0260_jpg.rf.b129e15448ccec4a645d801e693ad9f8.jpg as mostly black. Maximum pixel value: 116
# Detected /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification Combined/Training/pituitary_tumor/Tr-pi_0580_jpg.rf.50b15af95f1da1e9b8440099bbd508cd.jpg as mostly black. Maximum pixel value: 91
# Detected 157 mostly black images for glioma_tumor label.
# Detected 155 mostly black images for meningioma_tumor label.
# Detected 121 mostly black images for no_tumor label.
# Detected 148 mostly black images for pituitary_tumor label.

# %% [markdown]
# ### Count of images After filtering

# %%
print("After filtering out images:")
for label in labels:
    train_count = len(os.listdir(os.path.join(TRAIN_PATH, label)))
    test_count = len(os.listdir(os.path.join(TEST_PATH, label)))
    print(f"{label}: Train - {train_count}, Test - {test_count}")
    
total_train_count = sum([len(os.listdir(os.path.join(TRAIN_PATH, label))) for label in labels])
total_test_count = sum([len(os.listdir(os.path.join(TEST_PATH, label))) for label in labels])
print(f"Total: Train - {total_train_count}, Test - {total_test_count}")
# Out:
# After filtering out images:
# glioma_tumor: Train - 1990, Test - 399
# meningioma_tumor: Train - 2000, Test - 416
# no_tumor: Train - 1680, Test - 486
# pituitary_tumor: Train - 2124, Test - 374
# Total: Train - 7794, Test - 1675

# %% [markdown]
# ### Show sample image of each labels

# %%
# Loop through the labels and show 1 sample from each folder horizontally
fig, axs = plt.subplots(1, len(labels), figsize=(16, 5))
for i, label in enumerate(labels):
  axs[i].set_title(label)

  # Get a list of images in the current folder
  directory = os.path.join(TRAIN_PATH, label)
  files = os.listdir(directory)

  # Show 1 sample image from the folder
  file = files[0]
  path = os.path.join(directory, file)
  img = tf.keras.preprocessing.image.load_img(path, target_size=IMAGE_SIZE)
  axs[i].imshow(img)
  
plt.show()

# %% [markdown]
# ### Create data generators for training and validation with advanced data augmentation

# %%
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    validation_split=0.2
)

test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_generator = train_datagen.flow_from_directory(
    TRAIN_PATH,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training'
)

validation_generator = train_datagen.flow_from_directory(
    TRAIN_PATH,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation'
)

test_generator = test_datagen.flow_from_directory(
    TEST_PATH,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 6236 images belonging to 4 classes.
# Found 1558 images belonging to 4 classes.
# Found 1675 images belonging to 4 classes.

# %% [markdown]
# ### Load the pre-trained ResNet50V2 model without top layers

# %%
base_model = ResNet50V2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94668760/94668760 [==============================] - 6s 0us/step

# %% [markdown]
# ### Add new fully connected layers on top of the base model

# %%
x = Flatten()(base_model.output)
prediction = Dense(train_generator.num_classes, activation='softmax')(x)

# %% [markdown]
# ### Create the model

# %%
model = Model(inputs=base_model.input, outputs=prediction)

# %% [markdown]
# ### Freeze the pre-trained layers in the base model and train only the new layers

# %%
for layer in base_model.layers:
    layer.trainable = False

# %% [markdown]
# ### Model Summary

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_conv[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_preact_bn (BatchN  (None, 56, 56, 64)  256         ['pool1_pool[0][0]']
#  ormalization)
#
#  conv2_block1_preact_relu (Acti  (None, 56, 56, 64)  0           ['conv2_block1_preact_bn[0][0]']
#  vation)
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 64)   4096        ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_pad (ZeroPaddin  (None, 58, 58, 64)  0           ['conv2_block1_1_relu[0][0]']
#  g2D)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 64)   36864       ['conv2_block1_2_pad[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_out (Add)         (None, 56, 56, 256)  0           ['conv2_block1_0_conv[0][0]',
#                                                                   'conv2_block1_3_conv[0][0]']
#
#  conv2_block2_preact_bn (BatchN  (None, 56, 56, 256)  1024       ['conv2_block1_out[0][0]']
#  ormalization)
#
#  conv2_block2_preact_relu (Acti  (None, 56, 56, 256)  0          ['conv2_block2_preact_bn[0][0]']
#  vation)
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 64)   16384       ['conv2_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_pad (ZeroPaddin  (None, 58, 58, 64)  0           ['conv2_block2_1_relu[0][0]']
#  g2D)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 64)   36864       ['conv2_block2_2_pad[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_out (Add)         (None, 56, 56, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_conv[0][0]']
#
#  conv2_block3_preact_bn (BatchN  (None, 56, 56, 256)  1024       ['conv2_block2_out[0][0]']
#  ormalization)
#
#  conv2_block3_preact_relu (Acti  (None, 56, 56, 256)  0          ['conv2_block3_preact_bn[0][0]']
#  vation)
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 64)   16384       ['conv2_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_pad (ZeroPaddin  (None, 58, 58, 64)  0           ['conv2_block3_1_relu[0][0]']
#  g2D)
#
#  conv2_block3_2_conv (Conv2D)   (None, 28, 28, 64)   36864       ['conv2_block3_2_pad[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 28, 28, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 28, 28, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  max_pooling2d (MaxPooling2D)   (None, 28, 28, 256)  0           ['conv2_block2_out[0][0]']
#
#  conv2_block3_3_conv (Conv2D)   (None, 28, 28, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_out (Add)         (None, 28, 28, 256)  0           ['max_pooling2d[0][0]',
#                                                                   'conv2_block3_3_conv[0][0]']
#
#  conv3_block1_preact_bn (BatchN  (None, 28, 28, 256)  1024       ['conv2_block3_out[0][0]']
#  ormalization)
#
#  conv3_block1_preact_relu (Acti  (None, 28, 28, 256)  0          ['conv3_block1_preact_bn[0][0]']
#  vation)
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  32768       ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block1_1_relu[0][0]']
#  g2D)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block1_2_pad[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 28, 28, 512)  131584      ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_out (Add)         (None, 28, 28, 512)  0           ['conv3_block1_0_conv[0][0]',
#                                                                   'conv3_block1_3_conv[0][0]']
#
#  conv3_block2_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block1_out[0][0]']
#  ormalization)
#
#  conv3_block2_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block2_preact_bn[0][0]']
#  vation)
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block2_1_relu[0][0]']
#  g2D)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block2_2_pad[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_out (Add)         (None, 28, 28, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_conv[0][0]']
#
#  conv3_block3_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block2_out[0][0]']
#  ormalization)
#
#  conv3_block3_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block3_preact_bn[0][0]']
#  vation)
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block3_1_relu[0][0]']
#  g2D)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block3_2_pad[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_out (Add)         (None, 28, 28, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_conv[0][0]']
#
#  conv3_block4_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block3_out[0][0]']
#  ormalization)
#
#  conv3_block4_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block4_preact_bn[0][0]']
#  vation)
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block4_1_relu[0][0]']
#  g2D)
#
#  conv3_block4_2_conv (Conv2D)   (None, 14, 14, 128)  147456      ['conv3_block4_2_pad[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 14, 14, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 14, 14, 512)  0          ['conv3_block3_out[0][0]']
#
#  conv3_block4_3_conv (Conv2D)   (None, 14, 14, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_out (Add)         (None, 14, 14, 512)  0           ['max_pooling2d_1[0][0]',
#                                                                   'conv3_block4_3_conv[0][0]']
#
#  conv4_block1_preact_bn (BatchN  (None, 14, 14, 512)  2048       ['conv3_block4_out[0][0]']
#  ormalization)
#
#  conv4_block1_preact_relu (Acti  (None, 14, 14, 512)  0          ['conv4_block1_preact_bn[0][0]']
#  vation)
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 256)  131072      ['conv4_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block1_1_relu[0][0]']
#  g2D)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block1_2_pad[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 14, 14, 1024  525312      ['conv4_block1_preact_relu[0][0]'
#                                 )                                ]
#
#  conv4_block1_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_out (Add)         (None, 14, 14, 1024  0           ['conv4_block1_0_conv[0][0]',
#                                 )                                 'conv4_block1_3_conv[0][0]']
#
#  conv4_block2_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block1_out[0][0]']
#  ormalization)                  )
#
#  conv4_block2_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block2_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block2_1_relu[0][0]']
#  g2D)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block2_2_pad[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_out (Add)         (None, 14, 14, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_conv[0][0]']
#
#  conv4_block3_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block2_out[0][0]']
#  ormalization)                  )
#
#  conv4_block3_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block3_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block3_1_relu[0][0]']
#  g2D)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block3_2_pad[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_out (Add)         (None, 14, 14, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_conv[0][0]']
#
#  conv4_block4_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block3_out[0][0]']
#  ormalization)                  )
#
#  conv4_block4_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block4_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block4_1_relu[0][0]']
#  g2D)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block4_2_pad[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_out (Add)         (None, 14, 14, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_conv[0][0]']
#
#  conv4_block5_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block4_out[0][0]']
#  ormalization)                  )
#
#  conv4_block5_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block5_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block5_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block5_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block5_1_relu[0][0]']
#  g2D)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block5_2_pad[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_out (Add)         (None, 14, 14, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_conv[0][0]']
#
#  conv4_block6_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block5_out[0][0]']
#  ormalization)                  )
#
#  conv4_block6_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block6_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block6_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block6_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block6_1_relu[0][0]']
#  g2D)
#
#  conv4_block6_2_conv (Conv2D)   (None, 7, 7, 256)    589824      ['conv4_block6_2_pad[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block6_2_bn[0][0]']
#  n)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 7, 7, 1024)  0           ['conv4_block5_out[0][0]']
#
#  conv4_block6_3_conv (Conv2D)   (None, 7, 7, 1024)   263168      ['conv4_block6_2_relu[0][0]']
#
#  conv4_block6_out (Add)         (None, 7, 7, 1024)   0           ['max_pooling2d_2[0][0]',
#                                                                   'conv4_block6_3_conv[0][0]']
#
#  conv5_block1_preact_bn (BatchN  (None, 7, 7, 1024)  4096        ['conv4_block6_out[0][0]']
#  ormalization)
#
#  conv5_block1_preact_relu (Acti  (None, 7, 7, 1024)  0           ['conv5_block1_preact_bn[0][0]']
#  vation)
#
#  conv5_block1_1_conv (Conv2D)   (None, 7, 7, 512)    524288      ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_pad (ZeroPaddin  (None, 9, 9, 512)   0           ['conv5_block1_1_relu[0][0]']
#  g2D)
#
#  conv5_block1_2_conv (Conv2D)   (None, 7, 7, 512)    2359296     ['conv5_block1_2_pad[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 7, 7, 2048)   2099200     ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_out (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_0_conv[0][0]',
#                                                                   'conv5_block1_3_conv[0][0]']
#
#  conv5_block2_preact_bn (BatchN  (None, 7, 7, 2048)  8192        ['conv5_block1_out[0][0]']
#  ormalization)
#
#  conv5_block2_preact_relu (Acti  (None, 7, 7, 2048)  0           ['conv5_block2_preact_bn[0][0]']
#  vation)
#
#  conv5_block2_1_conv (Conv2D)   (None, 7, 7, 512)    1048576     ['conv5_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block2_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_pad (ZeroPaddin  (None, 9, 9, 512)   0           ['conv5_block2_1_relu[0][0]']
#  g2D)
#
#  conv5_block2_2_conv (Conv2D)   (None, 7, 7, 512)    2359296     ['conv5_block2_2_pad[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_out (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_conv[0][0]']
#
#  conv5_block3_preact_bn (BatchN  (None, 7, 7, 2048)  8192        ['conv5_block2_out[0][0]']
#  ormalization)
#
#  conv5_block3_preact_relu (Acti  (None, 7, 7, 2048)  0           ['conv5_block3_preact_bn[0][0]']
#  vation)
#
#  conv5_block3_1_conv (Conv2D)   (None, 7, 7, 512)    1048576     ['conv5_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block3_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_pad (ZeroPaddin  (None, 9, 9, 512)   0           ['conv5_block3_1_relu[0][0]']
#  g2D)
#
#  conv5_block3_2_conv (Conv2D)   (None, 7, 7, 512)    2359296     ['conv5_block3_2_pad[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_out (Add)         (None, 7, 7, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_conv[0][0]']
#
#  post_bn (BatchNormalization)   (None, 7, 7, 2048)   8192        ['conv5_block3_out[0][0]']
#
#  post_relu (Activation)         (None, 7, 7, 2048)   0           ['post_bn[0][0]']
#
#  flatten (Flatten)              (None, 100352)       0           ['post_relu[0][0]']
#
#  dense (Dense)                  (None, 4)            401412      ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 23,966,212
# Trainable params: 401,412
# Non-trainable params: 23,564,800
# __________________________________________________________________________________________________

# %% [markdown]
# ### Visualize the model architecture

# %%
plot_model(model=model, show_shapes=True)

# %% [markdown]
# ### Compile the model with categorical cross-entropy loss and a lower learning rate

# %%
model.compile(
    loss='categorical_crossentropy',
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    metrics=['accuracy'])

# %% [markdown]
# ### Save the Model

# %%
# Define a callback to save the best model weights
checkpoint = ModelCheckpoint('/content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/ResNet50V2_Combined_Final.h5', 
                              monitor='val_accuracy', 
                              save_best_only=True, 
                              mode='max', 
                              verbose=1)

# Define a callback to track and print total training time and highest accuracy
class TimingCallback(tf.keras.callbacks.Callback):
    def __init__(self):
        self.start_time = None
        self.total_time = 0.0
        self.highest_train_acc = 0.0
        self.highest_val_acc = 0.0
        self.highest_train_epoch = 0
        self.highest_val_epoch = 0

    def on_epoch_begin(self, epoch, logs=None):
        self.start_time = time.time()

    def on_epoch_end(self, epoch, logs=None):
        epoch_time = time.time() - self.start_time
        self.total_time += epoch_time
        print(f'Total training time for epoch {epoch + 1}: {epoch_time:.2f} seconds')

        train_acc = logs['accuracy']
        val_acc = logs['val_accuracy']

        if train_acc > self.highest_train_acc:
            self.highest_train_acc = train_acc
            self.highest_train_epoch = epoch + 1
        
        if val_acc > self.highest_val_acc:
            self.highest_val_acc = val_acc
            self.highest_val_epoch = epoch + 1

        print(f'Highest training accuracy: {self.highest_train_acc:.4f} at epoch {self.highest_train_epoch}')
        print(f'Highest validation accuracy: {self.highest_val_acc:.4f} at epoch {self.highest_val_epoch}')

# %% [markdown]
# ### Train the model on training data and evaluate on validation data

# %%
timing_callback = TimingCallback()
history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=NUM_EPOCHS,
    steps_per_epoch=len(train_generator),
    validation_steps=len(validation_generator),
    callbacks=[checkpoint, timing_callback]
)

print(f'Total training time for {len(history.epoch)} epochs: {timing_callback.total_time:.2f} seconds')
# Out:
# Epoch 1/50
# 195/195 [==============================] - ETA: 0s - loss: 0.7524 - accuracy: 0.7752
# Epoch 1: val_accuracy improved from -inf to 0.77343, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/ResNet50V2_Combined_Final.h5
# Total training time for epoch 1: 148.92 seconds
# Highest training accuracy: 0.7752 at epoch 1
# Highest validation accuracy: 0.7734 at epoch 1
# 195/195 [==============================] - 149s 694ms/step - loss: 0.7524 - accuracy: 0.7752 - val_loss: 0.7516 - val_accuracy: 0.7734
# Epoch 2/50
# 195/195 [==============================] - ETA: 0s - loss: 0.4542 - accuracy: 0.8541
# Epoch 2: val_accuracy improved from 0.77343 to 0.80809, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/ResNet50V2_Combined_Final.h5
# Total training time for epoch 2: 133.91 seconds
# Highest training accuracy: 0.8541 at epoch 2
# Highest validation accuracy: 0.8081 at epoch 2
# 195/195 [==============================] - 134s 687ms/step - loss: 0.4542 - accuracy: 0.8541 - val_loss: 0.6386 - val_accuracy: 0.8081
# Epoch 3/50
# 195/195 [==============================] - ETA: 0s - loss: 0.3690 - accuracy: 0.8884
# Epoch 3: val_accuracy improved from 0.80809 to 0.85751, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/ResNet50V2_Combined_Final.h5
# Total training time for epoch 3: 148.77 seconds
# Highest training accuracy: 0.8884 at epoch 3
# Highest validation accuracy: 0.8575 at epoch 3
# 195/195 [==============================] - 149s 764ms/step - loss: 0.3690 - accuracy: 0.8884 - val_loss: 0.5002 - val_accuracy: 0.8575
# Epoch 4/50
# 195/195 [==============================] - ETA: 0s - loss: 0.3227 - accuracy: 0.8987
# Epoch 4: val_accuracy improved from 0.85751 to 0.87805, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/ResNet50V2_Combined_Final.h5
# Total training time for epoch 4: 146.30 seconds
# Highest training accuracy: 0.8987 at epoch 4
# Highest validation accuracy: 0.8780 at epoch 4
# 195/195 [==============================] - 146s 751ms/step - loss: 0.3227 - accuracy: 0.8987 - val_loss: 0.4406 - val_accuracy: 0.8780
# Epoch 5/50
# 195/195 [==============================] - ETA: 0s - loss: 0.2994 - accuracy: 0.9084
# Epoch 5: val_accuracy did not improve from 0.87805
# Total training time for epoch 5: 131.81 seconds
# Highest training accuracy: 0.9084 at epoch 5
# Highest validation accuracy: 0.8780 at epoch 4
# 195/195 [==============================] - 132s 676ms/step - loss: 0.2994 - accuracy: 0.9084 - val_loss: 0.4509 - val_accuracy: 0.8736
# Epoch 6/50
# 195/195 [==============================] - ETA: 0s - loss: 0.2834 - accuracy: 0.9100
# Epoch 6: val_accuracy did not improve from 0.87805
# Total training time for epoch 6: 146.10 seconds
# Highest training accuracy: 0.9100 at epoch 6
# Highest validation accuracy: 0.8780 at epoch 4
# 195/195 [==============================] - 146s 750ms/step - loss: 0.2834 - accuracy: 0.9100 - val_loss: 0.5211 - val_accuracy: 0.8549
# Epoch 7/50
# 195/195 [==============================] - ETA: 0s - loss: 0.2457 - accuracy: 0.9222
# Epoch 7: val_accuracy improved from 0.87805 to 0.87997, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/ResNet50V2_Combined_Final.h5
# Total training time for epoch 7: 131.77 seconds
# Highest training accuracy: 0.9222 at epoch 7
# Highest validation accuracy: 0.8800 at epoch 7
# 195/195 [==============================] - 132s 676ms/step - loss: 0.2457 - accuracy: 0.9222 - val_loss: 0.4732 - val_accuracy: 0.8800
# Epoch 8/50
# 195/195 [==============================] - ETA: 0s - loss: 0.2471 - accuracy: 0.9246
# Epoch 8: val_accuracy improved from 0.87997 to 0.89859, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/ResNet50V2_Combined_Final.h5
# Total training time for epoch 8: 132.93 seconds
# Highest training accuracy: 0.9246 at epoch 8
# Highest validation accuracy: 0.8986 at epoch 8
# 195/195 [==============================] - 133s 681ms/step - loss: 0.2471 - accuracy: 0.9246 - val_loss: 0.4044 - val_accuracy: 0.8986
# Epoch 9/50
# 195/195 [==============================] - ETA: 0s - loss: 0.2133 - accuracy: 0.9339
# Epoch 9: val_accuracy did not improve from 0.89859
# Total training time for epoch 9: 130.97 seconds
# Highest training accuracy: 0.9339 at epoch 9
# Highest validation accuracy: 0.8986 at epoch 8
# 195/195 [==============================] - 131s 672ms/step - loss: 0.2133 - accuracy: 0.9339 - val_loss: 0.4106 - val_accuracy: 0.8928
# Epoch 10/50
# 195/195 [==============================] - ETA: 0s - loss: 0.2204 - accuracy: 0.9352
# Epoch 10: val_accuracy did not improve from 0.89859
# Total training time for epoch 10: 130.09 seconds
# Highest training accuracy: 0.9352 at epoch 10
# Highest validation accuracy: 0.8986 at epoch 8
# 195/195 [==============================] - 130s 668ms/step - loss: 0.2204 - accuracy: 0.9352 - val_loss: 0.5056 - val_accuracy: 0.8761
# Epoch 11/50
# 195/195 [==============================] - ETA: 0s - loss: 0.2155 - accuracy: 0.9351
# Epoch 11: val_accuracy did not improve from 0.89859
# Total training time for epoch 11: 132.10 seconds
# Highest training accuracy: 0.9352 at epoch 10
# Highest validation accuracy: 0.8986 at epoch 8
# 195/195 [==============================] - 132s 678ms/step - loss: 0.2155 - accuracy: 0.9351 - val_loss: 0.4236 - val_accuracy: 0.8941
# Epoch 12/50
# 195/195 [==============================] - ETA: 0s - loss: 0.2119 - accuracy: 0.9346
# Epoch 12: val_accuracy did not improve from 0.89859
# Total training time for epoch 12: 132.98 seconds
# Highest training accuracy: 0.9352 at epoch 10
# Highest validation accuracy: 0.8986 at epoch 8
# 195/195 [==============================] - 133s 682ms/step - loss: 0.2119 - accuracy: 0.9346 - val_loss: 0.5099 - val_accuracy: 0.8825
# Epoch 13/50
# 195/195 [==============================] - ETA: 0s - loss: 0.1766 - accuracy: 0.9450
# Epoch 13: val_accuracy did not improve from 0.89859
# Total training time for epoch 13: 130.07 seconds
# Highest training accuracy: 0.9450 at epoch 13
# Highest validation accuracy: 0.8986 at epoch 8
# 195/195 [==============================] - 130s 668ms/step - loss: 0.1766 - accuracy: 0.9450 - val_loss: 0.4397 - val_accuracy: 0.8979
# Epoch 14/50
# 195/195 [==============================] - ETA: 0s - loss: 0.1868 - accuracy: 0.9415
# Epoch 14: val_accuracy did not improve from 0.89859
# Total training time for epoch 14: 132.08 seconds
# Highest training accuracy: 0.9450 at epoch 13
# Highest validation accuracy: 0.8986 at epoch 8
# 195/195 [==============================] - 132s 678ms/step - loss: 0.1868 - accuracy: 0.9415 - val_loss: 0.4713 - val_accuracy: 0.8838
# Epoch 15/50
# 195/195 [==============================] - ETA: 0s - loss: 0.1685 - accuracy: 0.9471
# Epoch 15: val_accuracy did not improve from 0.89859
# Total training time for epoch 15: 129.62 seconds
# Highest training accuracy: 0.9471 at epoch 15
# Highest validation accuracy: 0.8986 at epoch 8
# 195/195 [==============================] - 130s 665ms/step - loss: 0.1685 - accuracy: 0.9471 - val_loss: 0.5631 - val_accuracy: 0.8896
# Epoch 16/50
# 195/195 [==============================] - ETA: 0s - loss: 0.1688 - accuracy: 0.9484
# Epoch 16: val_accuracy did not improve from 0.89859
# Total training time for epoch 16: 130.94 seconds
# Highest training accuracy: 0.9484 at epoch 16
# Highest validation accuracy: 0.8986 at epoch 8
# 195/195 [==============================] - 131s 672ms/step - loss: 0.1688 - accuracy: 0.9484 - val_loss: 0.4887 - val_accuracy: 0.8870
# Epoch 17/50
# 195/195 [==============================] - ETA: 0s - loss: 0.1582 - accuracy: 0.9487
# Epoch 17: val_accuracy did not improve from 0.89859
# Total training time for epoch 17: 129.75 seconds
# Highest training accuracy: 0.9487 at epoch 17
# Highest validation accuracy: 0.8986 at epoch 8
# 195/195 [==============================] - 130s 666ms/step - loss: 0.1582 - accuracy: 0.9487 - val_loss: 0.4101 - val_accuracy: 0.8967
# Epoch 18/50
# 195/195 [==============================] - ETA: 0s - loss: 0.1737 - accuracy: 0.9469
# Epoch 18: val_accuracy did not improve from 0.89859
# Total training time for epoch 18: 132.54 seconds
# Highest training accuracy: 0.9487 at epoch 17
# Highest validation accuracy: 0.8986 at epoch 8
# 195/195 [==============================] - 133s 680ms/step - loss: 0.1737 - accuracy: 0.9469 - val_loss: 0.4388 - val_accuracy: 0.8954
# Epoch 19/50
# 195/195 [==============================] - ETA: 0s - loss: 0.1780 - accuracy: 0.9482
# Epoch 19: val_accuracy did not improve from 0.89859
# Total training time for epoch 19: 128.89 seconds
# Highest training accuracy: 0.9487 at epoch 17
# Highest validation accuracy: 0.8986 at epoch 8
# 195/195 [==============================] - 129s 662ms/step - loss: 0.1780 - accuracy: 0.9482 - val_loss: 0.5413 - val_accuracy: 0.8922
# Epoch 20/50
# 195/195 [==============================] - ETA: 0s - loss: 0.1681 - accuracy: 0.9504
# Epoch 20: val_accuracy improved from 0.89859 to 0.90372, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/ResNet50V2_Combined_Final.h5
# Total training time for epoch 20: 132.19 seconds
# Highest training accuracy: 0.9504 at epoch 20
# Highest validation accuracy: 0.9037 at epoch 20
# 195/195 [==============================] - 132s 677ms/step - loss: 0.1681 - accuracy: 0.9504 - val_loss: 0.4038 - val_accuracy: 0.9037
# Epoch 21/50
# 195/195 [==============================] - ETA: 0s - loss: 0.1834 - accuracy: 0.9464
# Epoch 21: val_accuracy did not improve from 0.90372
# Total training time for epoch 21: 146.64 seconds
# Highest training accuracy: 0.9504 at epoch 20
# Highest validation accuracy: 0.9037 at epoch 20
# 195/195 [==============================] - 147s 753ms/step - loss: 0.1834 - accuracy: 0.9464 - val_loss: 0.5943 - val_accuracy: 0.8883
# Epoch 22/50
# 195/195 [==============================] - ETA: 0s - loss: 0.1432 - accuracy: 0.9554
# Epoch 22: val_accuracy did not improve from 0.90372
# Total training time for epoch 22: 131.41 seconds
# Highest training accuracy: 0.9554 at epoch 22
# Highest validation accuracy: 0.9037 at epoch 20
# 195/195 [==============================] - 131s 674ms/step - loss: 0.1432 - accuracy: 0.9554 - val_loss: 0.4615 - val_accuracy: 0.9005
# Epoch 23/50
# 195/195 [==============================] - ETA: 0s - loss: 0.1660 - accuracy: 0.9554
# Epoch 23: val_accuracy improved from 0.90372 to 0.90501, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/ResNet50V2_Combined_Final.h5
# Total training time for epoch 23: 134.91 seconds
# Highest training accuracy: 0.9554 at epoch 22
# Highest validation accuracy: 0.9050 at epoch 23
# 195/195 [==============================] - 135s 692ms/step - loss: 0.1660 - accuracy: 0.9554 - val_loss: 0.4748 - val_accuracy: 0.9050
# Epoch 24/50
# 195/195 [==============================] - ETA: 0s - loss: 0.1344 - accuracy: 0.9630
# Epoch 24: val_accuracy improved from 0.90501 to 0.90629, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/ResNet50V2_Combined_Final.h5
# Total training time for epoch 24: 150.03 seconds
# Highest training accuracy: 0.9630 at epoch 24
# Highest validation accuracy: 0.9063 at epoch 24
# 195/195 [==============================] - 150s 770ms/step - loss: 0.1344 - accuracy: 0.9630 - val_loss: 0.4891 - val_accuracy: 0.9063
# Epoch 25/50
# 195/195 [==============================] - ETA: 0s - loss: 0.1598 - accuracy: 0.9553
# Epoch 25: val_accuracy improved from 0.90629 to 0.91078, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/ResNet50V2_Combined_Final.h5
# Total training time for epoch 25: 133.06 seconds
# Highest training accuracy: 0.9630 at epoch 24
# Highest validation accuracy: 0.9108 at epoch 25
# 195/195 [==============================] - 133s 683ms/step - loss: 0.1598 - accuracy: 0.9553 - val_loss: 0.3700 - val_accuracy: 0.9108
# Epoch 26/50
# 195/195 [==============================] - ETA: 0s - loss: 0.1745 - accuracy: 0.9567
# Epoch 26: val_accuracy did not improve from 0.91078
# Total training time for epoch 26: 133.14 seconds
# Highest training accuracy: 0.9630 at epoch 24
# Highest validation accuracy: 0.9108 at epoch 25
# 195/195 [==============================] - 133s 683ms/step - loss: 0.1745 - accuracy: 0.9567 - val_loss: 0.4700 - val_accuracy: 0.9018
# Epoch 27/50
# 195/195 [==============================] - ETA: 0s - loss: 0.1542 - accuracy: 0.9604
# Epoch 27: val_accuracy improved from 0.91078 to 0.91592, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/ResNet50V2_Combined_Final.h5
# Total training time for epoch 27: 132.69 seconds
# Highest training accuracy: 0.9630 at epoch 24
# Highest validation accuracy: 0.9159 at epoch 27
# 195/195 [==============================] - 133s 681ms/step - loss: 0.1542 - accuracy: 0.9604 - val_loss: 0.4362 - val_accuracy: 0.9159
# Epoch 28/50
# 195/195 [==============================] - ETA: 0s - loss: 0.1456 - accuracy: 0.9607
# Epoch 28: val_accuracy did not improve from 0.91592
# Total training time for epoch 28: 130.27 seconds
# Highest training accuracy: 0.9630 at epoch 24
# Highest validation accuracy: 0.9159 at epoch 27
# 195/195 [==============================] - 130s 668ms/step - loss: 0.1456 - accuracy: 0.9607 - val_loss: 0.5370 - val_accuracy: 0.8960
# Epoch 29/50
# 195/195 [==============================] - ETA: 0s - loss: 0.1673 - accuracy: 0.9573
# Epoch 29: val_accuracy did not improve from 0.91592
# Total training time for epoch 29: 134.20 seconds
# Highest training accuracy: 0.9630 at epoch 24
# Highest validation accuracy: 0.9159 at epoch 27
# 195/195 [==============================] - 134s 689ms/step - loss: 0.1673 - accuracy: 0.9573 - val_loss: 0.4346 - val_accuracy: 0.9121
# Epoch 30/50
# 195/195 [==============================] - ETA: 0s - loss: 0.1358 - accuracy: 0.9617
# Epoch 30: val_accuracy improved from 0.91592 to 0.91720, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/ResNet50V2_Combined_Final.h5
# Total training time for epoch 30: 131.57 seconds
# Highest training accuracy: 0.9630 at epoch 24
# Highest validation accuracy: 0.9172 at epoch 30
# 195/195 [==============================] - 132s 675ms/step - loss: 0.1358 - accuracy: 0.9617 - val_loss: 0.4119 - val_accuracy: 0.9172
# Epoch 31/50
# 195/195 [==============================] - ETA: 0s - loss: 0.1608 - accuracy: 0.9551
# Epoch 31: val_accuracy did not improve from 0.91720
# Total training time for epoch 31: 133.79 seconds
# Highest training accuracy: 0.9630 at epoch 24
# Highest validation accuracy: 0.9172 at epoch 30
# 195/195 [==============================] - 134s 685ms/step - loss: 0.1608 - accuracy: 0.9551 - val_loss: 0.5100 - val_accuracy: 0.8915
# Epoch 32/50
# 195/195 [==============================] - ETA: 0s - loss: 0.1205 - accuracy: 0.9647
# Epoch 32: val_accuracy did not improve from 0.91720
# Total training time for epoch 32: 130.17 seconds
# Highest training accuracy: 0.9647 at epoch 32
# Highest validation accuracy: 0.9172 at epoch 30
# 195/195 [==============================] - 130s 668ms/step - loss: 0.1205 - accuracy: 0.9647 - val_loss: 0.4815 - val_accuracy: 0.9056
# Epoch 33/50
# 195/195 [==============================] - ETA: 0s - loss: 0.1153 - accuracy: 0.9671
# Epoch 33: val_accuracy did not improve from 0.91720
# Total training time for epoch 33: 132.32 seconds
# Highest training accuracy: 0.9671 at epoch 33
# Highest validation accuracy: 0.9172 at epoch 30
# 195/195 [==============================] - 132s 679ms/step - loss: 0.1153 - accuracy: 0.9671 - val_loss: 0.5145 - val_accuracy: 0.9114
# Epoch 34/50
# 195/195 [==============================] - ETA: 0s - loss: 0.1278 - accuracy: 0.9633
# Epoch 34: val_accuracy did not improve from 0.91720
# Total training time for epoch 34: 145.03 seconds
# Highest training accuracy: 0.9671 at epoch 33
# Highest validation accuracy: 0.9172 at epoch 30
# 195/195 [==============================] - 145s 745ms/step - loss: 0.1278 - accuracy: 0.9633 - val_loss: 0.4461 - val_accuracy: 0.9134
# Epoch 35/50
# 195/195 [==============================] - ETA: 0s - loss: 0.1443 - accuracy: 0.9593
# Epoch 35: val_accuracy did not improve from 0.91720
# Total training time for epoch 35: 131.35 seconds
# Highest training accuracy: 0.9671 at epoch 33
# Highest validation accuracy: 0.9172 at epoch 30
# 195/195 [==============================] - 131s 674ms/step - loss: 0.1443 - accuracy: 0.9593 - val_loss: 0.5219 - val_accuracy: 0.8915
# Epoch 36/50
# 195/195 [==============================] - ETA: 0s - loss: 0.1356 - accuracy: 0.9631
# Epoch 36: val_accuracy improved from 0.91720 to 0.92298, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/ResNet50V2_Combined_Final.h5
# Total training time for epoch 36: 132.98 seconds
# Highest training accuracy: 0.9671 at epoch 33
# Highest validation accuracy: 0.9230 at epoch 36
# 195/195 [==============================] - 133s 683ms/step - loss: 0.1356 - accuracy: 0.9631 - val_loss: 0.4032 - val_accuracy: 0.9230
# Epoch 37/50
# 195/195 [==============================] - ETA: 0s - loss: 0.1132 - accuracy: 0.9684
# Epoch 37: val_accuracy did not improve from 0.92298
# Total training time for epoch 37: 130.45 seconds
# Highest training accuracy: 0.9684 at epoch 37
# Highest validation accuracy: 0.9230 at epoch 36
# 195/195 [==============================] - 130s 669ms/step - loss: 0.1132 - accuracy: 0.9684 - val_loss: 0.5427 - val_accuracy: 0.9108
# Epoch 38/50
# 195/195 [==============================] - ETA: 0s - loss: 0.1253 - accuracy: 0.9684
# Epoch 38: val_accuracy did not improve from 0.92298
# Total training time for epoch 38: 133.44 seconds
# Highest training accuracy: 0.9684 at epoch 37
# Highest validation accuracy: 0.9230 at epoch 36
# 195/195 [==============================] - 133s 684ms/step - loss: 0.1253 - accuracy: 0.9684 - val_loss: 0.4910 - val_accuracy: 0.9082
# Epoch 39/50
# 195/195 [==============================] - ETA: 0s - loss: 0.1281 - accuracy: 0.9671
# Epoch 39: val_accuracy did not improve from 0.92298
# Total training time for epoch 39: 131.21 seconds
# Highest training accuracy: 0.9684 at epoch 37
# Highest validation accuracy: 0.9230 at epoch 36
# 195/195 [==============================] - 131s 673ms/step - loss: 0.1281 - accuracy: 0.9671 - val_loss: 0.6140 - val_accuracy: 0.8986
# Epoch 40/50
# 195/195 [==============================] - ETA: 0s - loss: 0.1293 - accuracy: 0.9658
# Epoch 40: val_accuracy did not improve from 0.92298
# Total training time for epoch 40: 131.48 seconds
# Highest training accuracy: 0.9684 at epoch 37
# Highest validation accuracy: 0.9230 at epoch 36
# 195/195 [==============================] - 131s 675ms/step - loss: 0.1293 - accuracy: 0.9658 - val_loss: 0.5668 - val_accuracy: 0.9031
# Epoch 41/50
# 195/195 [==============================] - ETA: 0s - loss: 0.1174 - accuracy: 0.9684
# Epoch 41: val_accuracy did not improve from 0.92298
# Total training time for epoch 41: 131.03 seconds
# Highest training accuracy: 0.9684 at epoch 37
# Highest validation accuracy: 0.9230 at epoch 36
# 195/195 [==============================] - 131s 673ms/step - loss: 0.1174 - accuracy: 0.9684 - val_loss: 0.5898 - val_accuracy: 0.8960
# Epoch 42/50
# 195/195 [==============================] - ETA: 0s - loss: 0.1325 - accuracy: 0.9650
# Epoch 42: val_accuracy did not improve from 0.92298
# Total training time for epoch 42: 132.69 seconds
# Highest training accuracy: 0.9684 at epoch 37
# Highest validation accuracy: 0.9230 at epoch 36
# 195/195 [==============================] - 133s 681ms/step - loss: 0.1325 - accuracy: 0.9650 - val_loss: 0.5025 - val_accuracy: 0.9159
# Epoch 43/50
# 195/195 [==============================] - ETA: 0s - loss: 0.1071 - accuracy: 0.9679
# Epoch 43: val_accuracy did not improve from 0.92298
# Total training time for epoch 43: 131.27 seconds
# Highest training accuracy: 0.9684 at epoch 37
# Highest validation accuracy: 0.9230 at epoch 36
# 195/195 [==============================] - 131s 674ms/step - loss: 0.1071 - accuracy: 0.9679 - val_loss: 0.6651 - val_accuracy: 0.9121
# Epoch 44/50
# 195/195 [==============================] - ETA: 0s - loss: 0.1226 - accuracy: 0.9694
# Epoch 44: val_accuracy did not improve from 0.92298
# Total training time for epoch 44: 130.51 seconds
# Highest training accuracy: 0.9694 at epoch 44
# Highest validation accuracy: 0.9230 at epoch 36
# 195/195 [==============================] - 131s 670ms/step - loss: 0.1226 - accuracy: 0.9694 - val_loss: 0.6776 - val_accuracy: 0.8941
# Epoch 45/50
# 195/195 [==============================] - ETA: 0s - loss: 0.1222 - accuracy: 0.9666
# Epoch 45: val_accuracy did not improve from 0.92298
# Total training time for epoch 45: 134.39 seconds
# Highest training accuracy: 0.9694 at epoch 44
# Highest validation accuracy: 0.9230 at epoch 36
# 195/195 [==============================] - 134s 690ms/step - loss: 0.1222 - accuracy: 0.9666 - val_loss: 0.4784 - val_accuracy: 0.9095
# Epoch 46/50
# 195/195 [==============================] - ETA: 0s - loss: 0.1297 - accuracy: 0.9660
# Epoch 46: val_accuracy improved from 0.92298 to 0.92490, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/ResNet50V2_Combined_Final.h5
# Total training time for epoch 46: 133.59 seconds
# Highest training accuracy: 0.9694 at epoch 44
# Highest validation accuracy: 0.9249 at epoch 46
# 195/195 [==============================] - 134s 686ms/step - loss: 0.1297 - accuracy: 0.9660 - val_loss: 0.4410 - val_accuracy: 0.9249
# Epoch 47/50
# 195/195 [==============================] - ETA: 0s - loss: 0.1111 - accuracy: 0.9718
# Epoch 47: val_accuracy did not improve from 0.92490
# Total training time for epoch 47: 135.49 seconds
# Highest training accuracy: 0.9718 at epoch 47
# Highest validation accuracy: 0.9249 at epoch 46
# 195/195 [==============================] - 135s 694ms/step - loss: 0.1111 - accuracy: 0.9718 - val_loss: 0.7887 - val_accuracy: 0.8845
# Epoch 48/50
# 195/195 [==============================] - ETA: 0s - loss: 0.1525 - accuracy: 0.9606
# Epoch 48: val_accuracy did not improve from 0.92490
# Total training time for epoch 48: 135.90 seconds
# Highest training accuracy: 0.9718 at epoch 47
# Highest validation accuracy: 0.9249 at epoch 46
# 195/195 [==============================] - 136s 697ms/step - loss: 0.1525 - accuracy: 0.9606 - val_loss: 0.5957 - val_accuracy: 0.8960
# Epoch 49/50
# 195/195 [==============================] - ETA: 0s - loss: 0.0874 - accuracy: 0.9743
# Epoch 49: val_accuracy did not improve from 0.92490
# Total training time for epoch 49: 148.06 seconds
# Highest training accuracy: 0.9743 at epoch 49
# Highest validation accuracy: 0.9249 at epoch 46
# 195/195 [==============================] - 148s 760ms/step - loss: 0.0874 - accuracy: 0.9743 - val_loss: 0.5206 - val_accuracy: 0.9236
# Epoch 50/50
# 195/195 [==============================] - ETA: 0s - loss: 0.1357 - accuracy: 0.9666
# Epoch 50: val_accuracy did not improve from 0.92490
# Total training time for epoch 50: 131.17 seconds
# Highest training accuracy: 0.9743 at epoch 49
# Highest validation accuracy: 0.9249 at epoch 46
# 195/195 [==============================] - 131s 673ms/step - loss: 0.1357 - accuracy: 0.9666 - val_loss: 0.5521 - val_accuracy: 0.9095
# Total training time for 50 epochs: 6726.97 seconds

# %% [markdown]
# ### Plot the training and validation accuracy

# %%
fig, ax = plt.subplots(figsize=(14,7))
ax.plot(history.history['accuracy'])
ax.plot(history.history['val_accuracy'])
ax.set_title('Model Accuracy')
ax.set_xlabel('Epoch')
ax.set_ylabel('Accuracy')
ax.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### Plot the Training and Validation Loss

# %%
fig, ax = plt.subplots(figsize=(14,7))
ax.plot(history.history['loss'])
ax.plot(history.history['val_loss'])
ax.set_title('Model Loss')
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')
ax.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### Test the model on the test data

# %%
test_loss, test_acc = model.evaluate(test_generator, steps=len(test_generator))
print("Test accuracy:", test_acc)
# Out:
# 53/53 [==============================] - 13s 247ms/step - loss: 0.8764 - accuracy: 0.9284
# Test accuracy: 0.9283581972122192

# %% [markdown]
# ### Generate predictions on the test data

# %%
y_pred = model.predict(test_generator, steps=len(test_generator))
y_true = test_generator.classes
# Out:
# 53/53 [==============================] - 13s 236ms/step

# %% [markdown]
# ### Generate and plot confusion matrix

# %%
cm = confusion_matrix(y_true, np.argmax(y_pred, axis=1))
plt.figure(figsize=(8, 8))
sns.heatmap(cm, annot=True, cmap="Blues", square=True, xticklabels=test_generator.class_indices.keys(),
            yticklabels=test_generator.class_indices.keys(), fmt='g')
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.show()

# %% [markdown]
# ### Print classification report

# %%
class_names = list(test_generator.class_indices.keys())
print(classification_report(y_true, np.argmax(y_pred, axis=1), target_names=class_names))
# Out:
#                   precision    recall  f1-score   support
#
#     glioma_tumor       0.97      0.79      0.87       399
# meningioma_tumor       0.85      0.95      0.90       416
#         no_tumor       0.96      0.99      0.98       486
#  pituitary_tumor       0.95      0.97      0.96       374
#
#         accuracy                           0.93      1675
#        macro avg       0.93      0.93      0.93      1675
#     weighted avg       0.93      0.93      0.93      1675

# %% [markdown]
# ###Compute precision, recall, F1 score and support for each class

# %%
precision, recall, f1_score, support = precision_recall_fscore_support(y_true, np.argmax(y_pred, axis=1))

# %%
# Create a dataframe with the computed metrics for each class
metrics_df = pd.DataFrame({
    'Precision': precision,
    'Recall': recall,
    'F1 Score': f1_score,
    'Support': support
}, index=class_names)

# Print the dataframe
print(metrics_df)
# Out:
#                   Precision    Recall  F1 Score  Support
# glioma_tumor       0.966154  0.786967  0.867403      399
# meningioma_tumor   0.853763  0.954327  0.901249      416
# no_tumor           0.960159  0.991770  0.975709      486
# pituitary_tumor    0.945170  0.967914  0.956407      374

# %% [markdown]
# ### Compute ROC and AUC for each class

# %%
fpr = {}
tpr = {}
roc_auc = {}

# Compute ROC and AUC for each class
for i in range(train_generator.num_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true == i, y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# %% [markdown]
# ### Plot ROC curve for each class

# %%
plt.figure(figsize=(8, 6))
for i in range(train_generator.num_classes):
    plt.plot(fpr[i], tpr[i], label='%s (AUC = %0.2f)' % (class_names[i], roc_auc[i]))
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic Curve')
plt.legend(loc="lower right")
plt.show()
