# %% [markdown]
# # VGG-19 Model

# %% [markdown]
# ### Import required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix, precision_recall_fscore_support, roc_curve, auc
import tensorflow as tf
from tensorflow.keras.utils import plot_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.applications.vgg19 import preprocess_input
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg19 import VGG19

# %% [markdown]
# ### Define constants

# %%
TRAIN_PATH = "/content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/Training"
TEST_PATH = "/content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/Testing"
IMAGE_SIZE = [224, 224]
BATCH_SIZE = 32
NUM_EPOCHS = 50

# %% [markdown]
# ### Create data generators for training and validation with advanced data augmentation

# %%
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    validation_split=0.2
)

test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_generator = train_datagen.flow_from_directory(
    TRAIN_PATH,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training'
)

validation_generator = train_datagen.flow_from_directory(
    TRAIN_PATH,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation'
)

test_generator = test_datagen.flow_from_directory(
    TEST_PATH,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 4405 images belonging to 4 classes.
# Found 1100 images belonging to 4 classes.
# Found 1281 images belonging to 4 classes.

# %% [markdown]
# ### Load the pre-trained VGG19 model without top layers

# %%
base_model = VGG19(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 0s 0us/step

# %% [markdown]
# ### Add new fully connected layers on top of the base model

# %%
x = Flatten()(base_model.output)
prediction = Dense(train_generator.num_classes, activation='softmax')(x)

# %% [markdown]
# ### Create the model

# %%
model = Model(inputs=base_model.input, outputs=prediction)

# %% [markdown]
# ### Freeze the pre-trained layers in the base model and train only the new layers

# %%
for layer in base_model.layers:
    layer.trainable = False

# %% [markdown]
# Freeze all layers in the pre-trained model except the last two

# %%
#for layer in base_model.layers[:-2]:
 #   layer.trainable = False

# %% [markdown]
# ### Model Summary

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 4)                 100356
#
# =================================================================
# Total params: 20,124,740
# Trainable params: 100,356
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %% [markdown]
# ### Visualize the model architecture

# %%
plot_model(model=model, show_shapes=True)

# %% [markdown]
# ### Implement Early Stopping to prevent overfitting

# %%
#early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, mode='min', restore_best_weights=True)

# %% [markdown]
# ### Compile the model with categorical cross-entropy loss and a lower learning rate

# %%
model.compile(
    loss='categorical_crossentropy',
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    metrics=['accuracy'])

# %% [markdown]
# ### Save the Model

# %%
checkpoint = ModelCheckpoint('/content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/VGG_19_Final.h5', 
                              monitor='val_accuracy', 
                              save_best_only=True, 
                              mode='max', 
                              verbose=1)

# %% [markdown]
# ### Train the model on training data and evaluate on validation data

# %%
history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=NUM_EPOCHS,
    steps_per_epoch=len(train_generator),
    validation_steps=len(validation_generator),
    callbacks=[checkpoint])
# Out:
# Epoch 1/50
# 138/138 [==============================] - ETA: 0s - loss: 1.9323 - accuracy: 0.6558
# Epoch 1: val_accuracy improved from -inf to 0.63091, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/VGG_19_Final.h5
# 138/138 [==============================] - 1162s 8s/step - loss: 1.9323 - accuracy: 0.6558 - val_loss: 2.5749 - val_accuracy: 0.6309
# Epoch 2/50
# 138/138 [==============================] - ETA: 0s - loss: 1.0798 - accuracy: 0.7714
# Epoch 2: val_accuracy improved from 0.63091 to 0.67636, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/VGG_19_Final.h5
# 138/138 [==============================] - 108s 779ms/step - loss: 1.0798 - accuracy: 0.7714 - val_loss: 2.3669 - val_accuracy: 0.6764
# Epoch 3/50
# 138/138 [==============================] - ETA: 0s - loss: 0.8292 - accuracy: 0.8154
# Epoch 3: val_accuracy improved from 0.67636 to 0.70000, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/VGG_19_Final.h5
# 138/138 [==============================] - 106s 770ms/step - loss: 0.8292 - accuracy: 0.8154 - val_loss: 1.9878 - val_accuracy: 0.7000
# Epoch 4/50
# 138/138 [==============================] - ETA: 0s - loss: 0.6490 - accuracy: 0.8395
# Epoch 4: val_accuracy improved from 0.70000 to 0.70909, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/VGG_19_Final.h5
# 138/138 [==============================] - 103s 747ms/step - loss: 0.6490 - accuracy: 0.8395 - val_loss: 2.0723 - val_accuracy: 0.7091
# Epoch 5/50
# 138/138 [==============================] - ETA: 0s - loss: 0.6275 - accuracy: 0.8502
# Epoch 5: val_accuracy did not improve from 0.70909
# 138/138 [==============================] - 104s 755ms/step - loss: 0.6275 - accuracy: 0.8502 - val_loss: 2.0949 - val_accuracy: 0.6964
# Epoch 6/50
# 138/138 [==============================] - ETA: 0s - loss: 0.5413 - accuracy: 0.8647
# Epoch 6: val_accuracy improved from 0.70909 to 0.72273, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/VGG_19_Final.h5
# 138/138 [==============================] - 105s 759ms/step - loss: 0.5413 - accuracy: 0.8647 - val_loss: 1.7784 - val_accuracy: 0.7227
# Epoch 7/50
# 138/138 [==============================] - ETA: 0s - loss: 0.4868 - accuracy: 0.8717
# Epoch 7: val_accuracy improved from 0.72273 to 0.75455, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/VGG_19_Final.h5
# 138/138 [==============================] - 104s 754ms/step - loss: 0.4868 - accuracy: 0.8717 - val_loss: 1.8266 - val_accuracy: 0.7545
# Epoch 8/50
# 138/138 [==============================] - ETA: 0s - loss: 0.4377 - accuracy: 0.8865
# Epoch 8: val_accuracy did not improve from 0.75455
# 138/138 [==============================] - 103s 749ms/step - loss: 0.4377 - accuracy: 0.8865 - val_loss: 1.7520 - val_accuracy: 0.7382
# Epoch 9/50
# 138/138 [==============================] - ETA: 0s - loss: 0.4323 - accuracy: 0.8867
# Epoch 9: val_accuracy did not improve from 0.75455
# 138/138 [==============================] - 102s 738ms/step - loss: 0.4323 - accuracy: 0.8867 - val_loss: 1.9805 - val_accuracy: 0.7164
# Epoch 10/50
# 138/138 [==============================] - ETA: 0s - loss: 0.4205 - accuracy: 0.8926
# Epoch 10: val_accuracy improved from 0.75455 to 0.76000, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/VGG_19_Final.h5
# 138/138 [==============================] - 124s 899ms/step - loss: 0.4205 - accuracy: 0.8926 - val_loss: 1.7115 - val_accuracy: 0.7600
# Epoch 11/50
# 138/138 [==============================] - ETA: 0s - loss: 0.3833 - accuracy: 0.8985
# Epoch 11: val_accuracy did not improve from 0.76000
# 138/138 [==============================] - 103s 747ms/step - loss: 0.3833 - accuracy: 0.8985 - val_loss: 1.6517 - val_accuracy: 0.7545
# Epoch 12/50
# 138/138 [==============================] - ETA: 0s - loss: 0.3266 - accuracy: 0.9083
# Epoch 12: val_accuracy did not improve from 0.76000
# 138/138 [==============================] - 103s 745ms/step - loss: 0.3266 - accuracy: 0.9083 - val_loss: 1.5817 - val_accuracy: 0.7527
# Epoch 13/50
# 138/138 [==============================] - ETA: 0s - loss: 0.3179 - accuracy: 0.9121
# Epoch 13: val_accuracy did not improve from 0.76000
# 138/138 [==============================] - 104s 757ms/step - loss: 0.3179 - accuracy: 0.9121 - val_loss: 1.8583 - val_accuracy: 0.7536
# Epoch 14/50
# 138/138 [==============================] - ETA: 0s - loss: 0.2929 - accuracy: 0.9133
# Epoch 14: val_accuracy did not improve from 0.76000
# 138/138 [==============================] - 101s 735ms/step - loss: 0.2929 - accuracy: 0.9133 - val_loss: 1.9218 - val_accuracy: 0.7282
# Epoch 15/50
# 138/138 [==============================] - ETA: 0s - loss: 0.2902 - accuracy: 0.9142
# Epoch 15: val_accuracy did not improve from 0.76000
# 138/138 [==============================] - 103s 745ms/step - loss: 0.2902 - accuracy: 0.9142 - val_loss: 1.8386 - val_accuracy: 0.7600
# Epoch 16/50
# 138/138 [==============================] - ETA: 0s - loss: 0.2687 - accuracy: 0.9249
# Epoch 16: val_accuracy improved from 0.76000 to 0.76455, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/VGG_19_Final.h5
# 138/138 [==============================] - 105s 761ms/step - loss: 0.2687 - accuracy: 0.9249 - val_loss: 1.8217 - val_accuracy: 0.7645
# Epoch 17/50
# 138/138 [==============================] - ETA: 0s - loss: 0.2761 - accuracy: 0.9203
# Epoch 17: val_accuracy did not improve from 0.76455
# 138/138 [==============================] - 102s 735ms/step - loss: 0.2761 - accuracy: 0.9203 - val_loss: 1.8001 - val_accuracy: 0.7445
# Epoch 18/50
# 138/138 [==============================] - ETA: 0s - loss: 0.2572 - accuracy: 0.9237
# Epoch 18: val_accuracy did not improve from 0.76455
# 138/138 [==============================] - 102s 741ms/step - loss: 0.2572 - accuracy: 0.9237 - val_loss: 1.7698 - val_accuracy: 0.7645
# Epoch 19/50
# 138/138 [==============================] - ETA: 0s - loss: 0.2485 - accuracy: 0.9276
# Epoch 19: val_accuracy did not improve from 0.76455
# 138/138 [==============================] - 102s 738ms/step - loss: 0.2485 - accuracy: 0.9276 - val_loss: 2.1771 - val_accuracy: 0.7464
# Epoch 20/50
# 138/138 [==============================] - ETA: 0s - loss: 0.2447 - accuracy: 0.9283
# Epoch 20: val_accuracy improved from 0.76455 to 0.76818, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/VGG_19_Final.h5
# 138/138 [==============================] - 103s 746ms/step - loss: 0.2447 - accuracy: 0.9283 - val_loss: 1.6125 - val_accuracy: 0.7682
# Epoch 21/50
# 138/138 [==============================] - ETA: 0s - loss: 0.2576 - accuracy: 0.9276
# Epoch 21: val_accuracy did not improve from 0.76818
# 138/138 [==============================] - 106s 765ms/step - loss: 0.2576 - accuracy: 0.9276 - val_loss: 1.7300 - val_accuracy: 0.7609
# Epoch 22/50
# 138/138 [==============================] - ETA: 0s - loss: 0.2409 - accuracy: 0.9308
# Epoch 22: val_accuracy did not improve from 0.76818
# 138/138 [==============================] - 106s 766ms/step - loss: 0.2409 - accuracy: 0.9308 - val_loss: 1.6951 - val_accuracy: 0.7618
# Epoch 23/50
# 138/138 [==============================] - ETA: 0s - loss: 0.2227 - accuracy: 0.9371
# Epoch 23: val_accuracy did not improve from 0.76818
# 138/138 [==============================] - 126s 912ms/step - loss: 0.2227 - accuracy: 0.9371 - val_loss: 2.0831 - val_accuracy: 0.7645
# Epoch 24/50
# 138/138 [==============================] - ETA: 0s - loss: 0.2322 - accuracy: 0.9337
# Epoch 24: val_accuracy did not improve from 0.76818
# 138/138 [==============================] - 106s 766ms/step - loss: 0.2322 - accuracy: 0.9337 - val_loss: 1.9137 - val_accuracy: 0.7600
# Epoch 25/50
# 138/138 [==============================] - ETA: 0s - loss: 0.2158 - accuracy: 0.9369
# Epoch 25: val_accuracy did not improve from 0.76818
# 138/138 [==============================] - 127s 921ms/step - loss: 0.2158 - accuracy: 0.9369 - val_loss: 1.9087 - val_accuracy: 0.7609
# Epoch 26/50
# 138/138 [==============================] - ETA: 0s - loss: 0.2225 - accuracy: 0.9294
# Epoch 26: val_accuracy improved from 0.76818 to 0.77000, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/VGG_19_Final.h5
# 138/138 [==============================] - 104s 752ms/step - loss: 0.2225 - accuracy: 0.9294 - val_loss: 2.0208 - val_accuracy: 0.7700
# Epoch 27/50
# 138/138 [==============================] - ETA: 0s - loss: 0.2366 - accuracy: 0.9346
# Epoch 27: val_accuracy improved from 0.77000 to 0.77455, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/VGG_19_Final.h5
# 138/138 [==============================] - 102s 740ms/step - loss: 0.2366 - accuracy: 0.9346 - val_loss: 1.9026 - val_accuracy: 0.7745
# Epoch 28/50
# 138/138 [==============================] - ETA: 0s - loss: 0.2022 - accuracy: 0.9369
# Epoch 28: val_accuracy did not improve from 0.77455
# 138/138 [==============================] - 102s 736ms/step - loss: 0.2022 - accuracy: 0.9369 - val_loss: 2.1607 - val_accuracy: 0.7573
# Epoch 29/50
# 138/138 [==============================] - ETA: 0s - loss: 0.1947 - accuracy: 0.9419
# Epoch 29: val_accuracy did not improve from 0.77455
# 138/138 [==============================] - 100s 727ms/step - loss: 0.1947 - accuracy: 0.9419 - val_loss: 1.9987 - val_accuracy: 0.7745
# Epoch 30/50
# 138/138 [==============================] - ETA: 0s - loss: 0.1917 - accuracy: 0.9403
# Epoch 30: val_accuracy improved from 0.77455 to 0.78000, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/VGG_19_Final.h5
# 138/138 [==============================] - 102s 741ms/step - loss: 0.1917 - accuracy: 0.9403 - val_loss: 1.8024 - val_accuracy: 0.7800
# Epoch 31/50
# 138/138 [==============================] - ETA: 0s - loss: 0.1982 - accuracy: 0.9432
# Epoch 31: val_accuracy did not improve from 0.78000
# 138/138 [==============================] - 101s 733ms/step - loss: 0.1982 - accuracy: 0.9432 - val_loss: 1.9466 - val_accuracy: 0.7727
# Epoch 32/50
# 138/138 [==============================] - ETA: 0s - loss: 0.1897 - accuracy: 0.9419
# Epoch 32: val_accuracy did not improve from 0.78000
# 138/138 [==============================] - 100s 727ms/step - loss: 0.1897 - accuracy: 0.9419 - val_loss: 2.0055 - val_accuracy: 0.7800
# Epoch 33/50
# 138/138 [==============================] - ETA: 0s - loss: 0.1820 - accuracy: 0.9439
# Epoch 33: val_accuracy improved from 0.78000 to 0.79364, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/VGG_19_Final.h5
# 138/138 [==============================] - 101s 735ms/step - loss: 0.1820 - accuracy: 0.9439 - val_loss: 1.5745 - val_accuracy: 0.7936
# Epoch 34/50
# 138/138 [==============================] - ETA: 0s - loss: 0.1817 - accuracy: 0.9437
# Epoch 34: val_accuracy did not improve from 0.79364
# 138/138 [==============================] - 102s 734ms/step - loss: 0.1817 - accuracy: 0.9437 - val_loss: 1.9845 - val_accuracy: 0.7564
# Epoch 35/50
# 138/138 [==============================] - ETA: 0s - loss: 0.1769 - accuracy: 0.9439
# Epoch 35: val_accuracy did not improve from 0.79364
# 138/138 [==============================] - 106s 766ms/step - loss: 0.1769 - accuracy: 0.9439 - val_loss: 1.8216 - val_accuracy: 0.7800
# Epoch 36/50
# 138/138 [==============================] - ETA: 0s - loss: 0.1775 - accuracy: 0.9482
# Epoch 36: val_accuracy did not improve from 0.79364
# 138/138 [==============================] - 103s 746ms/step - loss: 0.1775 - accuracy: 0.9482 - val_loss: 1.8982 - val_accuracy: 0.7927
# Epoch 37/50
# 138/138 [==============================] - ETA: 0s - loss: 0.1878 - accuracy: 0.9491
# Epoch 37: val_accuracy did not improve from 0.79364
# 138/138 [==============================] - 102s 738ms/step - loss: 0.1878 - accuracy: 0.9491 - val_loss: 1.7247 - val_accuracy: 0.7936
# Epoch 38/50
# 138/138 [==============================] - ETA: 0s - loss: 0.1565 - accuracy: 0.9505
# Epoch 38: val_accuracy did not improve from 0.79364
# 138/138 [==============================] - 101s 729ms/step - loss: 0.1565 - accuracy: 0.9505 - val_loss: 1.9613 - val_accuracy: 0.7800
# Epoch 39/50
# 138/138 [==============================] - ETA: 0s - loss: 0.1925 - accuracy: 0.9460
# Epoch 39: val_accuracy did not improve from 0.79364
# 138/138 [==============================] - 101s 735ms/step - loss: 0.1925 - accuracy: 0.9460 - val_loss: 1.8208 - val_accuracy: 0.7909
# Epoch 40/50
# 138/138 [==============================] - ETA: 0s - loss: 0.1683 - accuracy: 0.9491
# Epoch 40: val_accuracy did not improve from 0.79364
# 138/138 [==============================] - 101s 731ms/step - loss: 0.1683 - accuracy: 0.9491 - val_loss: 1.9302 - val_accuracy: 0.7709
# Epoch 41/50
# 138/138 [==============================] - ETA: 0s - loss: 0.1934 - accuracy: 0.9462
# Epoch 41: val_accuracy did not improve from 0.79364
# 138/138 [==============================] - 100s 727ms/step - loss: 0.1934 - accuracy: 0.9462 - val_loss: 2.0485 - val_accuracy: 0.7564
# Epoch 42/50
# 138/138 [==============================] - ETA: 0s - loss: 0.1715 - accuracy: 0.9498
# Epoch 42: val_accuracy did not improve from 0.79364
# 138/138 [==============================] - 102s 737ms/step - loss: 0.1715 - accuracy: 0.9498 - val_loss: 2.2719 - val_accuracy: 0.7727
# Epoch 43/50
# 138/138 [==============================] - ETA: 0s - loss: 0.1887 - accuracy: 0.9480
# Epoch 43: val_accuracy did not improve from 0.79364
# 138/138 [==============================] - 100s 727ms/step - loss: 0.1887 - accuracy: 0.9480 - val_loss: 2.0306 - val_accuracy: 0.7618
# Epoch 44/50
# 138/138 [==============================] - ETA: 0s - loss: 0.1646 - accuracy: 0.9501
# Epoch 44: val_accuracy did not improve from 0.79364
# 138/138 [==============================] - 103s 747ms/step - loss: 0.1646 - accuracy: 0.9501 - val_loss: 1.8628 - val_accuracy: 0.7800
# Epoch 45/50
# 138/138 [==============================] - ETA: 0s - loss: 0.1700 - accuracy: 0.9507
# Epoch 45: val_accuracy did not improve from 0.79364
# 138/138 [==============================] - 106s 765ms/step - loss: 0.1700 - accuracy: 0.9507 - val_loss: 2.0951 - val_accuracy: 0.7655
# Epoch 46/50
# 138/138 [==============================] - ETA: 0s - loss: 0.1484 - accuracy: 0.9532
# Epoch 46: val_accuracy did not improve from 0.79364
# 138/138 [==============================] - 102s 740ms/step - loss: 0.1484 - accuracy: 0.9532 - val_loss: 2.0499 - val_accuracy: 0.7782
# Epoch 47/50
# 138/138 [==============================] - ETA: 0s - loss: 0.1743 - accuracy: 0.9505
# Epoch 47: val_accuracy did not improve from 0.79364
# 138/138 [==============================] - 103s 746ms/step - loss: 0.1743 - accuracy: 0.9505 - val_loss: 2.3645 - val_accuracy: 0.7682
# Epoch 48/50
# 138/138 [==============================] - ETA: 0s - loss: 0.1811 - accuracy: 0.9489
# Epoch 48: val_accuracy did not improve from 0.79364
# 138/138 [==============================] - 125s 909ms/step - loss: 0.1811 - accuracy: 0.9489 - val_loss: 2.0818 - val_accuracy: 0.7827
# Epoch 49/50
# 138/138 [==============================] - ETA: 0s - loss: 0.1376 - accuracy: 0.9589
# Epoch 49: val_accuracy did not improve from 0.79364
# 138/138 [==============================] - 104s 754ms/step - loss: 0.1376 - accuracy: 0.9589 - val_loss: 2.0131 - val_accuracy: 0.7882
# Epoch 50/50
# 138/138 [==============================] - ETA: 0s - loss: 0.1707 - accuracy: 0.9526
# Epoch 50: val_accuracy did not improve from 0.79364
# 138/138 [==============================] - 102s 738ms/step - loss: 0.1707 - accuracy: 0.9526 - val_loss: 1.9171 - val_accuracy: 0.7755

# %% [markdown]
# ### Plot the training and validation accuracy

# %%
fig, ax = plt.subplots(figsize=(14,7))
ax.plot(history.history['accuracy'])
ax.plot(history.history['val_accuracy'])
ax.set_title('Model Accuracy')
ax.set_xlabel('Epoch')
ax.set_ylabel('Accuracy')
ax.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### Plot the Training and Validation Loss

# %%
fig, ax = plt.subplots(figsize=(14,7))
ax.plot(history.history['loss'])
ax.plot(history.history['val_loss'])
ax.set_title('Model Loss')
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')
ax.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### Test the model on the test data

# %%
test_loss, test_acc = model.evaluate(test_generator, steps=len(test_generator))
print("Test accuracy:", test_acc)
# Out:
# 41/41 [==============================] - 312s 8s/step - loss: 1.0166 - accuracy: 0.8977
# Test accuracy: 0.897736132144928

# %% [markdown]
# ### Generate predictions on the test data

# %%
y_pred = model.predict(test_generator, steps=len(test_generator))
y_true = test_generator.classes
# Out:
# 41/41 [==============================] - 12s 274ms/step

# %% [markdown]
# ### Generate and plot confusion matrix

# %%
cm = confusion_matrix(y_true, np.argmax(y_pred, axis=1))
plt.figure(figsize=(8, 8))
sns.heatmap(cm, annot=True, cmap="Blues", square=True, xticklabels=test_generator.class_indices.keys(),
            yticklabels=test_generator.class_indices.keys(), fmt='g')
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.show()

# %% [markdown]
# ### Print classification report

# %%
class_names = list(test_generator.class_indices.keys())
print(classification_report(y_true, np.argmax(y_pred, axis=1), target_names=class_names))
# Out:
#                   precision    recall  f1-score   support
#
#     glioma_tumor       0.90      0.82      0.86       299
# meningioma_tumor       0.78      0.85      0.81       301
#         no_tumor       0.98      0.95      0.97       381
#  pituitary_tumor       0.92      0.96      0.94       300
#
#         accuracy                           0.90      1281
#        macro avg       0.90      0.89      0.89      1281
#     weighted avg       0.90      0.90      0.90      1281

# %% [markdown]
# ### Compute precision, recall, F1 score and support for each class

# %%
precision, recall, f1_score, support = precision_recall_fscore_support(y_true, np.argmax(y_pred, axis=1))

# %%
# Create a dataframe with the computed metrics for each class
metrics_df = pd.DataFrame({
    'Precision': precision,
    'Recall': recall,
    'F1 Score': f1_score,
    'Support': support
}, index=class_names)

#Print the dataframe
print(metrics_df)
# Out:
#                   Precision    Recall  F1 Score  Support
# glioma_tumor       0.901099  0.822742  0.860140      299
# meningioma_tumor   0.777439  0.847176  0.810811      301
# no_tumor           0.983651  0.947507  0.965241      381
# pituitary_tumor    0.920128  0.960000  0.939641      300

# %% [markdown]
# ### Compute ROC and AUC for each class

# %%
fpr = {}
tpr = {}
roc_auc = {}

# Compute ROC and AUC for each class
for i in range(train_generator.num_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true == i, y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# %% [markdown]
# ### Plot ROC curve for each class

# %%
plt.figure(figsize=(8, 6))
for i in range(train_generator.num_classes):
    plt.plot(fpr[i], tpr[i], label='%s (AUC = %0.2f)' % (class_names[i], roc_auc[i]))
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic Curve')
plt.legend(loc="lower right")
plt.show()
