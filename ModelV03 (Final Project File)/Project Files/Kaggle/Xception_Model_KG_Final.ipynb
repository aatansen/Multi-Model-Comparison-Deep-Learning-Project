# %% [markdown]
# # Xception Model (Kaggle Dataset)

# %% [markdown]
# ### Import required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import time
import matplotlib.pyplot as plt
from PIL import Image
import cv2
from google.colab.patches import cv2_imshow
import imutils
from sklearn.metrics import classification_report, confusion_matrix, precision_recall_fscore_support, roc_curve, auc
import tensorflow as tf
from tensorflow.keras.utils import plot_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.applications.xception import preprocess_input
from tensorflow.keras.applications.xception import Xception

# %% [markdown]
# ### Define constants

# %%
TRAIN_PATH = "/content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification/Training"
TEST_PATH = "/content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification/Testing"
labels = ['glioma_tumor', 'meningioma_tumor', 'no_tumor', 'pituitary_tumor']
IMAGE_SIZE = [224, 224]
BATCH_SIZE = 32
NUM_EPOCHS = 50

# %% [markdown]
# ### Count of images Before filtering

# %%
print("Before filtering out images:")
for label in labels:
    train_count = len(os.listdir(os.path.join(TRAIN_PATH, label)))
    test_count = len(os.listdir(os.path.join(TEST_PATH, label)))
    print(f"{label}: Train - {train_count}, Test - {test_count}")
    
total_train_count = sum([len(os.listdir(os.path.join(TRAIN_PATH, label))) for label in labels])
total_test_count = sum([len(os.listdir(os.path.join(TEST_PATH, label))) for label in labels])
print(f"Total: Train - {total_train_count}, Test - {total_test_count}")
# Out:
# Before filtering out images:
# glioma_tumor: Train - 826, Test - 100
# meningioma_tumor: Train - 822, Test - 115
# no_tumor: Train - 395, Test - 105
# pituitary_tumor: Train - 827, Test - 74
# Total: Train - 2870, Test - 394

# %% [markdown]
# ### Filtering images

# %%
# Initialize a dictionary to store the count of detected black images for each label
detected_count = {label: 0 for label in labels}

# Loop through each label folder in training and testing paths
for path in [TRAIN_PATH, TEST_PATH]:
    for label in labels:
        dir_path = os.path.join(path, label)

        # Loop through each image in the folder
        for img_name in os.listdir(dir_path):
            img_path = os.path.join(dir_path, img_name)
            img = cv2.imread(img_path)

            # Check if the image is mostly black
            if (img.max() <= 120):
                detected_count[label] += 1
                print(f"Detected {img_path} as mostly black. Maximum pixel value: {img.max()}")

                # Remove the detected black image from the original location
                os.remove(img_path)

# Print the count of detected black images for each label
for label in labels:
    print(f"Detected {detected_count[label]} mostly black images for {label} label.") 

if sum(detected_count.values()) == 0:
    print("No black images detected.")
# Out:
# Detected 0 mostly black images for glioma_tumor label.
# Detected 0 mostly black images for meningioma_tumor label.
# Detected 0 mostly black images for no_tumor label.
# Detected 0 mostly black images for pituitary_tumor label.
# No black images detected.

# %% [markdown]
# ### Count of images After filtering

# %%
print("After filtering out images:")
for label in labels:
    train_count = len(os.listdir(os.path.join(TRAIN_PATH, label)))
    test_count = len(os.listdir(os.path.join(TEST_PATH, label)))
    print(f"{label}: Train - {train_count}, Test - {test_count}")
    
total_train_count = sum([len(os.listdir(os.path.join(TRAIN_PATH, label))) for label in labels])
total_test_count = sum([len(os.listdir(os.path.join(TEST_PATH, label))) for label in labels])
print(f"Total: Train - {total_train_count}, Test - {total_test_count}")
# Out:
# After filtering out images:
# glioma_tumor: Train - 826, Test - 100
# meningioma_tumor: Train - 822, Test - 115
# no_tumor: Train - 395, Test - 105
# pituitary_tumor: Train - 827, Test - 74
# Total: Train - 2870, Test - 394

# %% [markdown]
# ### Show sample image of each labels

# %%
# Loop through the labels and show 1 sample from each folder horizontally
fig, axs = plt.subplots(1, len(labels), figsize=(16, 5))
for i, label in enumerate(labels):
  axs[i].set_title(label)

  # Get a list of images in the current folder
  directory = os.path.join(TRAIN_PATH, label)
  files = os.listdir(directory)

  # Show 1 sample image from the folder
  file = files[0]
  path = os.path.join(directory, file)
  img = tf.keras.preprocessing.image.load_img(path, target_size=IMAGE_SIZE)
  axs[i].imshow(img)
  
plt.show()

# %% [markdown]
# ### Create data generators for training and validation with advanced data augmentation

# %%
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    validation_split=0.2
)

test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_generator = train_datagen.flow_from_directory(
    TRAIN_PATH,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training'
)

validation_generator = train_datagen.flow_from_directory(
    TRAIN_PATH,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation'
)

test_generator = test_datagen.flow_from_directory(
    TEST_PATH,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 2297 images belonging to 4 classes.
# Found 573 images belonging to 4 classes.
# Found 394 images belonging to 4 classes.

# %% [markdown]
# ### Load the pre-trained Xception model without top layers

# %%
base_model = Xception(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 0s 0us/step

# %% [markdown]
# ### Add new fully connected layers on top of the base model

# %%
x = Flatten()(base_model.output)
prediction = Dense(train_generator.num_classes, activation='softmax')(x)

# %% [markdown]
# ### Create the model

# %%
model = Model(inputs=base_model.input, outputs=prediction)

# %% [markdown]
# ### Freeze the pre-trained layers in the base model and train only the new layers

# %%
for layer in base_model.layers:
    layer.trainable = False

# %% [markdown]
# ### Model Summary

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 111, 111, 32  864         ['input_1[0][0]']
#                                 )
#
#  block1_conv1_bn (BatchNormaliz  (None, 111, 111, 32  128        ['block1_conv1[0][0]']
#  ation)                         )
#
#  block1_conv1_act (Activation)  (None, 111, 111, 32  0           ['block1_conv1_bn[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 109, 109, 64  18432       ['block1_conv1_act[0][0]']
#                                 )
#
#  block1_conv2_bn (BatchNormaliz  (None, 109, 109, 64  256        ['block1_conv2[0][0]']
#  ation)                         )
#
#  block1_conv2_act (Activation)  (None, 109, 109, 64  0           ['block1_conv2_bn[0][0]']
#                                 )
#
#  block2_sepconv1 (SeparableConv  (None, 109, 109, 12  8768       ['block1_conv2_act[0][0]']
#  2D)                            8)
#
#  block2_sepconv1_bn (BatchNorma  (None, 109, 109, 12  512        ['block2_sepconv1[0][0]']
#  lization)                      8)
#
#  block2_sepconv2_act (Activatio  (None, 109, 109, 12  0          ['block2_sepconv1_bn[0][0]']
#  n)                             8)
#
#  block2_sepconv2 (SeparableConv  (None, 109, 109, 12  17536      ['block2_sepconv2_act[0][0]']
#  2D)                            8)
#
#  block2_sepconv2_bn (BatchNorma  (None, 109, 109, 12  512        ['block2_sepconv2[0][0]']
#  lization)                      8)
#
#  conv2d (Conv2D)                (None, 55, 55, 128)  8192        ['block1_conv2_act[0][0]']
#
#  block2_pool (MaxPooling2D)     (None, 55, 55, 128)  0           ['block2_sepconv2_bn[0][0]']
#
#  batch_normalization (BatchNorm  (None, 55, 55, 128)  512        ['conv2d[0][0]']
#  alization)
#
#  add (Add)                      (None, 55, 55, 128)  0           ['block2_pool[0][0]',
#                                                                   'batch_normalization[0][0]']
#
#  block3_sepconv1_act (Activatio  (None, 55, 55, 128)  0          ['add[0][0]']
#  n)
#
#  block3_sepconv1 (SeparableConv  (None, 55, 55, 256)  33920      ['block3_sepconv1_act[0][0]']
#  2D)
#
#  block3_sepconv1_bn (BatchNorma  (None, 55, 55, 256)  1024       ['block3_sepconv1[0][0]']
#  lization)
#
#  block3_sepconv2_act (Activatio  (None, 55, 55, 256)  0          ['block3_sepconv1_bn[0][0]']
#  n)
#
#  block3_sepconv2 (SeparableConv  (None, 55, 55, 256)  67840      ['block3_sepconv2_act[0][0]']
#  2D)
#
#  block3_sepconv2_bn (BatchNorma  (None, 55, 55, 256)  1024       ['block3_sepconv2[0][0]']
#  lization)
#
#  conv2d_1 (Conv2D)              (None, 28, 28, 256)  32768       ['add[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 28, 28, 256)  0           ['block3_sepconv2_bn[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 28, 28, 256)  1024       ['conv2d_1[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 28, 28, 256)  0           ['block3_pool[0][0]',
#                                                                   'batch_normalization_1[0][0]']
#
#  block4_sepconv1_act (Activatio  (None, 28, 28, 256)  0          ['add_1[0][0]']
#  n)
#
#  block4_sepconv1 (SeparableConv  (None, 28, 28, 728)  188672     ['block4_sepconv1_act[0][0]']
#  2D)
#
#  block4_sepconv1_bn (BatchNorma  (None, 28, 28, 728)  2912       ['block4_sepconv1[0][0]']
#  lization)
#
#  block4_sepconv2_act (Activatio  (None, 28, 28, 728)  0          ['block4_sepconv1_bn[0][0]']
#  n)
#
#  block4_sepconv2 (SeparableConv  (None, 28, 28, 728)  536536     ['block4_sepconv2_act[0][0]']
#  2D)
#
#  block4_sepconv2_bn (BatchNorma  (None, 28, 28, 728)  2912       ['block4_sepconv2[0][0]']
#  lization)
#
#  conv2d_2 (Conv2D)              (None, 14, 14, 728)  186368      ['add_1[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 14, 14, 728)  0           ['block4_sepconv2_bn[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 14, 14, 728)  2912       ['conv2d_2[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 14, 14, 728)  0           ['block4_pool[0][0]',
#                                                                   'batch_normalization_2[0][0]']
#
#  block5_sepconv1_act (Activatio  (None, 14, 14, 728)  0          ['add_2[0][0]']
#  n)
#
#  block5_sepconv1 (SeparableConv  (None, 14, 14, 728)  536536     ['block5_sepconv1_act[0][0]']
#  2D)
#
#  block5_sepconv1_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block5_sepconv1[0][0]']
#  lization)
#
#  block5_sepconv2_act (Activatio  (None, 14, 14, 728)  0          ['block5_sepconv1_bn[0][0]']
#  n)
#
#  block5_sepconv2 (SeparableConv  (None, 14, 14, 728)  536536     ['block5_sepconv2_act[0][0]']
#  2D)
#
#  block5_sepconv2_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block5_sepconv2[0][0]']
#  lization)
#
#  block5_sepconv3_act (Activatio  (None, 14, 14, 728)  0          ['block5_sepconv2_bn[0][0]']
#  n)
#
#  block5_sepconv3 (SeparableConv  (None, 14, 14, 728)  536536     ['block5_sepconv3_act[0][0]']
#  2D)
#
#  block5_sepconv3_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block5_sepconv3[0][0]']
#  lization)
#
#  add_3 (Add)                    (None, 14, 14, 728)  0           ['block5_sepconv3_bn[0][0]',
#                                                                   'add_2[0][0]']
#
#  block6_sepconv1_act (Activatio  (None, 14, 14, 728)  0          ['add_3[0][0]']
#  n)
#
#  block6_sepconv1 (SeparableConv  (None, 14, 14, 728)  536536     ['block6_sepconv1_act[0][0]']
#  2D)
#
#  block6_sepconv1_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block6_sepconv1[0][0]']
#  lization)
#
#  block6_sepconv2_act (Activatio  (None, 14, 14, 728)  0          ['block6_sepconv1_bn[0][0]']
#  n)
#
#  block6_sepconv2 (SeparableConv  (None, 14, 14, 728)  536536     ['block6_sepconv2_act[0][0]']
#  2D)
#
#  block6_sepconv2_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block6_sepconv2[0][0]']
#  lization)
#
#  block6_sepconv3_act (Activatio  (None, 14, 14, 728)  0          ['block6_sepconv2_bn[0][0]']
#  n)
#
#  block6_sepconv3 (SeparableConv  (None, 14, 14, 728)  536536     ['block6_sepconv3_act[0][0]']
#  2D)
#
#  block6_sepconv3_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block6_sepconv3[0][0]']
#  lization)
#
#  add_4 (Add)                    (None, 14, 14, 728)  0           ['block6_sepconv3_bn[0][0]',
#                                                                   'add_3[0][0]']
#
#  block7_sepconv1_act (Activatio  (None, 14, 14, 728)  0          ['add_4[0][0]']
#  n)
#
#  block7_sepconv1 (SeparableConv  (None, 14, 14, 728)  536536     ['block7_sepconv1_act[0][0]']
#  2D)
#
#  block7_sepconv1_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block7_sepconv1[0][0]']
#  lization)
#
#  block7_sepconv2_act (Activatio  (None, 14, 14, 728)  0          ['block7_sepconv1_bn[0][0]']
#  n)
#
#  block7_sepconv2 (SeparableConv  (None, 14, 14, 728)  536536     ['block7_sepconv2_act[0][0]']
#  2D)
#
#  block7_sepconv2_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block7_sepconv2[0][0]']
#  lization)
#
#  block7_sepconv3_act (Activatio  (None, 14, 14, 728)  0          ['block7_sepconv2_bn[0][0]']
#  n)
#
#  block7_sepconv3 (SeparableConv  (None, 14, 14, 728)  536536     ['block7_sepconv3_act[0][0]']
#  2D)
#
#  block7_sepconv3_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block7_sepconv3[0][0]']
#  lization)
#
#  add_5 (Add)                    (None, 14, 14, 728)  0           ['block7_sepconv3_bn[0][0]',
#                                                                   'add_4[0][0]']
#
#  block8_sepconv1_act (Activatio  (None, 14, 14, 728)  0          ['add_5[0][0]']
#  n)
#
#  block8_sepconv1 (SeparableConv  (None, 14, 14, 728)  536536     ['block8_sepconv1_act[0][0]']
#  2D)
#
#  block8_sepconv1_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block8_sepconv1[0][0]']
#  lization)
#
#  block8_sepconv2_act (Activatio  (None, 14, 14, 728)  0          ['block8_sepconv1_bn[0][0]']
#  n)
#
#  block8_sepconv2 (SeparableConv  (None, 14, 14, 728)  536536     ['block8_sepconv2_act[0][0]']
#  2D)
#
#  block8_sepconv2_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block8_sepconv2[0][0]']
#  lization)
#
#  block8_sepconv3_act (Activatio  (None, 14, 14, 728)  0          ['block8_sepconv2_bn[0][0]']
#  n)
#
#  block8_sepconv3 (SeparableConv  (None, 14, 14, 728)  536536     ['block8_sepconv3_act[0][0]']
#  2D)
#
#  block8_sepconv3_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block8_sepconv3[0][0]']
#  lization)
#
#  add_6 (Add)                    (None, 14, 14, 728)  0           ['block8_sepconv3_bn[0][0]',
#                                                                   'add_5[0][0]']
#
#  block9_sepconv1_act (Activatio  (None, 14, 14, 728)  0          ['add_6[0][0]']
#  n)
#
#  block9_sepconv1 (SeparableConv  (None, 14, 14, 728)  536536     ['block9_sepconv1_act[0][0]']
#  2D)
#
#  block9_sepconv1_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block9_sepconv1[0][0]']
#  lization)
#
#  block9_sepconv2_act (Activatio  (None, 14, 14, 728)  0          ['block9_sepconv1_bn[0][0]']
#  n)
#
#  block9_sepconv2 (SeparableConv  (None, 14, 14, 728)  536536     ['block9_sepconv2_act[0][0]']
#  2D)
#
#  block9_sepconv2_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block9_sepconv2[0][0]']
#  lization)
#
#  block9_sepconv3_act (Activatio  (None, 14, 14, 728)  0          ['block9_sepconv2_bn[0][0]']
#  n)
#
#  block9_sepconv3 (SeparableConv  (None, 14, 14, 728)  536536     ['block9_sepconv3_act[0][0]']
#  2D)
#
#  block9_sepconv3_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block9_sepconv3[0][0]']
#  lization)
#
#  add_7 (Add)                    (None, 14, 14, 728)  0           ['block9_sepconv3_bn[0][0]',
#                                                                   'add_6[0][0]']
#
#  block10_sepconv1_act (Activati  (None, 14, 14, 728)  0          ['add_7[0][0]']
#  on)
#
#  block10_sepconv1 (SeparableCon  (None, 14, 14, 728)  536536     ['block10_sepconv1_act[0][0]']
#  v2D)
#
#  block10_sepconv1_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block10_sepconv1[0][0]']
#  alization)
#
#  block10_sepconv2_act (Activati  (None, 14, 14, 728)  0          ['block10_sepconv1_bn[0][0]']
#  on)
#
#  block10_sepconv2 (SeparableCon  (None, 14, 14, 728)  536536     ['block10_sepconv2_act[0][0]']
#  v2D)
#
#  block10_sepconv2_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block10_sepconv2[0][0]']
#  alization)
#
#  block10_sepconv3_act (Activati  (None, 14, 14, 728)  0          ['block10_sepconv2_bn[0][0]']
#  on)
#
#  block10_sepconv3 (SeparableCon  (None, 14, 14, 728)  536536     ['block10_sepconv3_act[0][0]']
#  v2D)
#
#  block10_sepconv3_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block10_sepconv3[0][0]']
#  alization)
#
#  add_8 (Add)                    (None, 14, 14, 728)  0           ['block10_sepconv3_bn[0][0]',
#                                                                   'add_7[0][0]']
#
#  block11_sepconv1_act (Activati  (None, 14, 14, 728)  0          ['add_8[0][0]']
#  on)
#
#  block11_sepconv1 (SeparableCon  (None, 14, 14, 728)  536536     ['block11_sepconv1_act[0][0]']
#  v2D)
#
#  block11_sepconv1_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block11_sepconv1[0][0]']
#  alization)
#
#  block11_sepconv2_act (Activati  (None, 14, 14, 728)  0          ['block11_sepconv1_bn[0][0]']
#  on)
#
#  block11_sepconv2 (SeparableCon  (None, 14, 14, 728)  536536     ['block11_sepconv2_act[0][0]']
#  v2D)
#
#  block11_sepconv2_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block11_sepconv2[0][0]']
#  alization)
#
#  block11_sepconv3_act (Activati  (None, 14, 14, 728)  0          ['block11_sepconv2_bn[0][0]']
#  on)
#
#  block11_sepconv3 (SeparableCon  (None, 14, 14, 728)  536536     ['block11_sepconv3_act[0][0]']
#  v2D)
#
#  block11_sepconv3_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block11_sepconv3[0][0]']
#  alization)
#
#  add_9 (Add)                    (None, 14, 14, 728)  0           ['block11_sepconv3_bn[0][0]',
#                                                                   'add_8[0][0]']
#
#  block12_sepconv1_act (Activati  (None, 14, 14, 728)  0          ['add_9[0][0]']
#  on)
#
#  block12_sepconv1 (SeparableCon  (None, 14, 14, 728)  536536     ['block12_sepconv1_act[0][0]']
#  v2D)
#
#  block12_sepconv1_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block12_sepconv1[0][0]']
#  alization)
#
#  block12_sepconv2_act (Activati  (None, 14, 14, 728)  0          ['block12_sepconv1_bn[0][0]']
#  on)
#
#  block12_sepconv2 (SeparableCon  (None, 14, 14, 728)  536536     ['block12_sepconv2_act[0][0]']
#  v2D)
#
#  block12_sepconv2_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block12_sepconv2[0][0]']
#  alization)
#
#  block12_sepconv3_act (Activati  (None, 14, 14, 728)  0          ['block12_sepconv2_bn[0][0]']
#  on)
#
#  block12_sepconv3 (SeparableCon  (None, 14, 14, 728)  536536     ['block12_sepconv3_act[0][0]']
#  v2D)
#
#  block12_sepconv3_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block12_sepconv3[0][0]']
#  alization)
#
#  add_10 (Add)                   (None, 14, 14, 728)  0           ['block12_sepconv3_bn[0][0]',
#                                                                   'add_9[0][0]']
#
#  block13_sepconv1_act (Activati  (None, 14, 14, 728)  0          ['add_10[0][0]']
#  on)
#
#  block13_sepconv1 (SeparableCon  (None, 14, 14, 728)  536536     ['block13_sepconv1_act[0][0]']
#  v2D)
#
#  block13_sepconv1_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block13_sepconv1[0][0]']
#  alization)
#
#  block13_sepconv2_act (Activati  (None, 14, 14, 728)  0          ['block13_sepconv1_bn[0][0]']
#  on)
#
#  block13_sepconv2 (SeparableCon  (None, 14, 14, 1024  752024     ['block13_sepconv2_act[0][0]']
#  v2D)                           )
#
#  block13_sepconv2_bn (BatchNorm  (None, 14, 14, 1024  4096       ['block13_sepconv2[0][0]']
#  alization)                     )
#
#  conv2d_3 (Conv2D)              (None, 7, 7, 1024)   745472      ['add_10[0][0]']
#
#  block13_pool (MaxPooling2D)    (None, 7, 7, 1024)   0           ['block13_sepconv2_bn[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 7, 7, 1024)  4096        ['conv2d_3[0][0]']
#  rmalization)
#
#  add_11 (Add)                   (None, 7, 7, 1024)   0           ['block13_pool[0][0]',
#                                                                   'batch_normalization_3[0][0]']
#
#  block14_sepconv1 (SeparableCon  (None, 7, 7, 1536)  1582080     ['add_11[0][0]']
#  v2D)
#
#  block14_sepconv1_bn (BatchNorm  (None, 7, 7, 1536)  6144        ['block14_sepconv1[0][0]']
#  alization)
#
#  block14_sepconv1_act (Activati  (None, 7, 7, 1536)  0           ['block14_sepconv1_bn[0][0]']
#  on)
#
#  block14_sepconv2 (SeparableCon  (None, 7, 7, 2048)  3159552     ['block14_sepconv1_act[0][0]']
#  v2D)
#
#  block14_sepconv2_bn (BatchNorm  (None, 7, 7, 2048)  8192        ['block14_sepconv2[0][0]']
#  alization)
#
#  block14_sepconv2_act (Activati  (None, 7, 7, 2048)  0           ['block14_sepconv2_bn[0][0]']
#  on)
#
#  flatten (Flatten)              (None, 100352)       0           ['block14_sepconv2_act[0][0]']
#
#  dense (Dense)                  (None, 4)            401412      ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 21,262,892
# Trainable params: 401,412
# Non-trainable params: 20,861,480
# __________________________________________________________________________________________________

# %% [markdown]
# ### Visualize the model architecture

# %%
plot_model(model=model, show_shapes=True)

# %% [markdown]
# ### Compile the model with categorical cross-entropy loss and a lower learning rate

# %%
model.compile(
    loss='categorical_crossentropy',
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    metrics=['accuracy'])

# %% [markdown]
# ### Save the Model

# %%
# Define a callback to save the best model weights
checkpoint = ModelCheckpoint('/content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/Xception_KG_Final.h5', 
                              monitor='val_accuracy', 
                              save_best_only=True, 
                              mode='max', 
                              verbose=1)

# Define a callback to track and print total training time and highest accuracy
class TimingCallback(tf.keras.callbacks.Callback):
    def __init__(self):
        self.start_time = None
        self.total_time = 0.0
        self.highest_train_acc = 0.0
        self.highest_val_acc = 0.0
        self.highest_train_epoch = 0
        self.highest_val_epoch = 0

    def on_epoch_begin(self, epoch, logs=None):
        self.start_time = time.time()

    def on_epoch_end(self, epoch, logs=None):
        epoch_time = time.time() - self.start_time
        self.total_time += epoch_time
        print(f'Total training time for epoch {epoch + 1}: {epoch_time:.2f} seconds')

        train_acc = logs['accuracy']
        val_acc = logs['val_accuracy']

        if train_acc > self.highest_train_acc:
            self.highest_train_acc = train_acc
            self.highest_train_epoch = epoch + 1
        
        if val_acc > self.highest_val_acc:
            self.highest_val_acc = val_acc
            self.highest_val_epoch = epoch + 1

        print(f'Highest training accuracy: {self.highest_train_acc:.4f} at epoch {self.highest_train_epoch}')
        print(f'Highest validation accuracy: {self.highest_val_acc:.4f} at epoch {self.highest_val_epoch}')

# %% [markdown]
# ### Train the model on training data and evaluate on validation data

# %%
timing_callback = TimingCallback()
history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=NUM_EPOCHS,
    steps_per_epoch=len(train_generator),
    validation_steps=len(validation_generator),
    callbacks=[checkpoint, timing_callback]
)

print(f'Total training time for {len(history.epoch)} epochs: {timing_callback.total_time:.2f} seconds')
# Out:
# Epoch 1/50
# 72/72 [==============================] - ETA: 0s - loss: 0.7240 - accuracy: 0.7118
# Epoch 1: val_accuracy improved from -inf to 0.72251, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/Xception_KG_Final.h5
# Total training time for epoch 1: 66.93 seconds
# Highest training accuracy: 0.7118 at epoch 1
# Highest validation accuracy: 0.7225 at epoch 1
# 72/72 [==============================] - 67s 740ms/step - loss: 0.7240 - accuracy: 0.7118 - val_loss: 0.7285 - val_accuracy: 0.7225
# Epoch 2/50
# 72/72 [==============================] - ETA: 0s - loss: 0.4136 - accuracy: 0.8494
# Epoch 2: val_accuracy improved from 0.72251 to 0.76265, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/Xception_KG_Final.h5
# Total training time for epoch 2: 51.50 seconds
# Highest training accuracy: 0.8494 at epoch 2
# Highest validation accuracy: 0.7627 at epoch 2
# 72/72 [==============================] - 51s 717ms/step - loss: 0.4136 - accuracy: 0.8494 - val_loss: 0.6044 - val_accuracy: 0.7627
# Epoch 3/50
# 72/72 [==============================] - ETA: 0s - loss: 0.3222 - accuracy: 0.8733
# Epoch 3: val_accuracy improved from 0.76265 to 0.80977, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/Xception_KG_Final.h5
# Total training time for epoch 3: 62.00 seconds
# Highest training accuracy: 0.8733 at epoch 3
# Highest validation accuracy: 0.8098 at epoch 3
# 72/72 [==============================] - 62s 865ms/step - loss: 0.3222 - accuracy: 0.8733 - val_loss: 0.5548 - val_accuracy: 0.8098
# Epoch 4/50
# 72/72 [==============================] - ETA: 0s - loss: 0.2877 - accuracy: 0.8999
# Epoch 4: val_accuracy did not improve from 0.80977
# Total training time for epoch 4: 49.54 seconds
# Highest training accuracy: 0.8999 at epoch 4
# Highest validation accuracy: 0.8098 at epoch 3
# 72/72 [==============================] - 50s 685ms/step - loss: 0.2877 - accuracy: 0.8999 - val_loss: 0.5977 - val_accuracy: 0.7871
# Epoch 5/50
# 72/72 [==============================] - ETA: 0s - loss: 0.2761 - accuracy: 0.8920
# Epoch 5: val_accuracy did not improve from 0.80977
# Total training time for epoch 5: 48.45 seconds
# Highest training accuracy: 0.8999 at epoch 4
# Highest validation accuracy: 0.8098 at epoch 3
# 72/72 [==============================] - 48s 673ms/step - loss: 0.2761 - accuracy: 0.8920 - val_loss: 0.6530 - val_accuracy: 0.7696
# Epoch 6/50
# 72/72 [==============================] - ETA: 0s - loss: 0.2301 - accuracy: 0.9160
# Epoch 6: val_accuracy did not improve from 0.80977
# Total training time for epoch 6: 49.45 seconds
# Highest training accuracy: 0.9160 at epoch 6
# Highest validation accuracy: 0.8098 at epoch 3
# 72/72 [==============================] - 49s 688ms/step - loss: 0.2301 - accuracy: 0.9160 - val_loss: 0.6796 - val_accuracy: 0.7522
# Epoch 7/50
# 72/72 [==============================] - ETA: 0s - loss: 0.2077 - accuracy: 0.9251
# Epoch 7: val_accuracy did not improve from 0.80977
# Total training time for epoch 7: 48.34 seconds
# Highest training accuracy: 0.9251 at epoch 7
# Highest validation accuracy: 0.8098 at epoch 3
# 72/72 [==============================] - 48s 672ms/step - loss: 0.2077 - accuracy: 0.9251 - val_loss: 0.7067 - val_accuracy: 0.7679
# Epoch 8/50
# 72/72 [==============================] - ETA: 0s - loss: 0.2016 - accuracy: 0.9208
# Epoch 8: val_accuracy did not improve from 0.80977
# Total training time for epoch 8: 50.00 seconds
# Highest training accuracy: 0.9251 at epoch 7
# Highest validation accuracy: 0.8098 at epoch 3
# 72/72 [==============================] - 50s 696ms/step - loss: 0.2016 - accuracy: 0.9208 - val_loss: 0.6566 - val_accuracy: 0.7749
# Epoch 9/50
# 72/72 [==============================] - ETA: 0s - loss: 0.2051 - accuracy: 0.9160
# Epoch 9: val_accuracy did not improve from 0.80977
# Total training time for epoch 9: 48.11 seconds
# Highest training accuracy: 0.9251 at epoch 7
# Highest validation accuracy: 0.8098 at epoch 3
# 72/72 [==============================] - 48s 669ms/step - loss: 0.2051 - accuracy: 0.9160 - val_loss: 0.6005 - val_accuracy: 0.7906
# Epoch 10/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1892 - accuracy: 0.9295
# Epoch 10: val_accuracy did not improve from 0.80977
# Total training time for epoch 10: 49.61 seconds
# Highest training accuracy: 0.9295 at epoch 10
# Highest validation accuracy: 0.8098 at epoch 3
# 72/72 [==============================] - 50s 691ms/step - loss: 0.1892 - accuracy: 0.9295 - val_loss: 0.6526 - val_accuracy: 0.8010
# Epoch 11/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1635 - accuracy: 0.9417
# Epoch 11: val_accuracy did not improve from 0.80977
# Total training time for epoch 11: 48.92 seconds
# Highest training accuracy: 0.9417 at epoch 11
# Highest validation accuracy: 0.8098 at epoch 3
# 72/72 [==============================] - 49s 676ms/step - loss: 0.1635 - accuracy: 0.9417 - val_loss: 0.5989 - val_accuracy: 0.7993
# Epoch 12/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1637 - accuracy: 0.9386
# Epoch 12: val_accuracy did not improve from 0.80977
# Total training time for epoch 12: 48.85 seconds
# Highest training accuracy: 0.9417 at epoch 11
# Highest validation accuracy: 0.8098 at epoch 3
# 72/72 [==============================] - 49s 680ms/step - loss: 0.1637 - accuracy: 0.9386 - val_loss: 0.7922 - val_accuracy: 0.7382
# Epoch 13/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1443 - accuracy: 0.9517
# Epoch 13: val_accuracy improved from 0.80977 to 0.81501, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/Xception_KG_Final.h5
# Total training time for epoch 13: 51.03 seconds
# Highest training accuracy: 0.9517 at epoch 13
# Highest validation accuracy: 0.8150 at epoch 13
# 72/72 [==============================] - 51s 710ms/step - loss: 0.1443 - accuracy: 0.9517 - val_loss: 0.5696 - val_accuracy: 0.8150
# Epoch 14/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1272 - accuracy: 0.9552
# Epoch 14: val_accuracy improved from 0.81501 to 0.83072, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/Xception_KG_Final.h5
# Total training time for epoch 14: 49.89 seconds
# Highest training accuracy: 0.9552 at epoch 14
# Highest validation accuracy: 0.8307 at epoch 14
# 72/72 [==============================] - 50s 694ms/step - loss: 0.1272 - accuracy: 0.9552 - val_loss: 0.5210 - val_accuracy: 0.8307
# Epoch 15/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1271 - accuracy: 0.9543
# Epoch 15: val_accuracy did not improve from 0.83072
# Total training time for epoch 15: 48.92 seconds
# Highest training accuracy: 0.9552 at epoch 14
# Highest validation accuracy: 0.8307 at epoch 14
# 72/72 [==============================] - 49s 677ms/step - loss: 0.1271 - accuracy: 0.9543 - val_loss: 0.5397 - val_accuracy: 0.8168
# Epoch 16/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1213 - accuracy: 0.9578
# Epoch 16: val_accuracy did not improve from 0.83072
# Total training time for epoch 16: 49.67 seconds
# Highest training accuracy: 0.9578 at epoch 16
# Highest validation accuracy: 0.8307 at epoch 14
# 72/72 [==============================] - 50s 691ms/step - loss: 0.1213 - accuracy: 0.9578 - val_loss: 0.6757 - val_accuracy: 0.7661
# Epoch 17/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1132 - accuracy: 0.9595
# Epoch 17: val_accuracy improved from 0.83072 to 0.83246, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/Xception_KG_Final.h5
# Total training time for epoch 17: 51.39 seconds
# Highest training accuracy: 0.9595 at epoch 17
# Highest validation accuracy: 0.8325 at epoch 17
# 72/72 [==============================] - 51s 715ms/step - loss: 0.1132 - accuracy: 0.9595 - val_loss: 0.6076 - val_accuracy: 0.8325
# Epoch 18/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1198 - accuracy: 0.9521
# Epoch 18: val_accuracy did not improve from 0.83246
# Total training time for epoch 18: 50.30 seconds
# Highest training accuracy: 0.9595 at epoch 17
# Highest validation accuracy: 0.8325 at epoch 17
# 72/72 [==============================] - 50s 696ms/step - loss: 0.1198 - accuracy: 0.9521 - val_loss: 0.6296 - val_accuracy: 0.8202
# Epoch 19/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1009 - accuracy: 0.9673
# Epoch 19: val_accuracy did not improve from 0.83246
# Total training time for epoch 19: 48.72 seconds
# Highest training accuracy: 0.9673 at epoch 19
# Highest validation accuracy: 0.8325 at epoch 17
# 72/72 [==============================] - 49s 677ms/step - loss: 0.1009 - accuracy: 0.9673 - val_loss: 0.6427 - val_accuracy: 0.8063
# Epoch 20/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1111 - accuracy: 0.9617
# Epoch 20: val_accuracy did not improve from 0.83246
# Total training time for epoch 20: 49.64 seconds
# Highest training accuracy: 0.9673 at epoch 19
# Highest validation accuracy: 0.8325 at epoch 17
# 72/72 [==============================] - 50s 690ms/step - loss: 0.1111 - accuracy: 0.9617 - val_loss: 0.5833 - val_accuracy: 0.8133
# Epoch 21/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1121 - accuracy: 0.9565
# Epoch 21: val_accuracy did not improve from 0.83246
# Total training time for epoch 21: 48.70 seconds
# Highest training accuracy: 0.9673 at epoch 19
# Highest validation accuracy: 0.8325 at epoch 17
# 72/72 [==============================] - 49s 677ms/step - loss: 0.1121 - accuracy: 0.9565 - val_loss: 0.5710 - val_accuracy: 0.8185
# Epoch 22/50
# 72/72 [==============================] - ETA: 0s - loss: 0.0886 - accuracy: 0.9695
# Epoch 22: val_accuracy did not improve from 0.83246
# Total training time for epoch 22: 49.60 seconds
# Highest training accuracy: 0.9695 at epoch 22
# Highest validation accuracy: 0.8325 at epoch 17
# 72/72 [==============================] - 50s 691ms/step - loss: 0.0886 - accuracy: 0.9695 - val_loss: 0.7040 - val_accuracy: 0.7801
# Epoch 23/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1133 - accuracy: 0.9599
# Epoch 23: val_accuracy did not improve from 0.83246
# Total training time for epoch 23: 49.76 seconds
# Highest training accuracy: 0.9695 at epoch 22
# Highest validation accuracy: 0.8325 at epoch 17
# 72/72 [==============================] - 50s 687ms/step - loss: 0.1133 - accuracy: 0.9599 - val_loss: 0.8437 - val_accuracy: 0.7714
# Epoch 24/50
# 72/72 [==============================] - ETA: 0s - loss: 0.0967 - accuracy: 0.9626
# Epoch 24: val_accuracy did not improve from 0.83246
# Total training time for epoch 24: 48.47 seconds
# Highest training accuracy: 0.9695 at epoch 22
# Highest validation accuracy: 0.8325 at epoch 17
# 72/72 [==============================] - 48s 674ms/step - loss: 0.0967 - accuracy: 0.9626 - val_loss: 0.6586 - val_accuracy: 0.8237
# Epoch 25/50
# 72/72 [==============================] - ETA: 0s - loss: 0.0826 - accuracy: 0.9717
# Epoch 25: val_accuracy did not improve from 0.83246
# Total training time for epoch 25: 49.90 seconds
# Highest training accuracy: 0.9717 at epoch 25
# Highest validation accuracy: 0.8325 at epoch 17
# 72/72 [==============================] - 50s 695ms/step - loss: 0.0826 - accuracy: 0.9717 - val_loss: 0.5849 - val_accuracy: 0.8290
# Epoch 26/50
# 72/72 [==============================] - ETA: 0s - loss: 0.0981 - accuracy: 0.9669
# Epoch 26: val_accuracy did not improve from 0.83246
# Total training time for epoch 26: 48.46 seconds
# Highest training accuracy: 0.9717 at epoch 25
# Highest validation accuracy: 0.8325 at epoch 17
# 72/72 [==============================] - 48s 674ms/step - loss: 0.0981 - accuracy: 0.9669 - val_loss: 0.6647 - val_accuracy: 0.8202
# Epoch 27/50
# 72/72 [==============================] - ETA: 0s - loss: 0.0822 - accuracy: 0.9669
# Epoch 27: val_accuracy did not improve from 0.83246
# Total training time for epoch 27: 49.93 seconds
# Highest training accuracy: 0.9717 at epoch 25
# Highest validation accuracy: 0.8325 at epoch 17
# 72/72 [==============================] - 50s 694ms/step - loss: 0.0822 - accuracy: 0.9669 - val_loss: 0.7212 - val_accuracy: 0.8080
# Epoch 28/50
# 72/72 [==============================] - ETA: 0s - loss: 0.0738 - accuracy: 0.9752
# Epoch 28: val_accuracy did not improve from 0.83246
# Total training time for epoch 28: 48.98 seconds
# Highest training accuracy: 0.9752 at epoch 28
# Highest validation accuracy: 0.8325 at epoch 17
# 72/72 [==============================] - 49s 681ms/step - loss: 0.0738 - accuracy: 0.9752 - val_loss: 0.7417 - val_accuracy: 0.7853
# Epoch 29/50
# 72/72 [==============================] - ETA: 0s - loss: 0.0981 - accuracy: 0.9630
# Epoch 29: val_accuracy did not improve from 0.83246
# Total training time for epoch 29: 49.35 seconds
# Highest training accuracy: 0.9752 at epoch 28
# Highest validation accuracy: 0.8325 at epoch 17
# 72/72 [==============================] - 49s 686ms/step - loss: 0.0981 - accuracy: 0.9630 - val_loss: 0.6505 - val_accuracy: 0.7976
# Epoch 30/50
# 72/72 [==============================] - ETA: 0s - loss: 0.0821 - accuracy: 0.9717
# Epoch 30: val_accuracy improved from 0.83246 to 0.83421, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/Xception_KG_Final.h5
# Total training time for epoch 30: 51.61 seconds
# Highest training accuracy: 0.9752 at epoch 28
# Highest validation accuracy: 0.8342 at epoch 30
# 72/72 [==============================] - 52s 718ms/step - loss: 0.0821 - accuracy: 0.9717 - val_loss: 0.5640 - val_accuracy: 0.8342
# Epoch 31/50
# 72/72 [==============================] - ETA: 0s - loss: 0.0922 - accuracy: 0.9704
# Epoch 31: val_accuracy did not improve from 0.83421
# Total training time for epoch 31: 51.26 seconds
# Highest training accuracy: 0.9752 at epoch 28
# Highest validation accuracy: 0.8342 at epoch 30
# 72/72 [==============================] - 51s 713ms/step - loss: 0.0922 - accuracy: 0.9704 - val_loss: 0.6897 - val_accuracy: 0.8220
# Epoch 32/50
# 72/72 [==============================] - ETA: 0s - loss: 0.0752 - accuracy: 0.9721
# Epoch 32: val_accuracy did not improve from 0.83421
# Total training time for epoch 32: 52.23 seconds
# Highest training accuracy: 0.9752 at epoch 28
# Highest validation accuracy: 0.8342 at epoch 30
# 72/72 [==============================] - 52s 726ms/step - loss: 0.0752 - accuracy: 0.9721 - val_loss: 0.6407 - val_accuracy: 0.8255
# Epoch 33/50
# 72/72 [==============================] - ETA: 0s - loss: 0.0727 - accuracy: 0.9761
# Epoch 33: val_accuracy did not improve from 0.83421
# Total training time for epoch 33: 50.52 seconds
# Highest training accuracy: 0.9761 at epoch 33
# Highest validation accuracy: 0.8342 at epoch 30
# 72/72 [==============================] - 51s 703ms/step - loss: 0.0727 - accuracy: 0.9761 - val_loss: 0.6520 - val_accuracy: 0.8202
# Epoch 34/50
# 72/72 [==============================] - ETA: 0s - loss: 0.0706 - accuracy: 0.9778
# Epoch 34: val_accuracy improved from 0.83421 to 0.83770, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/Xception_KG_Final.h5
# Total training time for epoch 34: 50.40 seconds
# Highest training accuracy: 0.9778 at epoch 34
# Highest validation accuracy: 0.8377 at epoch 34
# 72/72 [==============================] - 50s 701ms/step - loss: 0.0706 - accuracy: 0.9778 - val_loss: 0.7255 - val_accuracy: 0.8377
# Epoch 35/50
# 72/72 [==============================] - ETA: 0s - loss: 0.0848 - accuracy: 0.9704
# Epoch 35: val_accuracy did not improve from 0.83770
# Total training time for epoch 35: 50.04 seconds
# Highest training accuracy: 0.9778 at epoch 34
# Highest validation accuracy: 0.8377 at epoch 34
# 72/72 [==============================] - 50s 696ms/step - loss: 0.0848 - accuracy: 0.9704 - val_loss: 0.7989 - val_accuracy: 0.7993
# Epoch 36/50
# 72/72 [==============================] - ETA: 0s - loss: 0.0712 - accuracy: 0.9747
# Epoch 36: val_accuracy improved from 0.83770 to 0.84119, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/Xception_KG_Final.h5
# Total training time for epoch 36: 50.17 seconds
# Highest training accuracy: 0.9778 at epoch 34
# Highest validation accuracy: 0.8412 at epoch 36
# 72/72 [==============================] - 50s 698ms/step - loss: 0.0712 - accuracy: 0.9747 - val_loss: 0.6383 - val_accuracy: 0.8412
# Epoch 37/50
# 72/72 [==============================] - ETA: 0s - loss: 0.0675 - accuracy: 0.9782
# Epoch 37: val_accuracy did not improve from 0.84119
# Total training time for epoch 37: 51.19 seconds
# Highest training accuracy: 0.9782 at epoch 37
# Highest validation accuracy: 0.8412 at epoch 36
# 72/72 [==============================] - 51s 713ms/step - loss: 0.0675 - accuracy: 0.9782 - val_loss: 0.6635 - val_accuracy: 0.8168
# Epoch 38/50
# 72/72 [==============================] - ETA: 0s - loss: 0.0720 - accuracy: 0.9752
# Epoch 38: val_accuracy did not improve from 0.84119
# Total training time for epoch 38: 50.06 seconds
# Highest training accuracy: 0.9782 at epoch 37
# Highest validation accuracy: 0.8412 at epoch 36
# 72/72 [==============================] - 50s 697ms/step - loss: 0.0720 - accuracy: 0.9752 - val_loss: 0.7797 - val_accuracy: 0.8045
# Epoch 39/50
# 72/72 [==============================] - ETA: 0s - loss: 0.0679 - accuracy: 0.9752
# Epoch 39: val_accuracy did not improve from 0.84119
# Total training time for epoch 39: 48.97 seconds
# Highest training accuracy: 0.9782 at epoch 37
# Highest validation accuracy: 0.8412 at epoch 36
# 72/72 [==============================] - 49s 679ms/step - loss: 0.0679 - accuracy: 0.9752 - val_loss: 0.6953 - val_accuracy: 0.8063
# Epoch 40/50
# 72/72 [==============================] - ETA: 0s - loss: 0.0848 - accuracy: 0.9634
# Epoch 40: val_accuracy did not improve from 0.84119
# Total training time for epoch 40: 48.83 seconds
# Highest training accuracy: 0.9782 at epoch 37
# Highest validation accuracy: 0.8412 at epoch 36
# 72/72 [==============================] - 49s 679ms/step - loss: 0.0848 - accuracy: 0.9634 - val_loss: 0.6844 - val_accuracy: 0.8377
# Epoch 41/50
# 72/72 [==============================] - ETA: 0s - loss: 0.0738 - accuracy: 0.9756
# Epoch 41: val_accuracy did not improve from 0.84119
# Total training time for epoch 41: 50.00 seconds
# Highest training accuracy: 0.9782 at epoch 37
# Highest validation accuracy: 0.8412 at epoch 36
# 72/72 [==============================] - 50s 695ms/step - loss: 0.0738 - accuracy: 0.9756 - val_loss: 0.6274 - val_accuracy: 0.8342
# Epoch 42/50
# 72/72 [==============================] - ETA: 0s - loss: 0.0633 - accuracy: 0.9787
# Epoch 42: val_accuracy did not improve from 0.84119
# Total training time for epoch 42: 49.89 seconds
# Highest training accuracy: 0.9787 at epoch 42
# Highest validation accuracy: 0.8412 at epoch 36
# 72/72 [==============================] - 50s 693ms/step - loss: 0.0633 - accuracy: 0.9787 - val_loss: 0.7338 - val_accuracy: 0.8360
# Epoch 43/50
# 72/72 [==============================] - ETA: 0s - loss: 0.0594 - accuracy: 0.9804
# Epoch 43: val_accuracy did not improve from 0.84119
# Total training time for epoch 43: 49.50 seconds
# Highest training accuracy: 0.9804 at epoch 43
# Highest validation accuracy: 0.8412 at epoch 36
# 72/72 [==============================] - 50s 685ms/step - loss: 0.0594 - accuracy: 0.9804 - val_loss: 0.7914 - val_accuracy: 0.8010
# Epoch 44/50
# 72/72 [==============================] - ETA: 0s - loss: 0.0643 - accuracy: 0.9769
# Epoch 44: val_accuracy did not improve from 0.84119
# Total training time for epoch 44: 48.52 seconds
# Highest training accuracy: 0.9804 at epoch 43
# Highest validation accuracy: 0.8412 at epoch 36
# 72/72 [==============================] - 49s 673ms/step - loss: 0.0643 - accuracy: 0.9769 - val_loss: 0.7519 - val_accuracy: 0.8202
# Epoch 45/50
# 72/72 [==============================] - ETA: 0s - loss: 0.0774 - accuracy: 0.9752
# Epoch 45: val_accuracy did not improve from 0.84119
# Total training time for epoch 45: 50.20 seconds
# Highest training accuracy: 0.9804 at epoch 43
# Highest validation accuracy: 0.8412 at epoch 36
# 72/72 [==============================] - 50s 699ms/step - loss: 0.0774 - accuracy: 0.9752 - val_loss: 0.7753 - val_accuracy: 0.8220
# Epoch 46/50
# 72/72 [==============================] - ETA: 0s - loss: 0.0627 - accuracy: 0.9778
# Epoch 46: val_accuracy did not improve from 0.84119
# Total training time for epoch 46: 48.59 seconds
# Highest training accuracy: 0.9804 at epoch 43
# Highest validation accuracy: 0.8412 at epoch 36
# 72/72 [==============================] - 49s 676ms/step - loss: 0.0627 - accuracy: 0.9778 - val_loss: 0.6765 - val_accuracy: 0.8272
# Epoch 47/50
# 72/72 [==============================] - ETA: 0s - loss: 0.0528 - accuracy: 0.9826
# Epoch 47: val_accuracy did not improve from 0.84119
# Total training time for epoch 47: 49.97 seconds
# Highest training accuracy: 0.9826 at epoch 47
# Highest validation accuracy: 0.8412 at epoch 36
# 72/72 [==============================] - 50s 696ms/step - loss: 0.0528 - accuracy: 0.9826 - val_loss: 0.6724 - val_accuracy: 0.8394
# Epoch 48/50
# 72/72 [==============================] - ETA: 0s - loss: 0.0596 - accuracy: 0.9817
# Epoch 48: val_accuracy did not improve from 0.84119
# Total training time for epoch 48: 49.63 seconds
# Highest training accuracy: 0.9826 at epoch 47
# Highest validation accuracy: 0.8412 at epoch 36
# 72/72 [==============================] - 50s 687ms/step - loss: 0.0596 - accuracy: 0.9817 - val_loss: 0.7443 - val_accuracy: 0.8028
# Epoch 49/50
# 72/72 [==============================] - ETA: 0s - loss: 0.0619 - accuracy: 0.9800
# Epoch 49: val_accuracy did not improve from 0.84119
# Total training time for epoch 49: 49.79 seconds
# Highest training accuracy: 0.9826 at epoch 47
# Highest validation accuracy: 0.8412 at epoch 36
# 72/72 [==============================] - 50s 693ms/step - loss: 0.0619 - accuracy: 0.9800 - val_loss: 0.7747 - val_accuracy: 0.8360
# Epoch 50/50
# 72/72 [==============================] - ETA: 0s - loss: 0.0837 - accuracy: 0.9678
# Epoch 50: val_accuracy did not improve from 0.84119
# Total training time for epoch 50: 48.92 seconds
# Highest training accuracy: 0.9826 at epoch 47
# Highest validation accuracy: 0.8412 at epoch 36
# 72/72 [==============================] - 49s 681ms/step - loss: 0.0837 - accuracy: 0.9678 - val_loss: 0.7107 - val_accuracy: 0.8360
# Total training time for 50 epochs: 2514.76 seconds

# %% [markdown]
# ### Plot the training and validation accuracy

# %%
fig, ax = plt.subplots(figsize=(14,7))
ax.plot(history.history['accuracy'])
ax.plot(history.history['val_accuracy'])
ax.set_title('Model Accuracy')
ax.set_xlabel('Epoch')
ax.set_ylabel('Accuracy')
ax.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### Plot the Training and Validation Loss

# %%
fig, ax = plt.subplots(figsize=(14,7))
ax.plot(history.history['loss'])
ax.plot(history.history['val_loss'])
ax.set_title('Model Loss')
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')
ax.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### Test the model on the test data

# %%
test_loss, test_acc = model.evaluate(test_generator, steps=len(test_generator))
print("Test accuracy:", test_acc)
# Out:
# 13/13 [==============================] - 3s 224ms/step - loss: 2.2747 - accuracy: 0.7284
# Test accuracy: 0.7284263968467712

# %% [markdown]
# ### Generate predictions on the test data

# %%
y_pred = model.predict(test_generator, steps=len(test_generator))
y_true = test_generator.classes
# Out:
# 13/13 [==============================] - 4s 233ms/step

# %% [markdown]
# ### Generate and plot confusion matrix

# %%
cm = confusion_matrix(y_true, np.argmax(y_pred, axis=1))
plt.figure(figsize=(8, 8))
sns.heatmap(cm, annot=True, cmap="Blues", square=True, xticklabels=test_generator.class_indices.keys(),
            yticklabels=test_generator.class_indices.keys(), fmt='g')
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.show()

# %% [markdown]
# ### Print classification report

# %%
class_names = list(test_generator.class_indices.keys())
print(classification_report(y_true, np.argmax(y_pred, axis=1), target_names=class_names))
# Out:
#                   precision    recall  f1-score   support
#
#     glioma_tumor       0.96      0.22      0.36       100
# meningioma_tumor       0.66      0.97      0.79       115
#         no_tumor       0.70      0.99      0.82       105
#  pituitary_tumor       0.89      0.68      0.77        74
#
#         accuracy                           0.73       394
#        macro avg       0.80      0.71      0.68       394
#     weighted avg       0.79      0.73      0.68       394

# %% [markdown]
# ### Compute precision, recall, F1 score and support for each class

# %%
precision, recall, f1_score, support = precision_recall_fscore_support(y_true, np.argmax(y_pred, axis=1))

# %%
# Create a dataframe with the computed metrics for each class
metrics_df = pd.DataFrame({
    'Precision': precision,
    'Recall': recall,
    'F1 Score': f1_score,
    'Support': support
}, index=class_names)

# Print the dataframe
print(metrics_df)
# Out:
#                   Precision    Recall  F1 Score  Support
# glioma_tumor       0.956522  0.220000  0.357724      100
# meningioma_tumor   0.664671  0.965217  0.787234      115
# no_tumor           0.702703  0.990476  0.822134      105
# pituitary_tumor    0.892857  0.675676  0.769231       74

# %% [markdown]
# ### Compute ROC and AUC for each class

# %%
fpr = {}
tpr = {}
roc_auc = {}

# Compute ROC and AUC for each class
for i in range(train_generator.num_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true == i, y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# %% [markdown]
# ### Plot ROC curve for each class

# %%
plt.figure(figsize=(8, 6))
for i in range(train_generator.num_classes):
    plt.plot(fpr[i], tpr[i], label='%s (AUC = %0.2f)' % (class_names[i], roc_auc[i]))
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic Curve')
plt.legend(loc="lower right")
plt.show()
