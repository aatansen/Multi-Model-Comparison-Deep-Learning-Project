# %% [markdown]
# # VGG-16 Model (Kaggle Dataset)

# %% [markdown]
# ### Mount google drive

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %% [markdown]
# ### Import required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import time
import matplotlib.pyplot as plt
from PIL import Image
import cv2
from google.colab.patches import cv2_imshow
import imutils
from sklearn.metrics import classification_report, confusion_matrix, precision_recall_fscore_support, roc_curve, auc
import tensorflow as tf
from tensorflow.keras.utils import plot_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.applications.vgg16 import VGG16

# %% [markdown]
# ### Define constants

# %%
TRAIN_PATH = "/content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification/Training"
TEST_PATH = "/content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification/Testing"
labels = ['glioma_tumor', 'meningioma_tumor', 'no_tumor', 'pituitary_tumor']
IMAGE_SIZE = [224, 224]
BATCH_SIZE = 32
NUM_EPOCHS = 50

# %% [markdown]
# ### Count of images Before filtering

# %%
print("Before filtering out images:")
for label in labels:
    train_count = len(os.listdir(os.path.join(TRAIN_PATH, label)))
    test_count = len(os.listdir(os.path.join(TEST_PATH, label)))
    print(f"{label}: Train - {train_count}, Test - {test_count}")
    
total_train_count = sum([len(os.listdir(os.path.join(TRAIN_PATH, label))) for label in labels])
total_test_count = sum([len(os.listdir(os.path.join(TEST_PATH, label))) for label in labels])
print(f"Total: Train - {total_train_count}, Test - {total_test_count}")
# Out:
# Before filtering out images:
# glioma_tumor: Train - 826, Test - 100
# meningioma_tumor: Train - 822, Test - 115
# no_tumor: Train - 395, Test - 105
# pituitary_tumor: Train - 827, Test - 74
# Total: Train - 2870, Test - 394

# %% [markdown]
# ### Filtering images

# %%
# Initialize a dictionary to store the count of detected black images for each label
detected_count = {label: 0 for label in labels}

# Loop through each label folder in training and testing paths
for path in [TRAIN_PATH, TEST_PATH]:
    for label in labels:
        dir_path = os.path.join(path, label)

        # Loop through each image in the folder
        for img_name in os.listdir(dir_path):
            img_path = os.path.join(dir_path, img_name)
            img = cv2.imread(img_path)

            # Check if the image is mostly black
            if (img.max() <= 120):
                detected_count[label] += 1
                print(f"Detected {img_path} as mostly black. Maximum pixel value: {img.max()}")

                # Remove the detected black image from the original location
                os.remove(img_path)

# Print the count of detected black images for each label
for label in labels:
    print(f"Detected {detected_count[label]} mostly black images for {label} label.") 

if sum(detected_count.values()) == 0:
    print("No black images detected.")
# Out:
# Detected 0 mostly black images for glioma_tumor label.
# Detected 0 mostly black images for meningioma_tumor label.
# Detected 0 mostly black images for no_tumor label.
# Detected 0 mostly black images for pituitary_tumor label.
# No black images detected.

# %% [markdown]
# ### Count of images After filtering

# %%
print("After filtering out images:")
for label in labels:
    train_count = len(os.listdir(os.path.join(TRAIN_PATH, label)))
    test_count = len(os.listdir(os.path.join(TEST_PATH, label)))
    print(f"{label}: Train - {train_count}, Test - {test_count}")
    
total_train_count = sum([len(os.listdir(os.path.join(TRAIN_PATH, label))) for label in labels])
total_test_count = sum([len(os.listdir(os.path.join(TEST_PATH, label))) for label in labels])
print(f"Total: Train - {total_train_count}, Test - {total_test_count}")
# Out:
# After filtering out images:
# glioma_tumor: Train - 826, Test - 100
# meningioma_tumor: Train - 822, Test - 115
# no_tumor: Train - 395, Test - 105
# pituitary_tumor: Train - 827, Test - 74
# Total: Train - 2870, Test - 394

# %% [markdown]
# ### Show sample image of each labels

# %%
# Loop through the labels and show 1 sample from each folder horizontally
fig, axs = plt.subplots(1, len(labels), figsize=(16, 5))
for i, label in enumerate(labels):
  axs[i].set_title(label)

  # Get a list of images in the current folder
  directory = os.path.join(TRAIN_PATH, label)
  files = os.listdir(directory)

  # Show 1 sample image from the folder
  file = files[0]
  path = os.path.join(directory, file)
  img = tf.keras.preprocessing.image.load_img(path, target_size=IMAGE_SIZE)
  axs[i].imshow(img)
  
plt.show()

# %% [markdown]
# ### Create data generators for training and validation with advanced data augmentation

# %%
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    validation_split=0.2
)

test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_generator = train_datagen.flow_from_directory(
    TRAIN_PATH,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training'
)

validation_generator = train_datagen.flow_from_directory(
    TRAIN_PATH,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation'
)

test_generator = test_datagen.flow_from_directory(
    TEST_PATH,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 2297 images belonging to 4 classes.
# Found 573 images belonging to 4 classes.
# Found 394 images belonging to 4 classes.

# %% [markdown]
# ### Load the pre-trained VGG16 model without top layers

# %%
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 3s 0us/step

# %% [markdown]
# ### Add new fully connected layers on top of the base model

# %%
x = Flatten()(base_model.output)
prediction = Dense(train_generator.num_classes, activation='softmax')(x)

# %% [markdown]
# ### Create the model

# %%
model = Model(inputs=base_model.input, outputs=prediction)

# %% [markdown]
# ### Freeze the pre-trained layers in the base model and train only the new layers

# %%
for layer in base_model.layers:
    layer.trainable = False

# %% [markdown]
# Freeze all layers in the pre-trained model except the last two

# %%
#for layer in base_model.layers[:-2]:
 #   layer.trainable = False

# %% [markdown]
# ### Model Summary

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 4)                 100356
#
# =================================================================
# Total params: 14,815,044
# Trainable params: 100,356
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# ### Visualize the model architecture

# %%
plot_model(model=model, show_shapes=True)

# %% [markdown]
# ### Implement Early Stopping to prevent overfitting

# %%
#early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, mode='min', restore_best_weights=True)

# %% [markdown]
# ### Compile the model with categorical cross-entropy loss and a lower learning rate

# %%
model.compile(
    loss='categorical_crossentropy',
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    metrics=['accuracy'])

# %% [markdown]
# ### Save the Model

# %%
# Define a callback to save the best model weights
checkpoint = ModelCheckpoint('/content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/VGG16_KG_Final.h5', 
                              monitor='val_accuracy', 
                              save_best_only=True, 
                              mode='max', 
                              verbose=1)

# Define a callback to track and print total training time and highest accuracy
class TimingCallback(tf.keras.callbacks.Callback):
    def __init__(self):
        self.start_time = None
        self.total_time = 0.0
        self.highest_train_acc = 0.0
        self.highest_val_acc = 0.0
        self.highest_train_epoch = 0
        self.highest_val_epoch = 0

    def on_epoch_begin(self, epoch, logs=None):
        self.start_time = time.time()

    def on_epoch_end(self, epoch, logs=None):
        epoch_time = time.time() - self.start_time
        self.total_time += epoch_time
        print(f'Total training time for epoch {epoch + 1}: {epoch_time:.2f} seconds')

        train_acc = logs['accuracy']
        val_acc = logs['val_accuracy']

        if train_acc > self.highest_train_acc:
            self.highest_train_acc = train_acc
            self.highest_train_epoch = epoch + 1
        
        if val_acc > self.highest_val_acc:
            self.highest_val_acc = val_acc
            self.highest_val_epoch = epoch + 1

        print(f'Highest training accuracy: {self.highest_train_acc:.4f} at epoch {self.highest_train_epoch}')
        print(f'Highest validation accuracy: {self.highest_val_acc:.4f} at epoch {self.highest_val_epoch}')

# %% [markdown]
# ### Train the model on training data and evaluate on validation data

# %%
timing_callback = TimingCallback()
history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=NUM_EPOCHS,
    steps_per_epoch=len(train_generator),
    validation_steps=len(validation_generator),
    callbacks=[checkpoint, timing_callback]
)

print(f'Total training time for {len(history.epoch)} epochs: {timing_callback.total_time:.2f} seconds')
# Out:
# Epoch 1/50
# 72/72 [==============================] - ETA: 0s - loss: 3.9597 - accuracy: 0.5633
# Epoch 1: val_accuracy improved from -inf to 0.62653, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/VGG16_KG_Final.h5
# Total training time for epoch 1: 69.18 seconds
# Highest training accuracy: 0.5633 at epoch 1
# Highest validation accuracy: 0.6265 at epoch 1
# 72/72 [==============================] - 69s 793ms/step - loss: 3.9597 - accuracy: 0.5633 - val_loss: 3.1438 - val_accuracy: 0.6265
# Epoch 2/50
# 72/72 [==============================] - ETA: 0s - loss: 1.8583 - accuracy: 0.7510
# Epoch 2: val_accuracy improved from 0.62653 to 0.67539, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/VGG16_KG_Final.h5
# Total training time for epoch 2: 50.60 seconds
# Highest training accuracy: 0.7510 at epoch 2
# Highest validation accuracy: 0.6754 at epoch 2
# 72/72 [==============================] - 51s 704ms/step - loss: 1.8583 - accuracy: 0.7510 - val_loss: 2.4815 - val_accuracy: 0.6754
# Epoch 3/50
# 72/72 [==============================] - ETA: 0s - loss: 1.3182 - accuracy: 0.8158
# Epoch 3: val_accuracy improved from 0.67539 to 0.72775, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/VGG16_KG_Final.h5
# Total training time for epoch 3: 51.97 seconds
# Highest training accuracy: 0.8158 at epoch 3
# Highest validation accuracy: 0.7277 at epoch 3
# 72/72 [==============================] - 52s 723ms/step - loss: 1.3182 - accuracy: 0.8158 - val_loss: 2.2755 - val_accuracy: 0.7277
# Epoch 4/50
# 72/72 [==============================] - ETA: 0s - loss: 1.1180 - accuracy: 0.8359
# Epoch 4: val_accuracy did not improve from 0.72775
# Total training time for epoch 4: 51.62 seconds
# Highest training accuracy: 0.8359 at epoch 4
# Highest validation accuracy: 0.7277 at epoch 3
# 72/72 [==============================] - 52s 718ms/step - loss: 1.1180 - accuracy: 0.8359 - val_loss: 2.4513 - val_accuracy: 0.6946
# Epoch 5/50
# 72/72 [==============================] - ETA: 0s - loss: 0.8530 - accuracy: 0.8633
# Epoch 5: val_accuracy did not improve from 0.72775
# Total training time for epoch 5: 50.44 seconds
# Highest training accuracy: 0.8633 at epoch 5
# Highest validation accuracy: 0.7277 at epoch 3
# 72/72 [==============================] - 50s 700ms/step - loss: 0.8530 - accuracy: 0.8633 - val_loss: 2.1324 - val_accuracy: 0.6998
# Epoch 6/50
# 72/72 [==============================] - ETA: 0s - loss: 0.7663 - accuracy: 0.8737
# Epoch 6: val_accuracy improved from 0.72775 to 0.77661, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/VGG16_KG_Final.h5
# Total training time for epoch 6: 51.24 seconds
# Highest training accuracy: 0.8737 at epoch 6
# Highest validation accuracy: 0.7766 at epoch 6
# 72/72 [==============================] - 51s 713ms/step - loss: 0.7663 - accuracy: 0.8737 - val_loss: 2.0020 - val_accuracy: 0.7766
# Epoch 7/50
# 72/72 [==============================] - ETA: 0s - loss: 0.6280 - accuracy: 0.8833
# Epoch 7: val_accuracy did not improve from 0.77661
# Total training time for epoch 7: 49.22 seconds
# Highest training accuracy: 0.8833 at epoch 7
# Highest validation accuracy: 0.7766 at epoch 6
# 72/72 [==============================] - 49s 684ms/step - loss: 0.6280 - accuracy: 0.8833 - val_loss: 2.4082 - val_accuracy: 0.7173
# Epoch 8/50
# 72/72 [==============================] - ETA: 0s - loss: 0.5425 - accuracy: 0.8968
# Epoch 8: val_accuracy did not improve from 0.77661
# Total training time for epoch 8: 50.14 seconds
# Highest training accuracy: 0.8968 at epoch 8
# Highest validation accuracy: 0.7766 at epoch 6
# 72/72 [==============================] - 50s 697ms/step - loss: 0.5425 - accuracy: 0.8968 - val_loss: 2.2637 - val_accuracy: 0.7312
# Epoch 9/50
# 72/72 [==============================] - ETA: 0s - loss: 0.5228 - accuracy: 0.9016
# Epoch 9: val_accuracy did not improve from 0.77661
# Total training time for epoch 9: 49.45 seconds
# Highest training accuracy: 0.9016 at epoch 9
# Highest validation accuracy: 0.7766 at epoch 6
# 72/72 [==============================] - 49s 684ms/step - loss: 0.5228 - accuracy: 0.9016 - val_loss: 2.4366 - val_accuracy: 0.7138
# Epoch 10/50
# 72/72 [==============================] - ETA: 0s - loss: 0.4314 - accuracy: 0.9264
# Epoch 10: val_accuracy did not improve from 0.77661
# Total training time for epoch 10: 49.81 seconds
# Highest training accuracy: 0.9264 at epoch 10
# Highest validation accuracy: 0.7766 at epoch 6
# 72/72 [==============================] - 50s 693ms/step - loss: 0.4314 - accuracy: 0.9264 - val_loss: 2.3914 - val_accuracy: 0.7295
# Epoch 11/50
# 72/72 [==============================] - ETA: 0s - loss: 0.4199 - accuracy: 0.9160
# Epoch 11: val_accuracy did not improve from 0.77661
# Total training time for epoch 11: 49.29 seconds
# Highest training accuracy: 0.9264 at epoch 10
# Highest validation accuracy: 0.7766 at epoch 6
# 72/72 [==============================] - 49s 686ms/step - loss: 0.4199 - accuracy: 0.9160 - val_loss: 1.9914 - val_accuracy: 0.7522
# Epoch 12/50
# 72/72 [==============================] - ETA: 0s - loss: 0.3117 - accuracy: 0.9286
# Epoch 12: val_accuracy did not improve from 0.77661
# Total training time for epoch 12: 50.71 seconds
# Highest training accuracy: 0.9286 at epoch 12
# Highest validation accuracy: 0.7766 at epoch 6
# 72/72 [==============================] - 51s 705ms/step - loss: 0.3117 - accuracy: 0.9286 - val_loss: 1.9713 - val_accuracy: 0.7417
# Epoch 13/50
# 72/72 [==============================] - ETA: 0s - loss: 0.3258 - accuracy: 0.9330
# Epoch 13: val_accuracy did not improve from 0.77661
# Total training time for epoch 13: 49.48 seconds
# Highest training accuracy: 0.9330 at epoch 13
# Highest validation accuracy: 0.7766 at epoch 6
# 72/72 [==============================] - 49s 685ms/step - loss: 0.3258 - accuracy: 0.9330 - val_loss: 2.1111 - val_accuracy: 0.7557
# Epoch 14/50
# 72/72 [==============================] - ETA: 0s - loss: 0.2979 - accuracy: 0.9308
# Epoch 14: val_accuracy did not improve from 0.77661
# Total training time for epoch 14: 49.14 seconds
# Highest training accuracy: 0.9330 at epoch 13
# Highest validation accuracy: 0.7766 at epoch 6
# 72/72 [==============================] - 49s 683ms/step - loss: 0.2979 - accuracy: 0.9308 - val_loss: 2.2791 - val_accuracy: 0.7312
# Epoch 15/50
# 72/72 [==============================] - ETA: 0s - loss: 0.3111 - accuracy: 0.9377
# Epoch 15: val_accuracy did not improve from 0.77661
# Total training time for epoch 15: 50.42 seconds
# Highest training accuracy: 0.9377 at epoch 15
# Highest validation accuracy: 0.7766 at epoch 6
# 72/72 [==============================] - 50s 698ms/step - loss: 0.3111 - accuracy: 0.9377 - val_loss: 2.4049 - val_accuracy: 0.7557
# Epoch 16/50
# 72/72 [==============================] - ETA: 0s - loss: 0.3304 - accuracy: 0.9316
# Epoch 16: val_accuracy improved from 0.77661 to 0.78185, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/VGG16_KG_Final.h5
# Total training time for epoch 16: 50.94 seconds
# Highest training accuracy: 0.9377 at epoch 15
# Highest validation accuracy: 0.7818 at epoch 16
# 72/72 [==============================] - 51s 709ms/step - loss: 0.3304 - accuracy: 0.9316 - val_loss: 2.1674 - val_accuracy: 0.7818
# Epoch 17/50
# 72/72 [==============================] - ETA: 0s - loss: 0.2999 - accuracy: 0.9465
# Epoch 17: val_accuracy did not improve from 0.78185
# Total training time for epoch 17: 50.46 seconds
# Highest training accuracy: 0.9465 at epoch 17
# Highest validation accuracy: 0.7818 at epoch 16
# 72/72 [==============================] - 50s 702ms/step - loss: 0.2999 - accuracy: 0.9465 - val_loss: 2.1395 - val_accuracy: 0.7749
# Epoch 18/50
# 72/72 [==============================] - ETA: 0s - loss: 0.2432 - accuracy: 0.9512
# Epoch 18: val_accuracy did not improve from 0.78185
# Total training time for epoch 18: 49.42 seconds
# Highest training accuracy: 0.9512 at epoch 18
# Highest validation accuracy: 0.7818 at epoch 16
# 72/72 [==============================] - 49s 688ms/step - loss: 0.2432 - accuracy: 0.9512 - val_loss: 2.4442 - val_accuracy: 0.7382
# Epoch 19/50
# 72/72 [==============================] - ETA: 0s - loss: 0.2527 - accuracy: 0.9512
# Epoch 19: val_accuracy did not improve from 0.78185
# Total training time for epoch 19: 50.14 seconds
# Highest training accuracy: 0.9512 at epoch 18
# Highest validation accuracy: 0.7818 at epoch 16
# 72/72 [==============================] - 50s 697ms/step - loss: 0.2527 - accuracy: 0.9512 - val_loss: 2.1763 - val_accuracy: 0.7627
# Epoch 20/50
# 72/72 [==============================] - ETA: 0s - loss: 0.2086 - accuracy: 0.9495
# Epoch 20: val_accuracy did not improve from 0.78185
# Total training time for epoch 20: 48.78 seconds
# Highest training accuracy: 0.9512 at epoch 18
# Highest validation accuracy: 0.7818 at epoch 16
# 72/72 [==============================] - 49s 679ms/step - loss: 0.2086 - accuracy: 0.9495 - val_loss: 2.0956 - val_accuracy: 0.7801
# Epoch 21/50
# 72/72 [==============================] - ETA: 0s - loss: 0.2533 - accuracy: 0.9425
# Epoch 21: val_accuracy did not improve from 0.78185
# Total training time for epoch 21: 50.95 seconds
# Highest training accuracy: 0.9512 at epoch 18
# Highest validation accuracy: 0.7818 at epoch 16
# 72/72 [==============================] - 51s 709ms/step - loss: 0.2533 - accuracy: 0.9425 - val_loss: 2.2853 - val_accuracy: 0.7592
# Epoch 22/50
# 72/72 [==============================] - ETA: 0s - loss: 0.2029 - accuracy: 0.9530
# Epoch 22: val_accuracy did not improve from 0.78185
# Total training time for epoch 22: 49.57 seconds
# Highest training accuracy: 0.9530 at epoch 22
# Highest validation accuracy: 0.7818 at epoch 16
# 72/72 [==============================] - 50s 690ms/step - loss: 0.2029 - accuracy: 0.9530 - val_loss: 2.3373 - val_accuracy: 0.7661
# Epoch 23/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1663 - accuracy: 0.9660
# Epoch 23: val_accuracy did not improve from 0.78185
# Total training time for epoch 23: 51.22 seconds
# Highest training accuracy: 0.9660 at epoch 23
# Highest validation accuracy: 0.7818 at epoch 16
# 72/72 [==============================] - 51s 713ms/step - loss: 0.1663 - accuracy: 0.9660 - val_loss: 2.1632 - val_accuracy: 0.7784
# Epoch 24/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1671 - accuracy: 0.9665
# Epoch 24: val_accuracy did not improve from 0.78185
# Total training time for epoch 24: 51.25 seconds
# Highest training accuracy: 0.9665 at epoch 24
# Highest validation accuracy: 0.7818 at epoch 16
# 72/72 [==============================] - 51s 712ms/step - loss: 0.1671 - accuracy: 0.9665 - val_loss: 2.1624 - val_accuracy: 0.7679
# Epoch 25/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1726 - accuracy: 0.9613
# Epoch 25: val_accuracy did not improve from 0.78185
# Total training time for epoch 25: 50.41 seconds
# Highest training accuracy: 0.9665 at epoch 24
# Highest validation accuracy: 0.7818 at epoch 16
# 72/72 [==============================] - 50s 702ms/step - loss: 0.1726 - accuracy: 0.9613 - val_loss: 2.1871 - val_accuracy: 0.7731
# Epoch 26/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1933 - accuracy: 0.9608
# Epoch 26: val_accuracy improved from 0.78185 to 0.78360, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/VGG16_KG_Final.h5
# Total training time for epoch 26: 51.48 seconds
# Highest training accuracy: 0.9665 at epoch 24
# Highest validation accuracy: 0.7836 at epoch 26
# 72/72 [==============================] - 51s 716ms/step - loss: 0.1933 - accuracy: 0.9608 - val_loss: 2.1100 - val_accuracy: 0.7836
# Epoch 27/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1538 - accuracy: 0.9634
# Epoch 27: val_accuracy did not improve from 0.78360
# Total training time for epoch 27: 50.09 seconds
# Highest training accuracy: 0.9665 at epoch 24
# Highest validation accuracy: 0.7836 at epoch 26
# 72/72 [==============================] - 50s 697ms/step - loss: 0.1538 - accuracy: 0.9634 - val_loss: 2.5631 - val_accuracy: 0.7661
# Epoch 28/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1802 - accuracy: 0.9621
# Epoch 28: val_accuracy did not improve from 0.78360
# Total training time for epoch 28: 50.18 seconds
# Highest training accuracy: 0.9665 at epoch 24
# Highest validation accuracy: 0.7836 at epoch 26
# 72/72 [==============================] - 50s 695ms/step - loss: 0.1802 - accuracy: 0.9621 - val_loss: 2.4168 - val_accuracy: 0.7766
# Epoch 29/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1926 - accuracy: 0.9634
# Epoch 29: val_accuracy improved from 0.78360 to 0.78534, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/VGG16_KG_Final.h5
# Total training time for epoch 29: 49.89 seconds
# Highest training accuracy: 0.9665 at epoch 24
# Highest validation accuracy: 0.7853 at epoch 29
# 72/72 [==============================] - 50s 692ms/step - loss: 0.1926 - accuracy: 0.9634 - val_loss: 2.2682 - val_accuracy: 0.7853
# Epoch 30/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1382 - accuracy: 0.9687
# Epoch 30: val_accuracy improved from 0.78534 to 0.81675, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/VGG16_KG_Final.h5
# Total training time for epoch 30: 61.50 seconds
# Highest training accuracy: 0.9687 at epoch 30
# Highest validation accuracy: 0.8168 at epoch 30
# 72/72 [==============================] - 61s 858ms/step - loss: 0.1382 - accuracy: 0.9687 - val_loss: 1.9803 - val_accuracy: 0.8168
# Epoch 31/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1441 - accuracy: 0.9652
# Epoch 31: val_accuracy did not improve from 0.81675
# Total training time for epoch 31: 50.75 seconds
# Highest training accuracy: 0.9687 at epoch 30
# Highest validation accuracy: 0.8168 at epoch 30
# 72/72 [==============================] - 51s 705ms/step - loss: 0.1441 - accuracy: 0.9652 - val_loss: 2.1672 - val_accuracy: 0.7731
# Epoch 32/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1199 - accuracy: 0.9739
# Epoch 32: val_accuracy did not improve from 0.81675
# Total training time for epoch 32: 50.25 seconds
# Highest training accuracy: 0.9739 at epoch 32
# Highest validation accuracy: 0.8168 at epoch 30
# 72/72 [==============================] - 50s 695ms/step - loss: 0.1199 - accuracy: 0.9739 - val_loss: 2.0176 - val_accuracy: 0.7993
# Epoch 33/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1705 - accuracy: 0.9665
# Epoch 33: val_accuracy did not improve from 0.81675
# Total training time for epoch 33: 48.91 seconds
# Highest training accuracy: 0.9739 at epoch 32
# Highest validation accuracy: 0.8168 at epoch 30
# 72/72 [==============================] - 49s 680ms/step - loss: 0.1705 - accuracy: 0.9665 - val_loss: 2.1090 - val_accuracy: 0.7976
# Epoch 34/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1512 - accuracy: 0.9643
# Epoch 34: val_accuracy did not improve from 0.81675
# Total training time for epoch 34: 50.28 seconds
# Highest training accuracy: 0.9739 at epoch 32
# Highest validation accuracy: 0.8168 at epoch 30
# 72/72 [==============================] - 50s 700ms/step - loss: 0.1512 - accuracy: 0.9643 - val_loss: 2.2682 - val_accuracy: 0.7888
# Epoch 35/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1497 - accuracy: 0.9717
# Epoch 35: val_accuracy did not improve from 0.81675
# Total training time for epoch 35: 49.94 seconds
# Highest training accuracy: 0.9739 at epoch 32
# Highest validation accuracy: 0.8168 at epoch 30
# 72/72 [==============================] - 50s 695ms/step - loss: 0.1497 - accuracy: 0.9717 - val_loss: 2.3891 - val_accuracy: 0.8150
# Epoch 36/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1262 - accuracy: 0.9687
# Epoch 36: val_accuracy did not improve from 0.81675
# Total training time for epoch 36: 48.49 seconds
# Highest training accuracy: 0.9739 at epoch 32
# Highest validation accuracy: 0.8168 at epoch 30
# 72/72 [==============================] - 48s 671ms/step - loss: 0.1262 - accuracy: 0.9687 - val_loss: 2.2464 - val_accuracy: 0.7993
# Epoch 37/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1239 - accuracy: 0.9726
# Epoch 37: val_accuracy did not improve from 0.81675
# Total training time for epoch 37: 48.99 seconds
# Highest training accuracy: 0.9739 at epoch 32
# Highest validation accuracy: 0.8168 at epoch 30
# 72/72 [==============================] - 49s 681ms/step - loss: 0.1239 - accuracy: 0.9726 - val_loss: 2.1565 - val_accuracy: 0.7906
# Epoch 38/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1326 - accuracy: 0.9739
# Epoch 38: val_accuracy did not improve from 0.81675
# Total training time for epoch 38: 60.33 seconds
# Highest training accuracy: 0.9739 at epoch 32
# Highest validation accuracy: 0.8168 at epoch 30
# 72/72 [==============================] - 60s 837ms/step - loss: 0.1326 - accuracy: 0.9739 - val_loss: 2.4594 - val_accuracy: 0.7696
# Epoch 39/50
# 72/72 [==============================] - ETA: 0s - loss: 0.0739 - accuracy: 0.9800
# Epoch 39: val_accuracy did not improve from 0.81675
# Total training time for epoch 39: 49.04 seconds
# Highest training accuracy: 0.9800 at epoch 39
# Highest validation accuracy: 0.8168 at epoch 30
# 72/72 [==============================] - 49s 682ms/step - loss: 0.0739 - accuracy: 0.9800 - val_loss: 2.1952 - val_accuracy: 0.7871
# Epoch 40/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1318 - accuracy: 0.9665
# Epoch 40: val_accuracy did not improve from 0.81675
# Total training time for epoch 40: 50.46 seconds
# Highest training accuracy: 0.9800 at epoch 39
# Highest validation accuracy: 0.8168 at epoch 30
# 72/72 [==============================] - 50s 702ms/step - loss: 0.1318 - accuracy: 0.9665 - val_loss: 2.4192 - val_accuracy: 0.7784
# Epoch 41/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1414 - accuracy: 0.9717
# Epoch 41: val_accuracy did not improve from 0.81675
# Total training time for epoch 41: 50.50 seconds
# Highest training accuracy: 0.9800 at epoch 39
# Highest validation accuracy: 0.8168 at epoch 30
# 72/72 [==============================] - 51s 703ms/step - loss: 0.1414 - accuracy: 0.9717 - val_loss: 2.1969 - val_accuracy: 0.7958
# Epoch 42/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1011 - accuracy: 0.9739
# Epoch 42: val_accuracy did not improve from 0.81675
# Total training time for epoch 42: 61.30 seconds
# Highest training accuracy: 0.9800 at epoch 39
# Highest validation accuracy: 0.8168 at epoch 30
# 72/72 [==============================] - 61s 854ms/step - loss: 0.1011 - accuracy: 0.9739 - val_loss: 2.3743 - val_accuracy: 0.8115
# Epoch 43/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1418 - accuracy: 0.9691
# Epoch 43: val_accuracy did not improve from 0.81675
# Total training time for epoch 43: 51.40 seconds
# Highest training accuracy: 0.9800 at epoch 39
# Highest validation accuracy: 0.8168 at epoch 30
# 72/72 [==============================] - 51s 715ms/step - loss: 0.1418 - accuracy: 0.9691 - val_loss: 2.2122 - val_accuracy: 0.8028
# Epoch 44/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1115 - accuracy: 0.9787
# Epoch 44: val_accuracy did not improve from 0.81675
# Total training time for epoch 44: 49.99 seconds
# Highest training accuracy: 0.9800 at epoch 39
# Highest validation accuracy: 0.8168 at epoch 30
# 72/72 [==============================] - 50s 695ms/step - loss: 0.1115 - accuracy: 0.9787 - val_loss: 2.5252 - val_accuracy: 0.7941
# Epoch 45/50
# 72/72 [==============================] - ETA: 0s - loss: 0.0781 - accuracy: 0.9765
# Epoch 45: val_accuracy did not improve from 0.81675
# Total training time for epoch 45: 50.06 seconds
# Highest training accuracy: 0.9800 at epoch 39
# Highest validation accuracy: 0.8168 at epoch 30
# 72/72 [==============================] - 50s 693ms/step - loss: 0.0781 - accuracy: 0.9765 - val_loss: 2.5959 - val_accuracy: 0.7696
# Epoch 46/50
# 72/72 [==============================] - ETA: 0s - loss: 0.0916 - accuracy: 0.9774
# Epoch 46: val_accuracy did not improve from 0.81675
# Total training time for epoch 46: 48.47 seconds
# Highest training accuracy: 0.9800 at epoch 39
# Highest validation accuracy: 0.8168 at epoch 30
# 72/72 [==============================] - 48s 671ms/step - loss: 0.0916 - accuracy: 0.9774 - val_loss: 2.7262 - val_accuracy: 0.7871
# Epoch 47/50
# 72/72 [==============================] - ETA: 0s - loss: 0.0971 - accuracy: 0.9761
# Epoch 47: val_accuracy did not improve from 0.81675
# Total training time for epoch 47: 49.71 seconds
# Highest training accuracy: 0.9800 at epoch 39
# Highest validation accuracy: 0.8168 at epoch 30
# 72/72 [==============================] - 50s 692ms/step - loss: 0.0971 - accuracy: 0.9761 - val_loss: 2.1297 - val_accuracy: 0.7888
# Epoch 48/50
# 72/72 [==============================] - ETA: 0s - loss: 0.0675 - accuracy: 0.9835
# Epoch 48: val_accuracy did not improve from 0.81675
# Total training time for epoch 48: 49.90 seconds
# Highest training accuracy: 0.9835 at epoch 48
# Highest validation accuracy: 0.8168 at epoch 30
# 72/72 [==============================] - 50s 694ms/step - loss: 0.0675 - accuracy: 0.9835 - val_loss: 2.6076 - val_accuracy: 0.7801
# Epoch 49/50
# 72/72 [==============================] - ETA: 0s - loss: 0.0945 - accuracy: 0.9761
# Epoch 49: val_accuracy did not improve from 0.81675
# Total training time for epoch 49: 49.66 seconds
# Highest training accuracy: 0.9835 at epoch 48
# Highest validation accuracy: 0.8168 at epoch 30
# 72/72 [==============================] - 50s 687ms/step - loss: 0.0945 - accuracy: 0.9761 - val_loss: 2.5374 - val_accuracy: 0.7923
# Epoch 50/50
# 72/72 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9778
# Epoch 50: val_accuracy did not improve from 0.81675
# Total training time for epoch 50: 48.55 seconds
# Highest training accuracy: 0.9835 at epoch 48
# Highest validation accuracy: 0.8168 at epoch 30
# 72/72 [==============================] - 49s 675ms/step - loss: 0.0939 - accuracy: 0.9778 - val_loss: 2.3682 - val_accuracy: 0.7801
# Total training time for 50 epochs: 2556.01 seconds

# %% [markdown]
# ### Plot the training and validation accuracy

# %%
fig, ax = plt.subplots(figsize=(14,7))
ax.plot(history.history['accuracy'])
ax.plot(history.history['val_accuracy'])
ax.set_title('Model Accuracy')
ax.set_xlabel('Epoch')
ax.set_ylabel('Accuracy')
ax.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### Plot the Training and Validation Loss

# %%
fig, ax = plt.subplots(figsize=(14,7))
ax.plot(history.history['loss'])
ax.plot(history.history['val_loss'])
ax.set_title('Model Loss')
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')
ax.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### Test the model on the test data

# %%
test_loss, test_acc = model.evaluate(test_generator, steps=len(test_generator))
print("Test accuracy:", test_acc)
# Out:
# 13/13 [==============================] - 4s 316ms/step - loss: 8.3507 - accuracy: 0.7386
# Test accuracy: 0.7385786771774292

# %% [markdown]
# ### Generate predictions on the test data

# %%
y_pred = model.predict(test_generator, steps=len(test_generator))
y_true = test_generator.classes
# Out:
# 13/13 [==============================] - 3s 240ms/step

# %% [markdown]
# ### Generate and plot confusion matrix

# %%
cm = confusion_matrix(y_true, np.argmax(y_pred, axis=1))
plt.figure(figsize=(8, 8))
sns.heatmap(cm, annot=True, cmap="Blues", square=True, xticklabels=test_generator.class_indices.keys(),
            yticklabels=test_generator.class_indices.keys(), fmt='g')
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.show()

# %% [markdown]
# ### Print classification report

# %%
class_names = list(test_generator.class_indices.keys())
print(classification_report(y_true, np.argmax(y_pred, axis=1), target_names=class_names))
# Out:
#                   precision    recall  f1-score   support
#
#     glioma_tumor       1.00      0.25      0.40       100
# meningioma_tumor       0.57      0.99      0.73       115
#         no_tumor       0.86      0.96      0.91       105
#  pituitary_tumor       0.96      0.69      0.80        74
#
#         accuracy                           0.74       394
#        macro avg       0.85      0.72      0.71       394
#     weighted avg       0.83      0.74      0.71       394

# %% [markdown]
# ### Compute precision, recall, F1 score and support for each class

# %%
precision, recall, f1_score, support = precision_recall_fscore_support(y_true, np.argmax(y_pred, axis=1))

# %%
# Create a dataframe with the computed metrics for each class
metrics_df = pd.DataFrame({
    'Precision': precision,
    'Recall': recall,
    'F1 Score': f1_score,
    'Support': support
}, index=class_names)

# Print the dataframe
print(metrics_df)
# Out:
#                   Precision    Recall  F1 Score  Support
# glioma_tumor       1.000000  0.250000  0.400000      100
# meningioma_tumor   0.572864  0.991304  0.726115      115
# no_tumor           0.863248  0.961905  0.909910      105
# pituitary_tumor    0.962264  0.689189  0.803150       74

# %% [markdown]
# ### Compute ROC and AUC for each class

# %%
fpr = {}
tpr = {}
roc_auc = {}

# Compute ROC and AUC for each class
for i in range(train_generator.num_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true == i, y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# %% [markdown]
# ### Plot ROC curve for each class

# %%
plt.figure(figsize=(8, 6))
for i in range(train_generator.num_classes):
    plt.plot(fpr[i], tpr[i], label='%s (AUC = %0.2f)' % (class_names[i], roc_auc[i]))
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic Curve')
plt.legend(loc="lower right")
plt.show()
