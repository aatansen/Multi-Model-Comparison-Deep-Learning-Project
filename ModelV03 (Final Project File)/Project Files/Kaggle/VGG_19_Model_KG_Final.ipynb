# %% [markdown]
# # VGG-19 Model (Kaggle Dataset)

# %% [markdown]
# ### Import required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import time
import matplotlib.pyplot as plt
from PIL import Image
import cv2
from google.colab.patches import cv2_imshow
import imutils
from sklearn.metrics import classification_report, confusion_matrix, precision_recall_fscore_support, roc_curve, auc
import tensorflow as tf
from tensorflow.keras.utils import plot_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg19 import preprocess_input
from tensorflow.keras.applications.vgg19 import VGG19

# %% [markdown]
# ### Define constants

# %%
TRAIN_PATH = "/content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification/Training"
TEST_PATH = "/content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification/Testing"
labels = ['glioma_tumor', 'meningioma_tumor', 'no_tumor', 'pituitary_tumor']
IMAGE_SIZE = [224, 224]
BATCH_SIZE = 32
NUM_EPOCHS = 50

# %% [markdown]
# ### Count of images Before filtering

# %%
print("Before filtering out images:")
for label in labels:
    train_count = len(os.listdir(os.path.join(TRAIN_PATH, label)))
    test_count = len(os.listdir(os.path.join(TEST_PATH, label)))
    print(f"{label}: Train - {train_count}, Test - {test_count}")
    
total_train_count = sum([len(os.listdir(os.path.join(TRAIN_PATH, label))) for label in labels])
total_test_count = sum([len(os.listdir(os.path.join(TEST_PATH, label))) for label in labels])
print(f"Total: Train - {total_train_count}, Test - {total_test_count}")
# Out:
# Before filtering out images:
# glioma_tumor: Train - 826, Test - 100
# meningioma_tumor: Train - 822, Test - 115
# no_tumor: Train - 395, Test - 105
# pituitary_tumor: Train - 827, Test - 74
# Total: Train - 2870, Test - 394

# %% [markdown]
# ### Filtering images

# %%
# Initialize a dictionary to store the count of detected black images for each label
detected_count = {label: 0 for label in labels}

# Loop through each label folder in training and testing paths
for path in [TRAIN_PATH, TEST_PATH]:
    for label in labels:
        dir_path = os.path.join(path, label)

        # Loop through each image in the folder
        for img_name in os.listdir(dir_path):
            img_path = os.path.join(dir_path, img_name)
            img = cv2.imread(img_path)

            # Check if the image is mostly black
            if (img.max() <= 120):
                detected_count[label] += 1
                print(f"Detected {img_path} as mostly black. Maximum pixel value: {img.max()}")

                # Remove the detected black image from the original location
                os.remove(img_path)

# Print the count of detected black images for each label
for label in labels:
    print(f"Detected {detected_count[label]} mostly black images for {label} label.") 

if sum(detected_count.values()) == 0:
    print("No black images detected.")
# Out:
# Detected 0 mostly black images for glioma_tumor label.
# Detected 0 mostly black images for meningioma_tumor label.
# Detected 0 mostly black images for no_tumor label.
# Detected 0 mostly black images for pituitary_tumor label.
# No black images detected.

# %% [markdown]
# ### Count of images After filtering

# %%
print("After filtering out images:")
for label in labels:
    train_count = len(os.listdir(os.path.join(TRAIN_PATH, label)))
    test_count = len(os.listdir(os.path.join(TEST_PATH, label)))
    print(f"{label}: Train - {train_count}, Test - {test_count}")
    
total_train_count = sum([len(os.listdir(os.path.join(TRAIN_PATH, label))) for label in labels])
total_test_count = sum([len(os.listdir(os.path.join(TEST_PATH, label))) for label in labels])
print(f"Total: Train - {total_train_count}, Test - {total_test_count}")
# Out:
# After filtering out images:
# glioma_tumor: Train - 826, Test - 100
# meningioma_tumor: Train - 822, Test - 115
# no_tumor: Train - 395, Test - 105
# pituitary_tumor: Train - 827, Test - 74
# Total: Train - 2870, Test - 394

# %% [markdown]
# ### Show sample image of each labels

# %%
# Loop through the labels and show 1 sample from each folder horizontally
fig, axs = plt.subplots(1, len(labels), figsize=(16, 5))
for i, label in enumerate(labels):
  axs[i].set_title(label)

  # Get a list of images in the current folder
  directory = os.path.join(TRAIN_PATH, label)
  files = os.listdir(directory)

  # Show 1 sample image from the folder
  file = files[0]
  path = os.path.join(directory, file)
  img = tf.keras.preprocessing.image.load_img(path, target_size=IMAGE_SIZE)
  axs[i].imshow(img)
  
plt.show()

# %% [markdown]
# ### Create data generators for training and validation with advanced data augmentation

# %%
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    validation_split=0.2
)

test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_generator = train_datagen.flow_from_directory(
    TRAIN_PATH,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training'
)

validation_generator = train_datagen.flow_from_directory(
    TRAIN_PATH,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation'
)

test_generator = test_datagen.flow_from_directory(
    TEST_PATH,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 2297 images belonging to 4 classes.
# Found 573 images belonging to 4 classes.
# Found 394 images belonging to 4 classes.

# %% [markdown]
# ### Load the pre-trained VGG19 model without top layers

# %%
base_model = VGG19(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 5s 0us/step

# %% [markdown]
# ### Add new fully connected layers on top of the base model

# %%
x = Flatten()(base_model.output)
prediction = Dense(train_generator.num_classes, activation='softmax')(x)

# %% [markdown]
# ### Create the model

# %%
model = Model(inputs=base_model.input, outputs=prediction)

# %% [markdown]
# ### Freeze the pre-trained layers in the base model and train only the new layers

# %%
for layer in base_model.layers:
    layer.trainable = False

# %% [markdown]
# Freeze all layers in the pre-trained model except the last two

# %%
#for layer in base_model.layers[:-2]:
 #   layer.trainable = False

# %% [markdown]
# ### Model Summary

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 4)                 100356
#
# =================================================================
# Total params: 20,124,740
# Trainable params: 100,356
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %% [markdown]
# ### Visualize the model architecture

# %%
plot_model(model=model, show_shapes=True)

# %% [markdown]
# ### Implement Early Stopping to prevent overfitting

# %%
#early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, mode='min', restore_best_weights=True)

# %% [markdown]
# ### Compile the model with categorical cross-entropy loss and a lower learning rate

# %%
model.compile(
    loss='categorical_crossentropy',
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    metrics=['accuracy'])

# %% [markdown]
# ### Save the Model

# %%
# Define a callback to save the best model weights
checkpoint = ModelCheckpoint('/content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/VGG19_KG_Final.h5', 
                              monitor='val_accuracy', 
                              save_best_only=True, 
                              mode='max', 
                              verbose=1)

# Define a callback to track and print total training time and highest accuracy
class TimingCallback(tf.keras.callbacks.Callback):
    def __init__(self):
        self.start_time = None
        self.total_time = 0.0
        self.highest_train_acc = 0.0
        self.highest_val_acc = 0.0
        self.highest_train_epoch = 0
        self.highest_val_epoch = 0

    def on_epoch_begin(self, epoch, logs=None):
        self.start_time = time.time()

    def on_epoch_end(self, epoch, logs=None):
        epoch_time = time.time() - self.start_time
        self.total_time += epoch_time
        print(f'Total training time for epoch {epoch + 1}: {epoch_time:.2f} seconds')

        train_acc = logs['accuracy']
        val_acc = logs['val_accuracy']

        if train_acc > self.highest_train_acc:
            self.highest_train_acc = train_acc
            self.highest_train_epoch = epoch + 1
        
        if val_acc > self.highest_val_acc:
            self.highest_val_acc = val_acc
            self.highest_val_epoch = epoch + 1

        print(f'Highest training accuracy: {self.highest_train_acc:.4f} at epoch {self.highest_train_epoch}')
        print(f'Highest validation accuracy: {self.highest_val_acc:.4f} at epoch {self.highest_val_epoch}')

# %% [markdown]
# ### Train the model on training data and evaluate on validation data

# %%
timing_callback = TimingCallback()
history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=NUM_EPOCHS,
    steps_per_epoch=len(train_generator),
    validation_steps=len(validation_generator),
    callbacks=[checkpoint, timing_callback]
)

print(f'Total training time for {len(history.epoch)} epochs: {timing_callback.total_time:.2f} seconds')
# Out:
# Epoch 1/50
# 72/72 [==============================] - ETA: 0s - loss: 3.5904 - accuracy: 0.5616
# Epoch 1: val_accuracy improved from -inf to 0.56719, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/VGG19_KG_Final.h5
# Total training time for epoch 1: 70.91 seconds
# Highest training accuracy: 0.5616 at epoch 1
# Highest validation accuracy: 0.5672 at epoch 1
# 72/72 [==============================] - 71s 808ms/step - loss: 3.5904 - accuracy: 0.5616 - val_loss: 3.2198 - val_accuracy: 0.5672
# Epoch 2/50
# 72/72 [==============================] - ETA: 0s - loss: 1.6468 - accuracy: 0.7492
# Epoch 2: val_accuracy improved from 0.56719 to 0.62478, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/VGG19_KG_Final.h5
# Total training time for epoch 2: 52.55 seconds
# Highest training accuracy: 0.7492 at epoch 2
# Highest validation accuracy: 0.6248 at epoch 2
# 72/72 [==============================] - 53s 731ms/step - loss: 1.6468 - accuracy: 0.7492 - val_loss: 2.3463 - val_accuracy: 0.6248
# Epoch 3/50
# 72/72 [==============================] - ETA: 0s - loss: 1.1757 - accuracy: 0.7963
# Epoch 3: val_accuracy improved from 0.62478 to 0.63176, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/VGG19_KG_Final.h5
# Total training time for epoch 3: 53.32 seconds
# Highest training accuracy: 0.7963 at epoch 3
# Highest validation accuracy: 0.6318 at epoch 3
# 72/72 [==============================] - 53s 741ms/step - loss: 1.1757 - accuracy: 0.7963 - val_loss: 2.5521 - val_accuracy: 0.6318
# Epoch 4/50
# 72/72 [==============================] - ETA: 0s - loss: 0.9720 - accuracy: 0.8289
# Epoch 4: val_accuracy improved from 0.63176 to 0.69284, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/VGG19_KG_Final.h5
# Total training time for epoch 4: 60.15 seconds
# Highest training accuracy: 0.8289 at epoch 4
# Highest validation accuracy: 0.6928 at epoch 4
# 72/72 [==============================] - 60s 838ms/step - loss: 0.9720 - accuracy: 0.8289 - val_loss: 2.2818 - val_accuracy: 0.6928
# Epoch 5/50
# 72/72 [==============================] - ETA: 0s - loss: 0.8888 - accuracy: 0.8407
# Epoch 5: val_accuracy improved from 0.69284 to 0.69983, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/VGG19_KG_Final.h5
# Total training time for epoch 5: 83.83 seconds
# Highest training accuracy: 0.8407 at epoch 5
# Highest validation accuracy: 0.6998 at epoch 5
# 72/72 [==============================] - 84s 1s/step - loss: 0.8888 - accuracy: 0.8407 - val_loss: 2.0070 - val_accuracy: 0.6998
# Epoch 6/50
# 72/72 [==============================] - ETA: 0s - loss: 0.6775 - accuracy: 0.8794
# Epoch 6: val_accuracy did not improve from 0.69983
# Total training time for epoch 6: 51.80 seconds
# Highest training accuracy: 0.8794 at epoch 6
# Highest validation accuracy: 0.6998 at epoch 5
# 72/72 [==============================] - 52s 720ms/step - loss: 0.6775 - accuracy: 0.8794 - val_loss: 2.1744 - val_accuracy: 0.6894
# Epoch 7/50
# 72/72 [==============================] - ETA: 0s - loss: 0.6023 - accuracy: 0.8772
# Epoch 7: val_accuracy improved from 0.69983 to 0.70157, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/VGG19_KG_Final.h5
# Total training time for epoch 7: 51.35 seconds
# Highest training accuracy: 0.8794 at epoch 6
# Highest validation accuracy: 0.7016 at epoch 7
# 72/72 [==============================] - 51s 714ms/step - loss: 0.6023 - accuracy: 0.8772 - val_loss: 2.0752 - val_accuracy: 0.7016
# Epoch 8/50
# 72/72 [==============================] - ETA: 0s - loss: 0.5267 - accuracy: 0.8872
# Epoch 8: val_accuracy did not improve from 0.70157
# Total training time for epoch 8: 51.86 seconds
# Highest training accuracy: 0.8872 at epoch 8
# Highest validation accuracy: 0.7016 at epoch 7
# 72/72 [==============================] - 52s 719ms/step - loss: 0.5267 - accuracy: 0.8872 - val_loss: 2.1265 - val_accuracy: 0.7016
# Epoch 9/50
# 72/72 [==============================] - ETA: 0s - loss: 0.4850 - accuracy: 0.9016
# Epoch 9: val_accuracy did not improve from 0.70157
# Total training time for epoch 9: 50.89 seconds
# Highest training accuracy: 0.9016 at epoch 9
# Highest validation accuracy: 0.7016 at epoch 7
# 72/72 [==============================] - 51s 704ms/step - loss: 0.4850 - accuracy: 0.9016 - val_loss: 2.2104 - val_accuracy: 0.6946
# Epoch 10/50
# 72/72 [==============================] - ETA: 0s - loss: 0.3898 - accuracy: 0.9112
# Epoch 10: val_accuracy improved from 0.70157 to 0.74520, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/VGG19_KG_Final.h5
# Total training time for epoch 10: 53.34 seconds
# Highest training accuracy: 0.9112 at epoch 10
# Highest validation accuracy: 0.7452 at epoch 10
# 72/72 [==============================] - 53s 742ms/step - loss: 0.3898 - accuracy: 0.9112 - val_loss: 1.9533 - val_accuracy: 0.7452
# Epoch 11/50
# 72/72 [==============================] - ETA: 0s - loss: 0.4622 - accuracy: 0.9064
# Epoch 11: val_accuracy did not improve from 0.74520
# Total training time for epoch 11: 52.49 seconds
# Highest training accuracy: 0.9112 at epoch 10
# Highest validation accuracy: 0.7452 at epoch 10
# 72/72 [==============================] - 52s 730ms/step - loss: 0.4622 - accuracy: 0.9064 - val_loss: 1.8913 - val_accuracy: 0.7277
# Epoch 12/50
# 72/72 [==============================] - ETA: 0s - loss: 0.3526 - accuracy: 0.9216
# Epoch 12: val_accuracy did not improve from 0.74520
# Total training time for epoch 12: 51.25 seconds
# Highest training accuracy: 0.9216 at epoch 12
# Highest validation accuracy: 0.7452 at epoch 10
# 72/72 [==============================] - 51s 713ms/step - loss: 0.3526 - accuracy: 0.9216 - val_loss: 1.8810 - val_accuracy: 0.7365
# Epoch 13/50
# 72/72 [==============================] - ETA: 0s - loss: 0.3481 - accuracy: 0.9203
# Epoch 13: val_accuracy did not improve from 0.74520
# Total training time for epoch 13: 50.46 seconds
# Highest training accuracy: 0.9216 at epoch 12
# Highest validation accuracy: 0.7452 at epoch 10
# 72/72 [==============================] - 50s 701ms/step - loss: 0.3481 - accuracy: 0.9203 - val_loss: 1.8941 - val_accuracy: 0.7173
# Epoch 14/50
# 72/72 [==============================] - ETA: 0s - loss: 0.2811 - accuracy: 0.9369
# Epoch 14: val_accuracy did not improve from 0.74520
# Total training time for epoch 14: 51.91 seconds
# Highest training accuracy: 0.9369 at epoch 14
# Highest validation accuracy: 0.7452 at epoch 10
# 72/72 [==============================] - 52s 719ms/step - loss: 0.2811 - accuracy: 0.9369 - val_loss: 1.9816 - val_accuracy: 0.7382
# Epoch 15/50
# 72/72 [==============================] - ETA: 0s - loss: 0.3133 - accuracy: 0.9282
# Epoch 15: val_accuracy did not improve from 0.74520
# Total training time for epoch 15: 52.19 seconds
# Highest training accuracy: 0.9369 at epoch 14
# Highest validation accuracy: 0.7452 at epoch 10
# 72/72 [==============================] - 52s 726ms/step - loss: 0.3133 - accuracy: 0.9282 - val_loss: 2.0313 - val_accuracy: 0.7312
# Epoch 16/50
# 72/72 [==============================] - ETA: 0s - loss: 0.2665 - accuracy: 0.9408
# Epoch 16: val_accuracy did not improve from 0.74520
# Total training time for epoch 16: 52.03 seconds
# Highest training accuracy: 0.9408 at epoch 16
# Highest validation accuracy: 0.7452 at epoch 10
# 72/72 [==============================] - 52s 723ms/step - loss: 0.2665 - accuracy: 0.9408 - val_loss: 2.4193 - val_accuracy: 0.7365
# Epoch 17/50
# 72/72 [==============================] - ETA: 0s - loss: 0.2760 - accuracy: 0.9343
# Epoch 17: val_accuracy improved from 0.74520 to 0.77836, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/VGG19_KG_Final.h5
# Total training time for epoch 17: 53.06 seconds
# Highest training accuracy: 0.9408 at epoch 16
# Highest validation accuracy: 0.7784 at epoch 17
# 72/72 [==============================] - 53s 739ms/step - loss: 0.2760 - accuracy: 0.9343 - val_loss: 1.9600 - val_accuracy: 0.7784
# Epoch 18/50
# 72/72 [==============================] - ETA: 0s - loss: 0.2417 - accuracy: 0.9417
# Epoch 18: val_accuracy did not improve from 0.77836
# Total training time for epoch 18: 61.57 seconds
# Highest training accuracy: 0.9417 at epoch 18
# Highest validation accuracy: 0.7784 at epoch 17
# 72/72 [==============================] - 62s 857ms/step - loss: 0.2417 - accuracy: 0.9417 - val_loss: 1.9170 - val_accuracy: 0.7400
# Epoch 19/50
# 72/72 [==============================] - ETA: 0s - loss: 0.2149 - accuracy: 0.9508
# Epoch 19: val_accuracy did not improve from 0.77836
# Total training time for epoch 19: 51.39 seconds
# Highest training accuracy: 0.9508 at epoch 19
# Highest validation accuracy: 0.7784 at epoch 17
# 72/72 [==============================] - 51s 713ms/step - loss: 0.2149 - accuracy: 0.9508 - val_loss: 2.0851 - val_accuracy: 0.7138
# Epoch 20/50
# 72/72 [==============================] - ETA: 0s - loss: 0.2206 - accuracy: 0.9482
# Epoch 20: val_accuracy did not improve from 0.77836
# Total training time for epoch 20: 51.11 seconds
# Highest training accuracy: 0.9508 at epoch 19
# Highest validation accuracy: 0.7784 at epoch 17
# 72/72 [==============================] - 51s 711ms/step - loss: 0.2206 - accuracy: 0.9482 - val_loss: 1.8739 - val_accuracy: 0.7661
# Epoch 21/50
# 72/72 [==============================] - ETA: 0s - loss: 0.2039 - accuracy: 0.9491
# Epoch 21: val_accuracy did not improve from 0.77836
# Total training time for epoch 21: 49.77 seconds
# Highest training accuracy: 0.9508 at epoch 19
# Highest validation accuracy: 0.7784 at epoch 17
# 72/72 [==============================] - 50s 692ms/step - loss: 0.2039 - accuracy: 0.9491 - val_loss: 2.0931 - val_accuracy: 0.7696
# Epoch 22/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1743 - accuracy: 0.9556
# Epoch 22: val_accuracy improved from 0.77836 to 0.78185, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/VGG19_KG_Final.h5
# Total training time for epoch 22: 63.19 seconds
# Highest training accuracy: 0.9556 at epoch 22
# Highest validation accuracy: 0.7818 at epoch 22
# 72/72 [==============================] - 63s 880ms/step - loss: 0.1743 - accuracy: 0.9556 - val_loss: 1.8392 - val_accuracy: 0.7818
# Epoch 23/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1958 - accuracy: 0.9504
# Epoch 23: val_accuracy did not improve from 0.78185
# Total training time for epoch 23: 51.13 seconds
# Highest training accuracy: 0.9556 at epoch 22
# Highest validation accuracy: 0.7818 at epoch 22
# 72/72 [==============================] - 51s 707ms/step - loss: 0.1958 - accuracy: 0.9504 - val_loss: 2.0499 - val_accuracy: 0.7365
# Epoch 24/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1610 - accuracy: 0.9608
# Epoch 24: val_accuracy did not improve from 0.78185
# Total training time for epoch 24: 51.17 seconds
# Highest training accuracy: 0.9608 at epoch 24
# Highest validation accuracy: 0.7818 at epoch 22
# 72/72 [==============================] - 51s 712ms/step - loss: 0.1610 - accuracy: 0.9608 - val_loss: 2.0461 - val_accuracy: 0.7609
# Epoch 25/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1720 - accuracy: 0.9547
# Epoch 25: val_accuracy did not improve from 0.78185
# Total training time for epoch 25: 49.58 seconds
# Highest training accuracy: 0.9608 at epoch 24
# Highest validation accuracy: 0.7818 at epoch 22
# 72/72 [==============================] - 50s 690ms/step - loss: 0.1720 - accuracy: 0.9547 - val_loss: 2.0088 - val_accuracy: 0.7469
# Epoch 26/50
# 72/72 [==============================] - ETA: 0s - loss: 0.2181 - accuracy: 0.9517
# Epoch 26: val_accuracy did not improve from 0.78185
# Total training time for epoch 26: 51.16 seconds
# Highest training accuracy: 0.9608 at epoch 24
# Highest validation accuracy: 0.7818 at epoch 22
# 72/72 [==============================] - 51s 712ms/step - loss: 0.2181 - accuracy: 0.9517 - val_loss: 2.1971 - val_accuracy: 0.7312
# Epoch 27/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1422 - accuracy: 0.9621
# Epoch 27: val_accuracy did not improve from 0.78185
# Total training time for epoch 27: 61.40 seconds
# Highest training accuracy: 0.9621 at epoch 27
# Highest validation accuracy: 0.7818 at epoch 22
# 72/72 [==============================] - 61s 856ms/step - loss: 0.1422 - accuracy: 0.9621 - val_loss: 2.0047 - val_accuracy: 0.7784
# Epoch 28/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1207 - accuracy: 0.9669
# Epoch 28: val_accuracy did not improve from 0.78185
# Total training time for epoch 28: 60.73 seconds
# Highest training accuracy: 0.9669 at epoch 28
# Highest validation accuracy: 0.7818 at epoch 22
# 72/72 [==============================] - 61s 843ms/step - loss: 0.1207 - accuracy: 0.9669 - val_loss: 1.9195 - val_accuracy: 0.7818
# Epoch 29/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1616 - accuracy: 0.9578
# Epoch 29: val_accuracy did not improve from 0.78185
# Total training time for epoch 29: 50.49 seconds
# Highest training accuracy: 0.9669 at epoch 28
# Highest validation accuracy: 0.7818 at epoch 22
# 72/72 [==============================] - 50s 702ms/step - loss: 0.1616 - accuracy: 0.9578 - val_loss: 2.0112 - val_accuracy: 0.7330
# Epoch 30/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1687 - accuracy: 0.9595
# Epoch 30: val_accuracy did not improve from 0.78185
# Total training time for epoch 30: 60.76 seconds
# Highest training accuracy: 0.9669 at epoch 28
# Highest validation accuracy: 0.7818 at epoch 22
# 72/72 [==============================] - 61s 847ms/step - loss: 0.1687 - accuracy: 0.9595 - val_loss: 2.2049 - val_accuracy: 0.7400
# Epoch 31/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1532 - accuracy: 0.9621
# Epoch 31: val_accuracy did not improve from 0.78185
# Total training time for epoch 31: 50.79 seconds
# Highest training accuracy: 0.9669 at epoch 28
# Highest validation accuracy: 0.7818 at epoch 22
# 72/72 [==============================] - 51s 702ms/step - loss: 0.1532 - accuracy: 0.9621 - val_loss: 2.0889 - val_accuracy: 0.7592
# Epoch 32/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1459 - accuracy: 0.9608
# Epoch 32: val_accuracy did not improve from 0.78185
# Total training time for epoch 32: 50.45 seconds
# Highest training accuracy: 0.9669 at epoch 28
# Highest validation accuracy: 0.7818 at epoch 22
# 72/72 [==============================] - 50s 701ms/step - loss: 0.1459 - accuracy: 0.9608 - val_loss: 2.4625 - val_accuracy: 0.7295
# Epoch 33/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1362 - accuracy: 0.9665
# Epoch 33: val_accuracy improved from 0.78185 to 0.79756, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/VGG19_KG_Final.h5
# Total training time for epoch 33: 52.33 seconds
# Highest training accuracy: 0.9669 at epoch 28
# Highest validation accuracy: 0.7976 at epoch 33
# 72/72 [==============================] - 52s 728ms/step - loss: 0.1362 - accuracy: 0.9665 - val_loss: 2.1182 - val_accuracy: 0.7976
# Epoch 34/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1248 - accuracy: 0.9669
# Epoch 34: val_accuracy did not improve from 0.79756
# Total training time for epoch 34: 50.80 seconds
# Highest training accuracy: 0.9669 at epoch 28
# Highest validation accuracy: 0.7976 at epoch 33
# 72/72 [==============================] - 51s 702ms/step - loss: 0.1248 - accuracy: 0.9669 - val_loss: 2.1251 - val_accuracy: 0.7714
# Epoch 35/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1112 - accuracy: 0.9708
# Epoch 35: val_accuracy did not improve from 0.79756
# Total training time for epoch 35: 49.55 seconds
# Highest training accuracy: 0.9708 at epoch 35
# Highest validation accuracy: 0.7976 at epoch 33
# 72/72 [==============================] - 50s 690ms/step - loss: 0.1112 - accuracy: 0.9708 - val_loss: 2.2262 - val_accuracy: 0.7644
# Epoch 36/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1234 - accuracy: 0.9673
# Epoch 36: val_accuracy did not improve from 0.79756
# Total training time for epoch 36: 50.78 seconds
# Highest training accuracy: 0.9708 at epoch 35
# Highest validation accuracy: 0.7976 at epoch 33
# 72/72 [==============================] - 51s 706ms/step - loss: 0.1234 - accuracy: 0.9673 - val_loss: 1.9823 - val_accuracy: 0.7888
# Epoch 37/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1197 - accuracy: 0.9687
# Epoch 37: val_accuracy did not improve from 0.79756
# Total training time for epoch 37: 49.24 seconds
# Highest training accuracy: 0.9708 at epoch 35
# Highest validation accuracy: 0.7976 at epoch 33
# 72/72 [==============================] - 49s 684ms/step - loss: 0.1197 - accuracy: 0.9687 - val_loss: 2.0963 - val_accuracy: 0.7574
# Epoch 38/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1039 - accuracy: 0.9721
# Epoch 38: val_accuracy did not improve from 0.79756
# Total training time for epoch 38: 51.75 seconds
# Highest training accuracy: 0.9721 at epoch 38
# Highest validation accuracy: 0.7976 at epoch 33
# 72/72 [==============================] - 52s 720ms/step - loss: 0.1039 - accuracy: 0.9721 - val_loss: 2.1501 - val_accuracy: 0.7714
# Epoch 39/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1252 - accuracy: 0.9695
# Epoch 39: val_accuracy did not improve from 0.79756
# Total training time for epoch 39: 50.91 seconds
# Highest training accuracy: 0.9721 at epoch 38
# Highest validation accuracy: 0.7976 at epoch 33
# 72/72 [==============================] - 51s 708ms/step - loss: 0.1252 - accuracy: 0.9695 - val_loss: 1.9517 - val_accuracy: 0.7853
# Epoch 40/50
# 72/72 [==============================] - ETA: 0s - loss: 0.0991 - accuracy: 0.9739
# Epoch 40: val_accuracy did not improve from 0.79756
# Total training time for epoch 40: 50.35 seconds
# Highest training accuracy: 0.9739 at epoch 40
# Highest validation accuracy: 0.7976 at epoch 33
# 72/72 [==============================] - 50s 696ms/step - loss: 0.0991 - accuracy: 0.9739 - val_loss: 2.3320 - val_accuracy: 0.7469
# Epoch 41/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1313 - accuracy: 0.9743
# Epoch 41: val_accuracy did not improve from 0.79756
# Total training time for epoch 41: 51.59 seconds
# Highest training accuracy: 0.9743 at epoch 41
# Highest validation accuracy: 0.7976 at epoch 33
# 72/72 [==============================] - 52s 717ms/step - loss: 0.1313 - accuracy: 0.9743 - val_loss: 2.2005 - val_accuracy: 0.7557
# Epoch 42/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1238 - accuracy: 0.9682
# Epoch 42: val_accuracy improved from 0.79756 to 0.79930, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/VGG19_KG_Final.h5
# Total training time for epoch 42: 62.38 seconds
# Highest training accuracy: 0.9743 at epoch 41
# Highest validation accuracy: 0.7993 at epoch 42
# 72/72 [==============================] - 62s 869ms/step - loss: 0.1238 - accuracy: 0.9682 - val_loss: 1.9086 - val_accuracy: 0.7993
# Epoch 43/50
# 72/72 [==============================] - ETA: 0s - loss: 0.0869 - accuracy: 0.9756
# Epoch 43: val_accuracy did not improve from 0.79930
# Total training time for epoch 43: 50.96 seconds
# Highest training accuracy: 0.9756 at epoch 43
# Highest validation accuracy: 0.7993 at epoch 42
# 72/72 [==============================] - 51s 708ms/step - loss: 0.0869 - accuracy: 0.9756 - val_loss: 2.4071 - val_accuracy: 0.7574
# Epoch 44/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1141 - accuracy: 0.9726
# Epoch 44: val_accuracy did not improve from 0.79930
# Total training time for epoch 44: 49.66 seconds
# Highest training accuracy: 0.9756 at epoch 43
# Highest validation accuracy: 0.7993 at epoch 42
# 72/72 [==============================] - 50s 691ms/step - loss: 0.1141 - accuracy: 0.9726 - val_loss: 2.3048 - val_accuracy: 0.7644
# Epoch 45/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1102 - accuracy: 0.9708
# Epoch 45: val_accuracy did not improve from 0.79930
# Total training time for epoch 45: 50.59 seconds
# Highest training accuracy: 0.9756 at epoch 43
# Highest validation accuracy: 0.7993 at epoch 42
# 72/72 [==============================] - 51s 703ms/step - loss: 0.1102 - accuracy: 0.9708 - val_loss: 2.3905 - val_accuracy: 0.7417
# Epoch 46/50
# 72/72 [==============================] - ETA: 0s - loss: 0.0836 - accuracy: 0.9774
# Epoch 46: val_accuracy did not improve from 0.79930
# Total training time for epoch 46: 50.33 seconds
# Highest training accuracy: 0.9774 at epoch 46
# Highest validation accuracy: 0.7993 at epoch 42
# 72/72 [==============================] - 50s 700ms/step - loss: 0.0836 - accuracy: 0.9774 - val_loss: 1.9103 - val_accuracy: 0.7993
# Epoch 47/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1021 - accuracy: 0.9756
# Epoch 47: val_accuracy did not improve from 0.79930
# Total training time for epoch 47: 49.36 seconds
# Highest training accuracy: 0.9774 at epoch 46
# Highest validation accuracy: 0.7993 at epoch 42
# 72/72 [==============================] - 49s 687ms/step - loss: 0.1021 - accuracy: 0.9756 - val_loss: 2.2008 - val_accuracy: 0.7801
# Epoch 48/50
# 72/72 [==============================] - ETA: 0s - loss: 0.0960 - accuracy: 0.9761
# Epoch 48: val_accuracy did not improve from 0.79930
# Total training time for epoch 48: 50.21 seconds
# Highest training accuracy: 0.9774 at epoch 46
# Highest validation accuracy: 0.7993 at epoch 42
# 72/72 [==============================] - 50s 698ms/step - loss: 0.0960 - accuracy: 0.9761 - val_loss: 2.2267 - val_accuracy: 0.7731
# Epoch 49/50
# 72/72 [==============================] - ETA: 0s - loss: 0.1101 - accuracy: 0.9743
# Epoch 49: val_accuracy did not improve from 0.79930
# Total training time for epoch 49: 50.04 seconds
# Highest training accuracy: 0.9774 at epoch 46
# Highest validation accuracy: 0.7993 at epoch 42
# 72/72 [==============================] - 50s 692ms/step - loss: 0.1101 - accuracy: 0.9743 - val_loss: 2.0741 - val_accuracy: 0.7818
# Epoch 50/50
# 72/72 [==============================] - ETA: 0s - loss: 0.0719 - accuracy: 0.9817
# Epoch 50: val_accuracy improved from 0.79930 to 0.81675, saving model to /content/drive/MyDrive/Deep_Learning/Brain Tumor MRI Classification RF/VGG19_KG_Final.h5
# Total training time for epoch 50: 51.09 seconds
# Highest training accuracy: 0.9817 at epoch 50
# Highest validation accuracy: 0.8168 at epoch 50
# 72/72 [==============================] - 51s 710ms/step - loss: 0.0719 - accuracy: 0.9817 - val_loss: 2.0799 - val_accuracy: 0.8168
# Total training time for 50 epochs: 2680.04 seconds

# %% [markdown]
# ### Plot the training and validation accuracy

# %%
fig, ax = plt.subplots(figsize=(14,7))
ax.plot(history.history['accuracy'])
ax.plot(history.history['val_accuracy'])
ax.set_title('Model Accuracy')
ax.set_xlabel('Epoch')
ax.set_ylabel('Accuracy')
ax.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### Plot the Training and Validation Loss

# %%
fig, ax = plt.subplots(figsize=(14,7))
ax.plot(history.history['loss'])
ax.plot(history.history['val_loss'])
ax.set_title('Model Loss')
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')
ax.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### Test the model on the test data

# %%
test_loss, test_acc = model.evaluate(test_generator, steps=len(test_generator))
print("Test accuracy:", test_acc)
# Out:
# 13/13 [==============================] - 5s 353ms/step - loss: 7.7960 - accuracy: 0.7437
# Test accuracy: 0.7436548471450806

# %% [markdown]
# ### Generate predictions on the test data

# %%
y_pred = model.predict(test_generator, steps=len(test_generator))
y_true = test_generator.classes
# Out:
# 13/13 [==============================] - 3s 188ms/step

# %% [markdown]
# ### Generate and plot confusion matrix

# %%
cm = confusion_matrix(y_true, np.argmax(y_pred, axis=1))
plt.figure(figsize=(8, 8))
sns.heatmap(cm, annot=True, cmap="Blues", square=True, xticklabels=test_generator.class_indices.keys(),
            yticklabels=test_generator.class_indices.keys(), fmt='g')
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.show()

# %% [markdown]
# ### Print classification report

# %%
class_names = list(test_generator.class_indices.keys())
print(classification_report(y_true, np.argmax(y_pred, axis=1), target_names=class_names))
# Out:
#                   precision    recall  f1-score   support
#
#     glioma_tumor       0.91      0.20      0.33       100
# meningioma_tumor       0.65      0.99      0.79       115
#         no_tumor       0.77      0.98      0.86       105
#  pituitary_tumor       0.89      0.76      0.82        74
#
#         accuracy                           0.74       394
#        macro avg       0.80      0.73      0.70       394
#     weighted avg       0.79      0.74      0.70       394

# %% [markdown]
# ### Compute precision, recall, F1 score and support for each class

# %%
precision, recall, f1_score, support = precision_recall_fscore_support(y_true, np.argmax(y_pred, axis=1))

# %%
# Create a dataframe with the computed metrics for each class
metrics_df = pd.DataFrame({
    'Precision': precision,
    'Recall': recall,
    'F1 Score': f1_score,
    'Support': support
}, index=class_names)

#Print the dataframe
print(metrics_df)
# Out:
#                   Precision    Recall  F1 Score  Support
# glioma_tumor       0.909091  0.200000  0.327869      100
# meningioma_tumor   0.651429  0.991304  0.786207      115
# no_tumor           0.768657  0.980952  0.861925      105
# pituitary_tumor    0.888889  0.756757  0.817518       74

# %% [markdown]
# ### Compute ROC and AUC for each class

# %%
fpr = {}
tpr = {}
roc_auc = {}

# Compute ROC and AUC for each class
for i in range(train_generator.num_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true == i, y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# %% [markdown]
# ### Plot ROC curve for each class

# %%
plt.figure(figsize=(8, 6))
for i in range(train_generator.num_classes):
    plt.plot(fpr[i], tpr[i], label='%s (AUC = %0.2f)' % (class_names[i], roc_auc[i]))
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic Curve')
plt.legend(loc="lower right")
plt.show()
